# %% [markdown]
# # Assignment 1: Keeping Up With Social Information (Part 1)
# ## © Cristian Danescu-Niculescu-Mizil 2023
# ## CS/INFO 4300 Language and Information
# ## Due by midnight on Wednesday February 1st
#
# This assignment is **individual**.
#
# In this assignment we are practicing with post-processing on a conversational dataset taken from the reality TV show "Keeping Up With The Kardashians" and gathering some basic statistics about it.
#
# In the next assignment (Assignment 2) we will extend these tools to analyze conversational behavior.
#
# **Learning Objectives**
#
# This project aims to help you get comfortable working with the following tools / technologies / concepts:
#
# * word tokenization
# * histogram plotting using `matplotlib`
# * character analysis via conversational language
# * familiarize yourself with basic numpy usage
#
# **Academic Integrity and Collaboration**
#
# Note that these projects should be completed individually. As a result, all University-standard academic integrity guidelines must be followed.
#
# **Guidelines**
#
# All cells that contain the blocks that read `# YOUR CODE HERE` are editable and are to be completed to ensure you pass the test-cases. Make sure to write your code where indicated.
#
# All cells that read `YOUR ANSWER HERE` are free-response cells that are editable and are to be completed.
#
# You may use any number of notebook cells to explore the data and test out your functions, although you will only be graded on the solution itself.
#
#
# You are unable to modify the read-only cells.
#
# You should also use Markdown cells to explain your code and discuss your results when necessary.
# Instructions can be found [here](http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# All floating point values should be printed with **2 decimal places** precision. You can do so using the built-in round function.
#
# **Grading**
#
# For code-completion questions you will be graded on passing the public test cases we have included, as well as any hidden test cases that we have supplemented within a given amount of time to ensure that your logic is correct.
#
# Your solution to A1 should finish running in **less than 5 minutes**.
# For your information, it takes less than 1 minute to run our solution for the entire A1.
# Also make sure to remove any **redundant print statements** to speed things up and prevent generating unnecessary outputs.
#
# For free-response questions you will be manually graded on the quality of your answer.
#
# **Submission**
#
# You are expected to submit this .ipynb as your submission for Assignment 1.
#
# In addition please submit an html copy of the notebook (You can create this by clicking File > Download as > HTML (.html)).

# %% [markdown]
# #### A0 Review
#
# Recall the learning objectives of A0:
#
# - The Jupyter Notebook environment
# - Recap of Python syntax and basic data structures
# - virtualenv environment for package dependencies
#
# We used the BeautifulSoup library to extract episode titles, timestamps, and character speech from HTML files, then stored this data in Python Dictionaries. Finally, we conducted preliminary checks of our data to test its usability (i.e. checking for duplicate transcripts and converting nickname "Rob" to "Robert").

# %%
import re
import json
from glob import glob
import os
from io import StringIO
from itertools import groupby
import pickle

import numpy as np
import bs4
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import sys
# Ensure that your kernel is using Python3
assert sys.version_info.major == 3

# %% [markdown]
# ## Preliminary Data Cleansing
# **Note: The following content is for you to review to understand how we cleaned and prepared the data for the analysis below.**
#
# We will be continuing where we left off from Assignment 0.
#
# ### Removing duplicates
# If you are to examine the original transcripts you will see that many of them are near-duplicates, but most are not *perfect* duplicates. This is problematic, because we cannot simply remove identical transcripts.  Furthermore, we cannot just throw away documents that have large overlap, because we would be throwing away the valuable data that is *not* overlapping.
#
# We therefore have to treat the transcripts as sequences, rather than as entire documents, and just remove subsequences that overlap.
#
# We therefore used a standard python `difflib` package to write the `find_overlaps` function:
#
# ```python
# import difflib
# def find_overlaps(transcript_a, transcript_b, threshold=5):
#     """Find and return the indices of overlapping subsequences between the two transcripts.
#     Only return overlapping sequences that consist of at least `threshold` entries."""
#
#     # We consider that two transcripts overlap when the messages
#     # and the speakers are the same, but not the timestamp.
#
#     # Massage the transcripts to disregard timestamp information.
#     # note that a tuple is hashable, so is okay to use for difflib's SequenceMatcher class.
#     msgs_a = [(m['speaker'], m['text']) if m is not None else None
#               for m in transcript_a]
#     msgs_b = [(m['speaker'], m['text']) if m is not None else None
#               for m in transcript_b]
#     matcher = difflib.SequenceMatcher(None, msgs_a, msgs_b)
#     return list(filter(lambda tup: tup[2] >= threshold, matcher.get_matching_blocks()))
# ```
#
# We now use the function above to remove duplicate subsequences. At each step, assume we have a list of "good" transcripts that have already been processed. When considering a new transcript, we first remove all subsequences that overlap with any of the already processed ones. Then, we split up the chunks that are not removed, and consider each of them a new transcript.
#
# ```python
# deduped_transcripts = []
# all_keys = sorted(transcripts.keys())
#
# for key in all_keys:
#     transcript = transcripts[key]
#     for _, good_transcript in deduped_transcripts:
#         overlaps = find_overlaps(transcript, good_transcript)
#         for idx_a, _, size in overlaps:
#             transcript[idx_a:idx_a + size] = [None] * size
#
#     for is_not_none, group in groupby(transcript, lambda x: x is not None):
#         if is_not_none:
#             subtranscript = list(group)
#             deduped_transcripts.append((key, subtranscript))
# ```
#
# The `deduped_transcripts` are what you are now analyzing for the rest of the assignment.

# %%
## We are loading the pickle file that contains all the deduped transcripts from Assignment 0
with open('deduped_transcripts.pickle','rb') as f:
    deduped_transcripts = pickle.load(f)
## We are also loading a pickle file of the titles file that we determined in the beginning of Assignment 0
with open('titles.pickle','rb') as f:
    titles = pickle.load(f)

# %% [markdown]
# # Language analysis
#
# ## Identifying the words
# It's time to get down to the bread-and-butter of language analysis: the words used.  For simplification, **we consider a word to be a sequence of alphabetical characters. Treat all other characters as delimiters and do not return them.**
#
#
# ## Question 1 (Code Completion): Tokenization
#
# In the cell below: *Write a function to 'tokenize' a string into the constituent words*.
#
# You **must** use regex to satisfy the function specification. We recommend you leverage `re.findall`.
#
# Hint: Check out this online regex calculator: [here](https://regex101.com/)

# %%
def tokenize(text):
    """Returns a list of words that make up the text.
    
    Note: for simplicity, lowercase everything.
    Requirement: Use Regex to satisfy this function
    
    Params: {text: String}
    Returns: List
    """
    # find the expression that matches a word using regex
    tokens = re.findall(r'[a-z]+', text.lower())
    return tokens

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that tokenize returns the correct output"""
assert tokenize("It's time 2 get down to the bread-and-butter") == \
    ['it', 's', 'time', 'get', 'down', 'to', 'the', 'bread', 'and', 'butter']
assert tokenize("Life, Liberty, & the Pursuit of Happiness") == \
    ['life', 'liberty', 'the', 'pursuit', 'of', 'happiness']

# %% [markdown]
# ## Question 2 (Code Completion): Tokenization of Entire Transcript
#
# In the cell below write a function that *tokenizes all of the text in an input transcript (given a method for tokenizing strings)*, producing a list of all tokens found in the entire transcript.

# %%
def tokenize_transcript(tokenize_method,input_transcript):
    """Returns a list of tokens contained in an entire transcript.
    Params: {tokenize_method: Function (a -> b),
             input_transcript: Tuple}
    Returns: List
    """
    tokens = [] 
    # input_transcript[1] is a list of dictionaries
    # each dictionary has a key 'text' and a value that is a string
    for transcript in input_transcript[1]:
        text = transcript['text']
        tokens += tokenize_method(text)

    return tokens

# %%
len(deduped_transcripts)
# Out:
# 1163

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that tokenize returns the correct output"""
assert len(tokenize_transcript(tokenize,deduped_transcripts[0])) > 6000 and \
    len(tokenize_transcript(tokenize,deduped_transcripts[0])) < 7000

# %% [markdown]
# ## Question 3 (Code Completion) Number of Tokens
# In the cell below write a function to *count how many tokens are used in the deduplicated transcripts in total*

# %%
def num_dedup_tokens(tokenize_method,tokenize_transcript_method,input_transcripts):
    """Returns number of tokens used in an entire transcript
    Params: {tokenize_method: Function (a -> b),
             // Note: Below type means a function that takes two arguments, the first of which is a function.
             tokenize_transcript_method: Function ((Function(a -> b), c) -> d),
             input_transcripts: Tuple List}
    Returns: Integer
    """
    token_num = 0
    for transcript in deduped_transcripts:
        token_num += len(tokenize_transcript_method(tokenize_method,transcript))
    return token_num

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that num_dedup_tokens returns the correct output"""
assert num_dedup_tokens(tokenize,tokenize_transcript,deduped_transcripts) > 200000 and \
    num_dedup_tokens(tokenize,tokenize_transcript,deduped_transcripts) < 300000

# %% [markdown]
# ## Question 4 (Code Completion) Number of Distinct Words
#
# In the cell below write a function to *count how many distinct words are in the deduplicated transcripts in total*.
#
# Hint: Use a *set*

# %%
def num_distinct_words(tokenize_method,tokenize_transcript_method,input_transcripts):
    """Returns number of distinct tokens used in an entire transcript
    Params: {tokenize_method: Function (a -> b),
             // Note: Below type means a function that takes two arguments, the first of which is a function.
             tokenize_transcript_method: Function ((Function(a -> b), c) -> d),
             input_transcripts: Tuple List}
    Returns: Integer
    """
    distinct_token = set()
    for transcript in deduped_transcripts:
        distinct_token.update(tokenize_transcript_method(tokenize_method,transcript))
    return len(distinct_token)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that num_dedup_tokens returns the correct output"""
assert num_distinct_words(tokenize,tokenize_transcript,deduped_transcripts) > 8000 and \
    num_distinct_words(tokenize,tokenize_transcript,deduped_transcripts) < 9000

# %% [markdown]
# # Question 5 (Code Completion) Word Episode Counts
#
# This question is asking you to build a dictionary `word_episode_count[word]` = *number of episodes in which the word appears*.
#
# *Note: Keep in mind that the de-duplicated transcripts don't have unique titles!
# Recall from A0 that **one episode corresponds to exactly one title** (but not necessarily to only one transcript).*
#
# **Your code should ideally take less than 1 second (or a few seconds) to run. If it does not, then you should be able to find a better answer.**
#
# In the cell below write a function that counts: *for each distinct (unique) word, in how many different episodes does it appear?*

# %%
def build_word_episode_count(tokenize_method,tokenize_transcript_method,input_transcripts,input_titles):
    """Returns a dictionary with the number of episodes each distinct word appears
        Params: {tokenize_method: Function (a -> b),
                 // Note: Below type means a function that takes two arguments, the first of which is a function.
                 tokenize_transcript_method: Function ((Function(a -> b), c) -> d),
                 input_transcripts: Tuple List,
                 input_titles: Dictionary}
        Returns: Dict
    """
    # a dictionary with the number of episodes each distinct word appears, initialized to 0
    distinct_tokens = set()
    for transcript in input_transcripts:
        distinct_tokens.update(tokenize_transcript_method(tokenize_method,transcript))

    word_episode_count = dict.fromkeys(distinct_tokens,0)

    # print(word_episode_count)

    # a set of distinct titles
    distinct_titles = {value for value in titles.values()}

    for title in distinct_titles:

        # a set of distinct tokens in an episode
        tokens_in_episode=set()

        # find the first transcripts with the title
        for index in range(len(input_transcripts)):
            code = input_transcripts[index][0]
            if (titles[code] == title):
                # tokenize the transcript
                tokens = tokenize_transcript_method(tokenize_method,input_transcripts[index])
                tokens_in_episode.update(tokens)
        

        # update the word_episode_count
        for token in tokens_in_episode:
            word_episode_count[token] += 1
    return word_episode_count

# %%
word_episode_count = build_word_episode_count(tokenize,tokenize_transcript,deduped_transcripts,titles)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that build_word_episode_count returns the correct output"""
assert word_episode_count['quarter'] == 2
assert word_episode_count['made'] == 40
assert word_episode_count['never'] == 49

# %% [markdown]
# ## Question 6 (Code Completion) Distribution Analysis
#
# For this question, you will be summarizing the word episode counts you found above by combining them into a *distribution* of the number of episodes in which words appear. That is: *how many words appear in only one episode, how many appear in two episodes, and so on?*
#
# Specifically, you will build a dictionary `word_episode_distribution[n]` = *number of words that appear in exactly* `n` *episodes*.
#
# In the cell below fulfill the specifications above and have the function: *produce a distribution of word episode counts*

# %%
word_episode_count
# Out:
# {'lasik': 1,
#  'guy': 37,
#  'prep': 2,
#  'rabbits': 2,
#  'nudity': 1,
#  'apology': 8,
#  'contact': 5,
#  'funny': 31,
#  'bouquet': 3,
#  'firm': 4,
#  'foundation': 3,
#  'papers': 1,
#  'managing': 5,
#  'thedub': 1,
#  'shortsto': 2,
#  'wondered': 2,
#  'beau': 2,
#  'haven': 30,
#  'interfere': 3,
#  'squatting': 1,
#  'medications': 2,
#  'lows': 1,
#  'tickets': 5,
#  'slopes': 1,
#  'taxis': 1,
#  'fed': 1,
#  'sickenin': 1,
#  'assault': 1,
#  'kimmie': 2,
#  'art': 5,
#  'stressful': 6,
#  'lube': 2,
#  'changes': 5,
#  'wake': 9,
#  'scan': 2,
#  'duo': 1,
#  'donor': 1,
#  'patter': 1,
#  'respect': 16,
#  'beard': 1,
#  'advilliqui': 1,
#  'airplane': 1,
#  'fish': 5,
#  'rooster': 1,
#  'theme': 3,
#  'mothers': 1,
#  'great': 44,
#  'cds': 1,
#  'roldan': 1,
#  'enjoying': 5,
#  'major': 14,
#  'everyday': 2,
#  'everybody': 39,
#  'eyeliner': 3,
#  'arabic': 1,
#  'affordable': 1,
#  'trademark': 1,
#  'triple': 3,
#  'doubled': 1,
#  'giving': 14,
#  'unfortunate': 1,
#  'july': 2,
#  'lengthens': 1,
#  'laughs': 1,
#  'upon': 4,
#  'needed': 10,
#  'trains': 1,
#  'sponsored': 28,
#  'jerk': 3,
#  'mergeyour': 1,
#  'addict': 4,
#  'motivates': 1,
#  'sooner': 7,
#  'upright': 2,
#  'murray': 29,
#  'soar': 1,
#  'merrier': 1,
#  'america': 4,
#  'metlife': 4,
#  'superbowl': 1,
#  'wearing': 23,
#  'wendy': 3,
#  'sing': 4,
#  'share': 13,
#  'introduces': 3,
#  'tobe': 2,
#  'caught': 6,
#  'lose': 20,
#  'napkin': 1,
#  'kidney': 3,
#  'since': 34,
#  'blew': 5,
#  'producer': 1,
#  'talk': 45,
#  'concern': 2,
#  'beautyof': 1,
#  'welcoming': 1,
#  'till': 13,
#  'swiff': 1,
#  'necklace': 1,
#  'floors': 2,
#  'yaz': 3,
#  'soho': 1,
#  'venture': 3,
#  'swats': 1,
#  'leggings': 2,
#  'decorate': 1,
#  'tobayerforwomen': 3,
#  'lady': 10,
#  'happen': 33,
#  'trick': 3,
#  'emotion': 3,
#  'louis': 1,
#  'ape': 1,
#  'sock': 1,
#  'jams': 1,
#  'message': 8,
#  'package': 4,
#  'leak': 2,
#  'cou': 1,
#  'echinacea': 1,
#  'honestly': 27,
#  'waver': 2,
#  'headed': 3,
#  'ofhormone': 1,
#  'ticket': 3,
#  'gabbana': 6,
#  'friendly': 4,
#  'temper': 2,
#  'essidn': 1,
#  'matt': 1,
#  'series': 2,
#  'injured': 2,
#  'randomly': 2,
#  'discounts': 1,
#  'regarding': 1,
#  'pun': 1,
#  'ma': 3,
#  'hook': 7,
#  'pretended': 1,
#  'ongainfabric': 1,
#  'racing': 4,
#  'wonderful': 12,
#  'leftover': 1,
#  'wo': 1,
#  'explain': 6,
#  'watched': 3,
#  'smells': 9,
#  'myspace': 2,
#  'killer': 2,
#  'insides': 2,
#  'blessed': 2,
#  'games': 14,
#  'persian': 1,
#  'developing': 1,
#  'sexiness': 2,
#  'babe': 21,
#  'switchin': 1,
#  'breakdown': 1,
#  'butta': 1,
#  'track': 5,
#  'prayers': 2,
#  'remove': 4,
#  'counters': 1,
#  'nutrition': 2,
#  'bayer': 3,
#  'phase': 3,
#  'satisfactionguaranteed': 1,
#  'peer': 1,
#  'payoff': 2,
#  'canyon': 3,
#  'moles': 1,
#  'loosening': 1,
#  'any': 46,
#  'shoot': 23,
#  'brittny': 1,
#  'anything': 44,
#  'lobster': 2,
#  'connect': 2,
#  'perfect': 39,
#  'dvd': 3,
#  'downs': 1,
#  'whether': 10,
#  'tre': 1,
#  'commissioned': 1,
#  'porch': 1,
#  'tippy': 1,
#  'mix': 2,
#  'preliminary': 1,
#  'naked': 9,
#  'understands': 6,
#  'fuel': 1,
#  'hpv': 1,
#  'sized': 1,
#  'smith': 3,
#  'dope': 1,
#  'lipolysis': 1,
#  'excellent': 5,
#  'tp': 1,
#  'toyour': 3,
#  'asthma': 1,
#  'showed': 5,
#  'planned': 8,
#  'grill': 1,
#  'premarital': 2,
#  'independent': 1,
#  'prices': 4,
#  'booking': 1,
#  'live': 24,
#  'interrupts': 1,
#  'odom': 5,
#  'clever': 1,
#  'mud': 2,
#  'subpoena': 1,
#  'blackmailing': 1,
#  'week': 22,
#  'committed': 3,
#  'reek': 3,
#  'while': 32,
#  'ever': 48,
#  'shownto': 1,
#  'dorm': 1,
#  'thecompetitions': 1,
#  'dealing': 4,
#  'retarded': 6,
#  'minty': 1,
#  'rollhas': 1,
#  'valuable': 1,
#  'visibly': 1,
#  'bottle': 9,
#  'africa': 2,
#  'goodness': 7,
#  'hill': 3,
#  'judgmental': 4,
#  'each': 35,
#  'prepared': 3,
#  'leaking': 1,
#  'dferent': 1,
#  'sam': 1,
#  'sentence': 1,
#  'saline': 1,
#  'cheats': 1,
#  'men': 8,
#  'looked': 19,
#  'pitter': 1,
#  'royces': 2,
#  'approval': 2,
#  'disappoints': 1,
#  'glucose': 1,
#  'computers': 1,
#  'penetration': 1,
#  'networks': 1,
#  'worldknow': 1,
#  'rest': 20,
#  'doggie': 1,
#  'providerabout': 1,
#  'hurdles': 1,
#  'matters': 7,
#  'network': 8,
#  'mmy': 1,
#  'swat': 1,
#  'attempt': 1,
#  'nurture': 1,
#  'auction': 1,
#  'texted': 2,
#  'calves': 2,
#  'armpits': 1,
#  'generation': 4,
#  'nervous': 24,
#  'knocked': 6,
#  'overnight': 4,
#  'unnatural': 1,
#  'kicking': 3,
#  'tvguideparty': 1,
#  'rwelcome': 1,
#  'hello': 46,
#  'peoplemagazine': 2,
#  'safely': 1,
#  'peed': 3,
#  'top': 22,
#  'pillar': 3,
#  'makers': 1,
#  'asinstructed': 3,
#  'dear': 2,
#  'date': 20,
#  'faze': 1,
#  'kendal': 2,
#  'seege': 1,
#  'destined': 1,
#  'fatal': 1,
#  'sharon': 2,
#  'hate': 31,
#  'agent': 4,
#  'amazing': 37,
#  'f': 1,
#  'correct': 4,
#  'padding': 1,
#  'liars': 1,
#  'sue': 5,
#  'pipe': 3,
#  'tent': 2,
#  'terms': 5,
#  'dish': 1,
#  'blows': 1,
#  'nut': 1,
#  'carrier': 1,
#  'stretching': 2,
#  'toast': 10,
#  'richconditioner': 1,
#  'donate': 4,
#  'noticeables': 1,
#  'psychotic': 4,
#  'gate': 2,
#  'proble': 1,
#  'insurance': 8,
#  'geez': 4,
#  'ipping': 1,
#  'own': 39,
#  'liner': 1,
#  'passionate': 2,
#  'frog': 1,
#  'plate': 7,
#  'clearly': 6,
#  'cordless': 1,
#  'thumb': 3,
#  'lookingcolor': 1,
#  'opened': 4,
#  'squared': 1,
#  'petrified': 2,
#  'trra': 1,
#  'companion': 1,
#  'luminary': 1,
#  'aids': 1,
#  'twitter': 2,
#  'win': 9,
#  'minnie': 1,
#  'gambler': 1,
#  'shine': 9,
#  'explains': 2,
#  'baron': 1,
#  'garrett': 2,
#  'embarrassment': 1,
#  'facelift': 1,
#  'butter': 9,
#  'surround': 1,
#  'byhim': 1,
#  'breathe': 5,
#  'cabin': 1,
#  'equivalent': 2,
#  'doesnot': 1,
#  'starstruck': 1,
#  'backgrounds': 1,
#  'accepts': 1,
#  'myth': 1,
#  'careful': 6,
#  'admire': 1,
#  'speakwith': 2,
#  'contactlenses': 3,
#  'mending': 1,
#  'surfers': 1,
#  'sold': 4,
#  'whenever': 14,
#  'hoped': 1,
#  'cocktail': 5,
#  'suffer': 2,
#  'pen': 2,
#  'october': 1,
#  'bright': 10,
#  'sausage': 2,
#  'but': 53,
#  'nit': 1,
#  'lightinterplay': 1,
#  'backstage': 1,
#  'death': 15,
#  'puffs': 2,
#  'crap': 6,
#  'reason': 21,
#  'beingo': 1,
#  'theoriginalbouncesmell': 1,
#  'easytone': 2,
#  'skinned': 1,
#  'bottles': 4,
#  'without': 24,
#  'glamour': 1,
#  'eightdelicious': 1,
#  'engaged': 8,
#  'focus': 10,
#  'excuse': 17,
#  'nutrisystem': 1,
#  'sightsee': 1,
#  'orchestra': 2,
#  'whiter': 1,
#  'unhappy': 2,
#  'defensive': 2,
#  'classes': 7,
#  'latelyshow': 1,
#  'chill': 9,
#  'registered': 1,
#  'perverts': 1,
#  'tick': 5,
#  'confirmed': 1,
#  'sickness': 2,
#  'recording': 2,
#  'flick': 2,
#  'whore': 7,
#  'skittles': 1,
#  'spin': 3,
#  'hangs': 1,
#  'types': 3,
#  'myod': 1,
#  'middle': 12,
#  'surprised': 8,
#  'stu': 1,
#  'pissedyouoff': 2,
#  'afterwards': 1,
#  'roll': 12,
#  'brah': 1,
#  'name': 26,
#  'unpacking': 1,
#  'additional': 2,
#  'flow': 5,
#  'rebel': 1,
#  'botch': 1,
#  'folder': 1,
#  'investigator': 1,
#  'room': 41,
#  'bobbo': 1,
#  'ruce': 1,
#  'flawlessgray': 2,
#  'discovering': 3,
#  'muzzle': 1,
#  'relaxing': 5,
#  'bloopers': 1,
#  'kira': 1,
#  'scream': 8,
#  'identical': 1,
#  'planetsyou': 1,
#  'holidays': 2,
#  'choking': 1,
#  'karma': 1,
#  'forum': 1,
#  'opens': 2,
#  'time': 52,
#  'coul': 1,
#  'boa': 1,
#  'dry': 8,
#  'beverly': 6,
#  'fabric': 5,
#  'sneakers': 2,
#  'did': 50,
#  'adoraboots': 1,
#  'eww': 1,
#  'fortunate': 1,
#  'cannibal': 1,
#  'quitter': 2,
#  'shorter': 1,
#  'aspect': 2,
#  'publicist': 3,
#  'swedish': 1,
#  'tastes': 4,
#  'cowrote': 1,
#  'answer': 17,
#  'tangle': 2,
#  'wasteful': 1,
#  'have': 52,
#  'blasted': 1,
#  'realizes': 4,
#  'dip': 2,
#  'pad': 3,
#  'smoothly': 3,
#  'conditioners': 1,
#  'nancsting': 1,
#  'overcrowding': 1,
#  'spree': 1,
#  'place': 31,
#  'whole': 43,
#  'unavailable': 2,
#  'troubles': 1,
#  'cheating': 4,
#  'products': 10,
#  'roadie': 1,
#  'boyfriend': 23,
#  'factor': 1,
#  'sugah': 1,
#  'attacked': 3,
#  'korchek': 1,
#  'ass': 31,
#  'swifferjet': 1,
#  'bachelorette': 2,
#  'peaceful': 2,
#  'sir': 5,
#  'jammer': 2,
#  'alex': 3,
#  'provento': 1,
#  'rowdier': 1,
#  'championship': 2,
#  'can': 53,
#  'womb': 1,
#  'yesterday': 13,
#  'winds': 1,
#  'tournament': 4,
#  'daters': 1,
#  'frankel': 2,
#  'ci': 1,
#  'patient': 2,
#  'wood': 1,
#  'pasta': 3,
#  'ottoman': 1,
#  'yep': 8,
#  'granting': 1,
#  'duster': 1,
#  'la': 2,
#  'renewing': 1,
#  'old': 40,
#  'stayed': 4,
#  'liven': 1,
#  'captioning': 28,
#  'expanding': 1,
#  'hairstyle': 1,
#  'premium': 3,
#  'petite': 1,
#  'productions': 29,
#  'slot': 1,
#  'trashy': 2,
#  'projects': 3,
#  'minnillo': 1,
#  'arrangement': 1,
#  'poor': 11,
#  'happ': 1,
#  'blast': 3,
#  'honey': 40,
#  'nilda': 1,
#  'tahoe': 1,
#  'bags': 8,
#  'windows': 4,
#  'sharpie': 2,
#  'tips': 2,
#  'black': 19,
#  'wrong': 32,
#  'turns': 6,
#  'express': 3,
#  'came': 35,
#  'counter': 4,
#  'reflect': 1,
#  'tor': 1,
#  'bird': 1,
#  'eed': 1,
#  'chrysler': 1,
#  'paperwork': 1,
#  'word': 13,
#  'sandra': 1,
#  'draped': 1,
#  'evolve': 1,
#  'confirm': 1,
#  'bus': 5,
#  'flower': 2,
#  'odem': 1,
#  'december': 3,
#  'utah': 2,
#  'electronics': 2,
#  'records': 1,
#  'cardboard': 1,
#  'dingy': 3,
#  'at': 53,
#  'remain': 2,
#  'torn': 3,
#  'nationwide': 1,
#  'air': 15,
#  'crystals': 2,
#  'foundin': 3,
#  'buttons': 4,
#  'cindals': 1,
#  'use': 27,
#  'snackaroo': 1,
#  'appreciates': 1,
#  'steam': 2,
#  'straightened': 1,
#  'pearls': 3,
#  'grr': 1,
#  'pure': 6,
#  'grandma': 4,
#  'hrt': 1,
#  'colorings': 2,
#  'join': 8,
#  'ool': 1,
#  'crear': 1,
#  'esteem': 2,
#  'argument': 3,
#  'odd': 3,
#  'li': 2,
#  'including': 12,
#  'fiesta': 1,
#  'entire': 23,
#  'cupcakes': 4,
#  'saw': 25,
#  'breakers': 2,
#  'character': 3,
#  'revlon': 4,
#  'yourselves': 4,
#  'allergic': 2,
#  'toacid': 1,
#  'flaked': 1,
#  'surprisingly': 3,
#  'captive': 1,
#  'excursion': 1,
#  'timeto': 1,
#  'seein': 1,
#  'mindset': 1,
#  'cottonelle': 1,
#  'tricky': 2,
#  'mostawards': 2,
#  'rolled': 1,
#  'groups': 2,
#  'flowers': 11,
#  'fabrics': 1,
#  'koala': 1,
#  'rewardson': 1,
#  'nowfor': 1,
#  'pam': 1,
#  'production': 1,
#  'tensions': 1,
#  'hos': 1,
#  'diaries': 1,
#  'overhearing': 2,
#  'skit': 1,
#  'vagine': 2,
#  'spatulas': 1,
#  'sheet': 5,
#  'swam': 1,
#  'taylor': 1,
#  'hercxxxxxxxxxxxxxxxxxxxxxxxxxxxx': 1,
#  'skills': 3,
#  'lookit': 1,
#  'associates': 1,
#  'indy': 1,
#  'electronic': 1,
#  'talking': 39,
#  'lamaze': 1,
#  'civilized': 2,
#  'technicians': 2,
#  'cuts': 1,
#  'single': 20,
#  'strays': 1,
#  'hump': 4,
#  'search': 3,
#  'ray': 4,
#  'angela': 1,
#  'representative': 1,
#  'spend': 16,
#  'dreary': 1,
#  'sometimes': 24,
#  'swing': 1,
#  'cuddle': 2,
#  'musicwith': 1,
#  'breakup': 2,
#  'leaks': 1,
#  'beginner': 1,
#  'swapped': 1,
#  'weapons': 1,
#  'comes': 30,
#  'theay': 1,
#  'inner': 5,
#  'sideways': 1,
#  'captured': 1,
#  'makeup': 20,
#  'burner': 1,
#  'hairstylist': 1,
#  'tequila': 2,
#  'gentleman': 4,
#  'shut': 25,
#  'carl': 3,
#  'metal': 1,
#  'contest': 1,
#  'inflatables': 1,
#  'mid': 2,
#  'wn': 1,
#  'iambeing': 1,
#  'lock': 5,
#  'dreaming': 2,
#  'perry': 1,
#  'breather': 1,
#  'figured': 8,
#  'download': 1,
#  'kmart': 8,
#  'helpssupport': 1,
#  'looker': 1,
#  'mean': 50,
#  'smell': 15,
#  'weekends': 1,
#  'deed': 1,
#  'osbourne': 1,
#  'chocolaty': 3,
#  'santa': 8,
#  'artist': 1,
#  'squealing': 1,
#  'bracelet': 4,
#  'awardsfrom': 1,
#  'blee': 1,
#  'cleanc': 1,
#  'ofg': 1,
#  'itching': 2,
#  'reports': 2,
#  'sweaters': 2,
#  'poms': 1,
#  'eyelid': 3,
#  'services': 3,
#  'hickies': 1,
#  'sounding': 1,
#  'handler': 1,
#  'dawg': 3,
#  'sappy': 1,
#  'canmake': 2,
#  'usand': 1,
#  'cause': 47,
#  'bunk': 1,
#  'speech': 4,
#  'weigh': 1,
#  'freaking': 14,
#  'ex': 8,
#  'doo': 1,
#  'turkey': 2,
#  'warning': 1,
#  'heady': 1,
#  'obey': 1,
#  'daughter': 15,
#  'made': 40,
#  'corporate': 1,
#  'revn': 1,
#  'fast': 20,
#  'conclusion': 3,
#  'accessories': 3,
#  'manager': 11,
#  'worldwide': 2,
#  'sitter': 2,
#  'drowning': 1,
#  'promotion': 1,
#  'upor': 1,
#  'jelly': 1,
#  'miracle': 1,
#  'yaaah': 1,
#  'belong': 1,
#  'book': 8,
#  'maseford': 1,
#  'boxers': 1,
#  'emotional': 8,
#  'cube': 2,
#  'aroundthe': 1,
#  'therapists': 1,
#  'invested': 1,
#  'finished': 9,
#  'professors': 2,
#  'rightcolor': 2,
#  'maybelline': 2,
#  'loops': 1,
#  'missionaccomplished': 1,
#  'european': 1,
#  'nurse': 4,
#  'technological': 1,
#  'sleep': 20,
#  'sweeter': 1,
#  'bagel': 1,
#  'solely': 1,
#  'grumpy': 1,
#  'wore': 1,
#  'puts': 6,
#  'every': 41,
#  'toot': 1,
#  'jew': 1,
#  'suction': 1,
#  'studio': 7,
#  'glory': 1,
#  'vulgar': 1,
#  'amazed': 1,
#  'late': 16,
#  'thestandard': 1,
#  'grinch': 1,
#  'specialist': 1,
#  'kabana': 1,
#  'erotic': 1,
#  'planted': 1,
#  'shoved': 3,
#  'bars': 1,
#  'disappointed': 8,
#  'smear': 1,
#  'nfl': 1,
#  'facultyand': 2,
#  'typically': 1,
#  'captivated': 1,
#  'areas': 4,
#  'classicbath': 1,
#  'relationship': 23,
#  'big': 46,
#  'coin': 1,
#  'thattv': 1,
#  'views': 1,
#  'dramatically': 1,
#  'leaving': 20,
#  'ago': 28,
#  'waxing': 1,
#  'balls': 11,
#  'clue': 1,
#  'sweater': 4,
#  'rmicro': 2,
#  'sup': 1,
#  'tito': 1,
#  'lauren': 6,
#  'down': 47,
#  'slash': 2,
#  'proud': 23,
#  'bothchildren': 1,
#  'bardot': 1,
#  'probably': 40,
#  'uncommon': 2,
#  'slacking': 1,
#  'constant': 3,
#  'brake': 2,
#  'wg': 1,
#  'knock': 3,
#  'lies': 1,
#  'italy': 1,
#  'may': 19,
#  'ginger': 4,
#  'anew': 1,
#  'styled': 1,
#  'decrease': 3,
#  'blow': 8,
#  'prebiotics': 2,
#  'hanged': 2,
#  'saving': 4,
#  'clearance': 1,
#  'sneak': 3,
#  'helpedover': 1,
#  'desire': 5,
#  'wirafruit': 1,
#  'naughty': 3,
#  'vegas': 14,
#  'required': 1,
#  'overwhelming': 2,
#  'cavalli': 1,
#  'window': 3,
#  'confined': 3,
#  'cott': 1,
#  'finger': 5,
#  'whip': 2,
#  'gecko': 1,
#  'dynamic': 1,
#  'bridesmaids': 3,
#  'reebok': 2,
#  'mole': 1,
#  'acted': 2,
#  'texas': 2,
#  'insecure': 4,
#  'fabu': 2,
#  'restoratives': 1,
#  'claimed': 1,
#  'becamea': 1,
#  'quickest': 1,
#  'skiers': 1,
#  'adults': 4,
#  'pepsi': 1,
#  'charm': 2,
#  'varieties': 1,
#  'jiggly': 1,
#  'maleouncer': 1,
#  'expertlycoordinated': 1,
#  'perfection': 2,
#  'decision': 19,
#  'wagon': 3,
#  'nvery': 1,
#  'oily': 1,
#  'torturous': 2,
#  'sight': 2,
#  'raw': 2,
#  'cristiano': 1,
#  'bug': 5,
#  'forgiving': 1,
#  'spread': 7,
#  'injections': 2,
#  'provider': 3,
#  'lemonade': 1,
#  'thought': 45,
#  'lifewith': 3,
#  'front': 24,
#  'glowing': 1,
#  'member': 3,
#  'cupcake': 3,
#  'mnot': 1,
#  'cigs': 1,
#  'cd': 1,
#  'lollipops': 1,
#  'ticking': 1,
#  'talkie': 1,
#  'photographs': 1,
#  'enjoyable': 1,
#  'fulfill': 1,
#  'ask': 27,
#  'cervix': 1,
#  'creature': 1,
#  'erection': 3,
#  'spell': 7,
#  'evening': 3,
#  'dermatologist': 1,
#  'disorder': 1,
#  'vaccines': 1,
#  'markets': 1,
#  'lovevalentine': 1,
#  'fair': 16,
#  'blade': 2,
#  'hosting': 11,
#  'tabloids': 3,
#  'aches': 1,
#  'governor': 3,
#  'jpmorgan': 1,
#  'yell': 10,
#  'thedid': 1,
#  'minerals': 2,
#  'hooverplatinum': 2,
#  'remarks': 1,
#  'bonding': 7,
#  'slams': 1,
#  'animals': 6,
#  'blinked': 1,
#  'trench': 1,
#  'acid': 1,
#  'exfoliates': 1,
#  'downstairs': 8,
#  'tickle': 1,
#  'unfortunately': 5,
#  'bring': 32,
#  'motion': 3,
#  'toms': 1,
#  'dig': 1,
#  'aspen': 1,
#  'spaghetti': 1,
#  'joining': 2,
#  'christmas': 7,
#  'inhuman': 1,
#  'scrapbook': 1,
#  'reaches': 1,
#  'maid': 6,
#  'yappity': 1,
#  'argue': 2,
#  'taken': 18,
#  'millions': 4,
#  'springs': 1,
#  'xpp': 1,
#  'patron': 3,
#  'st': 4,
#  'specimen': 1,
#  'announcer': 11,
#  'allits': 1,
#  'deejaying': 1,
#  'anner': 1,
#  'erasra': 1,
#  'kimberley': 1,
#  'prayer': 1,
#  'thathe': 1,
#  'whack': 1,
#  'infection': 3,
#  'drove': 3,
#  'hassling': 1,
#  'jackpot': 1,
#  'jcpenney': 1,
#  'heat': 4,
#  'bingeing': 1,
#  'overbearing': 2,
#  'resolve': 1,
#  'kenny': 3,
#  'eve': 3,
#  'nextgame': 1,
#  'plusa': 1,
#  'dude': 20,
#  'balloons': 1,
#  'barbeque': 2,
#  'bond': 5,
#  'signature': 2,
#  'gamecard': 1,
#  'became': 1,
#  'thejersey': 1,
#  'limits': 2,
#  'cultivated': 1,
#  'temporarily': 2,
#  'scrubs': 1,
#  'run': 28,
#  'drew': 1,
#  'union': 2,
#  'smashing': 1,
#  'list': 12,
#  'psycho': 12,
#  'venue': 1,
#  'perspective': 2,
#  'neighborhood': 3,
#  'squirming': 1,
#  'train': 5,
#  'disagree': 2,
#  'chocolates': 1,
#  'acne': 5,
#  'scaring': 2,
#  'animal': 5,
#  'ego': 1,
#  ...}

# %%
def build_word_episode_distribution(input_word_counts):
    """Returns a dictionary that counts how many words appear in exactly a given number of episodes
        Params: {input_word_counts: Dict}
        Returns: Dict
    """
    
    # a dictionary that counts how many words appear in exactly a given number of episodes
    word_episode_distribution = dict.fromkeys(set(input_word_counts.values()),0)

    for count in input_word_counts.values():
        word_episode_distribution[count] += 1
    return word_episode_distribution

# %%
word_episode_distribution = build_word_episode_distribution(word_episode_count)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that build_word_episode_distribution returns the correct output"""
assert word_episode_distribution[1] > 4000 and word_episode_distribution[1] < 4500
assert word_episode_distribution[3] > 700 and word_episode_distribution[3] < 800
assert word_episode_distribution[15] > 30 and word_episode_distribution[15] < 50

# %% [markdown]
# ## Question 6b (Free Response): Visualizing the distribution
#
# When working with distributions (like we're doing here), it can be helpful to *visualize* the distribution in order to get a better intuition. This can be achieved through the use of *histograms*, so in this question you will create one.
#
# Each bin of the histogram  (the *x axis*) should correspond to the *number of episodes* in which a word is mentioned, and the *y axis* should show the *number of words* in each bin.
#
# Note: Use the default matplotlib settings. You may find this tutorial helpful: https://matplotlib.org/3.0.2/tutorials/introductory/pyplot.html
#
# Create a new cell with the histogram below. Then, give an analysis of the distribution: What do you observe?

# %%
import matplotlib.pyplot as plt
plt.plot(list(word_episode_distribution.keys()), list(word_episode_distribution.values()))
plt.xlabel('number of episodes')
plt.ylabel('number of words')
plt.show()

# %% [markdown]
# ## Question 7 (Code Completion): Good Types
#
# As we have now seen, there are many *infrequent* words that occur only in one episode, and never again afterwards. When analyzing language use---for instance, if we wanted to make sense of how various characters tend to behave---we might not put too much stock in such infrequent words (maybe Kim was just having a bad day). This question deals with the step of filtering out infrequent words.
#
# In the cell below: build an alphabetically sorted list of all words that appear in more than one episode. We'll refer to these words as *good types*.

# %%
def output_good_types(input_word_counts):
    """Returns a list of good types in alphabetically sorted order
        Params: {input_word_counts: Dict}
        Returns: List
    """
    good_types = []
    for word in input_word_counts:
        if input_word_counts[word] > 1:
            good_types.append(word)
    return sorted(good_types)

# %%
good_types = output_good_types(word_episode_count)
n_good_types = len(good_types)

n_good_types
# Out:
# 4517

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that output_good_types returns the correct output"""
assert n_good_types > 4500 and n_good_types < 5000
assert good_types[0:5] == ['a','aah','ability','able','about']

# %% [markdown]
# ## Question 7b (Free Response): Good Types
#
# In the cell below answer the following: *How many good_types there are? What are the first 10 in alphabetical order?*
#
# Please write your answer in code and use Python's `print()` function, **NOT** markdown.

# %%
for i in range (0,10):
    print(good_types[i])
# Out:
# a
# aah
# ability
# able
# about
# absolute
# absolutely
# absurd
# accent
# accept

# %% [markdown]
# From now on, the use of array data structures from `numpy` is required in some places. If you've never used numpy before, it will take some time to get used to. In general, numpy is a library that you can use to handle vector/matrix/tensor operations, including creation, modification, and compositions (add, sub, mul, etc.). For example, try running the following code:

# %%
A = np.array([[1,2,3], [4,6,2]]) 
B = np.array([[1,2],[5,3],[1,1]])
print(A) #A is a 2x3 matrix
print(B) #B is a 3x2 matrix
print(A[0,2]) # Prints the value contained in the first row, third column of matrix A
print(A.dot(B)) #A.dot(B) multiplies the two matrices, producing a 2 by 2 matrix
print(np.sum(A, axis=0)) #np.sum(A, axis=0) sums along columns
print(np.sum(B, axis=1)) #np.sum(B, axis=1) sums along rows
# Out:
# [[1 2 3]
#  [4 6 2]]
# [[1 2]
#  [5 3]
#  [1 1]]
# 3
# [[14 11]
#  [36 28]]
# [5 8 5]
# [3 8 2]

# %% [markdown]
# You're welcome to find your own resources to learn more about numpy (there are lots of them) but one good introduction is [Justin Johnson's writeup](http://cs231n.github.io/python-numpy-tutorial/#numpy).
#
# We will be using vectors and arrays with *n_good_types* columns, such that each good type corresponds to a column, in alphabetical order.

# %% [markdown]
# ## Question 8 (Code Completion): Word Frequencies
#
# Previously, we characterized words according to how many episodes they appeared in. For this question, we will take a different approach: computing the rate (or *frequency*) at which a word appears across the entire corpus (note: a corpus is a collection of written texts, in this case the transcripts of a reality TV show).
#
# In the cell below, complete the function to *find the word frequency of all "good types"* in descending order.
#
# For this question only, **round your solution to 5 decimals**.
#
# What can we say about the most frequently used words? Briefly consider, would you expect to find the same ordering of frequent words in, say, the NY Times?

# %%
def create_ranked_good_types(tokenize_method,tokenize_transcript_method,input_transcripts,input_good_types):
    """Returns a list of good types in reverse sorted order in the form:
        [(word_1,word_frequency_1),
        ...
        (word_10,word_frequency_10)]
        Params: {tokenize_method: Function (a -> b),
                 // Note: Below type means a function that takes two arguments, the first of which is a function.
                 tokenize_transcript_method: Function ((Function(a -> b), c) -> d),
                 input_transcripts: Tuple List,
                 input_good_types: List}
        Returns: List
    """
    word_frequency = dict.fromkeys(input_good_types,0)

    # total number of corpus
    total_num = 0

    for transcript in input_transcripts:
        tokens = tokenize_transcript_method(tokenize_method,transcript)
        for token in tokens:
            total_num += 1
            if token in word_frequency:
                word_frequency[token] += 1
    


    # calculate the frequency of each word
    for word in word_frequency:
        word_frequency[word] = round(word_frequency[word]/total_num,5)

    # sort the word_frequency in reverse order
    ranked_good_types = sorted(word_frequency.items(), key=lambda x: x[1], reverse=True)



    return ranked_good_types

# %%
ranked_frequencies = create_ranked_good_types(tokenize,tokenize_transcript,deduped_transcripts,good_types)

# %%
ranked_frequencies
# Out:
# [('i', 0.04858),
#  ('you', 0.03797),
#  ('to', 0.03056),
#  ('s', 0.02312),
#  ('the', 0.02148),
#  ('and', 0.02085),
#  ('a', 0.01907),
#  ('it', 0.01785),
#  ('that', 0.01528),
#  ('t', 0.01248),
#  ('like', 0.01142),
#  ('m', 0.01108),
#  ('this', 0.01069),
#  ('is', 0.01063),
#  ('my', 0.00976),
#  ('just', 0.00952),
#  ('of', 0.00909),
#  ('we', 0.00875),
#  ('so', 0.00861),
#  ('what', 0.0085),
#  ('in', 0.00835),
#  ('me', 0.00798),
#  ('re', 0.00794),
#  ('have', 0.00788),
#  ('do', 0.00713),
#  ('for', 0.00681),
#  ('don', 0.00669),
#  ('know', 0.00668),
#  ('with', 0.00658),
#  ('not', 0.00657),
#  ('are', 0.00628),
#  ('be', 0.00626),
#  ('on', 0.00622),
#  ('she', 0.00607),
#  ('get', 0.00564),
#  ('go', 0.00551),
#  ('really', 0.00528),
#  ('all', 0.00527),
#  ('your', 0.0051),
#  ('going', 0.00493),
#  ('no', 0.00493),
#  ('want', 0.00492),
#  ('her', 0.00481),
#  ('he', 0.0046),
#  ('can', 0.00454),
#  ('but', 0.00411),
#  ('up', 0.00402),
#  ('out', 0.00397),
#  ('here', 0.0039),
#  ('think', 0.00383),
#  ('was', 0.00374),
#  ('right', 0.00368),
#  ('okay', 0.00361),
#  ('there', 0.00355),
#  ('oh', 0.00354),
#  ('about', 0.00348),
#  ('if', 0.00343),
#  ('yeah', 0.00342),
#  ('how', 0.00339),
#  ('at', 0.00337),
#  ('gonna', 0.00333),
#  ('they', 0.00325),
#  ('khloe', 0.00298),
#  ('got', 0.00295),
#  ('kim', 0.00283),
#  ('ll', 0.00279),
#  ('now', 0.00274),
#  ('one', 0.00273),
#  ('when', 0.00267),
#  ('good', 0.00266),
#  ('little', 0.00266),
#  ('guys', 0.00259),
#  ('love', 0.00253),
#  ('come', 0.00249),
#  ('ve', 0.00247),
#  ('need', 0.00239),
#  ('him', 0.00232),
#  ('mom', 0.00227),
#  ('see', 0.00224),
#  ('would', 0.00222),
#  ('time', 0.00211),
#  ('let', 0.00204),
#  ('back', 0.00196),
#  ('doing', 0.00193),
#  ('look', 0.00191),
#  ('as', 0.0019),
#  ('feel', 0.0019),
#  ('from', 0.00189),
#  ('mean', 0.00189),
#  ('hey', 0.00188),
#  ('an', 0.00184),
#  ('why', 0.00177),
#  ('new', 0.00172),
#  ('take', 0.00171),
#  ('well', 0.00167),
#  ('did', 0.00166),
#  ('or', 0.00166),
#  ('because', 0.00163),
#  ('hi', 0.00163),
#  ('more', 0.00161),
#  ('who', 0.00161),
#  ('us', 0.00158),
#  ('make', 0.00157),
#  ('kourtney', 0.00155),
#  ('rob', 0.00155),
#  ('been', 0.00154),
#  ('much', 0.00154),
#  ('has', 0.00149),
#  ('over', 0.00147),
#  ('way', 0.00147),
#  ('bruce', 0.00144),
#  ('scott', 0.00144),
#  ('where', 0.00139),
#  ('god', 0.00138),
#  ('our', 0.00137),
#  ('even', 0.00135),
#  ('something', 0.00132),
#  ('these', 0.00132),
#  ('thing', 0.00131),
#  ('some', 0.00128),
#  ('tell', 0.00128),
#  ('could', 0.00126),
#  ('will', 0.00126),
#  ('day', 0.00122),
#  ('life', 0.00121),
#  ('then', 0.0012),
#  ('down', 0.00118),
#  ('had', 0.00118),
#  ('off', 0.00116),
#  ('them', 0.00116),
#  ('say', 0.00113),
#  ('should', 0.00112),
#  ('give', 0.0011),
#  ('cause', 0.00107),
#  ('never', 0.00106),
#  ('kind', 0.00105),
#  ('getting', 0.00103),
#  ('his', 0.00102),
#  ('people', 0.00102),
#  ('were', 0.00102),
#  ('baby', 0.001),
#  ('too', 0.001),
#  ('always', 0.00098),
#  ('family', 0.00098),
#  ('nice', 0.00098),
#  ('thank', 0.00098),
#  ('by', 0.00097),
#  ('stop', 0.00097),
#  ('am', 0.00094),
#  ('very', 0.00094),
#  ('wait', 0.00093),
#  ('didn', 0.00092),
#  ('great', 0.00092),
#  ('talk', 0.00092),
#  ('york', 0.00092),
#  ('fun', 0.0009),
#  ('call', 0.00087),
#  ('done', 0.00087),
#  ('first', 0.00086),
#  ('only', 0.00086),
#  ('yes', 0.00086),
#  ('does', 0.00084),
#  ('doesn', 0.00084),
#  ('honey', 0.00084),
#  ('things', 0.00084),
#  ('two', 0.00084),
#  ('being', 0.00083),
#  ('put', 0.00083),
#  ('trying', 0.00083),
#  ('uh', 0.00083),
#  ('guy', 0.00082),
#  ('lamar', 0.00082),
#  ('house', 0.00081),
#  ('into', 0.00079),
#  ('room', 0.00079),
#  ('girls', 0.00078),
#  ('everything', 0.00077),
#  ('d', 0.00076),
#  ('sure', 0.00076),
#  ('actually', 0.00075),
#  ('help', 0.00074),
#  ('someone', 0.00074),
#  ('than', 0.00074),
#  ('together', 0.00074),
#  ('work', 0.00074),
#  ('bad', 0.00073),
#  ('bye', 0.00073),
#  ('lot', 0.00073),
#  ('um', 0.00073),
#  ('anything', 0.00072),
#  ('other', 0.00072),
#  ('dress', 0.0007),
#  ('every', 0.0007),
#  ('maybe', 0.0007),
#  ('home', 0.00068),
#  ('married', 0.00068),
#  ('wedding', 0.00068),
#  ('whole', 0.00067),
#  ('any', 0.00066),
#  ('ever', 0.00066),
#  ('night', 0.00066),
#  ('old', 0.00066),
#  ('said', 0.00066),
#  ('around', 0.00065),
#  ('before', 0.00064),
#  ('having', 0.00064),
#  ('hello', 0.00064),
#  ('care', 0.00063),
#  ('excited', 0.00062),
#  ('happy', 0.00062),
#  ('years', 0.00062),
#  ('definitely', 0.00061),
#  ('better', 0.0006),
#  ('big', 0.0006),
#  ('crazy', 0.0006),
#  ('everyone', 0.0006),
#  ('thought', 0.0006),
#  ('today', 0.0006),
#  ('best', 0.00058),
#  ('sorry', 0.00058),
#  ('their', 0.00058),
#  ('adrienne', 0.00056),
#  ('coming', 0.00056),
#  ('find', 0.00056),
#  ('meet', 0.00056),
#  ('last', 0.00055),
#  ('ready', 0.00055),
#  ('show', 0.00055),
#  ('store', 0.00055),
#  ('those', 0.00055),
#  ('wanted', 0.00055),
#  ('problem', 0.00054),
#  ('stuff', 0.00053),
#  ('away', 0.00052),
#  ('else', 0.00052),
#  ('please', 0.00052),
#  ('start', 0.00052),
#  ('talking', 0.00052),
#  ('cute', 0.00051),
#  ('wrong', 0.0005),
#  ('bit', 0.00049),
#  ('car', 0.00049),
#  ('keep', 0.00049),
#  ('kris', 0.00049),
#  ('kylie', 0.00049),
#  ('own', 0.00049),
#  ('try', 0.00049),
#  ('wants', 0.00049),
#  ('such', 0.00048),
#  ('again', 0.00047),
#  ('amazing', 0.00047),
#  ('deal', 0.00047),
#  ('job', 0.00047),
#  ('leave', 0.00047),
#  ('looks', 0.00047),
#  ('made', 0.00047),
#  ('makes', 0.00047),
#  ('man', 0.00047),
#  ('three', 0.00047),
#  ('through', 0.00047),
#  ('after', 0.00046),
#  ('dad', 0.00046),
#  ('long', 0.00046),
#  ('face', 0.00045),
#  ('fine', 0.00045),
#  ('hard', 0.00045),
#  ('hurt', 0.00045),
#  ('idea', 0.00045),
#  ('isn', 0.00045),
#  ('making', 0.00045),
#  ('nothing', 0.00044),
#  ('date', 0.00043),
#  ('everybody', 0.00043),
#  ('hmm', 0.00043),
#  ('next', 0.00043),
#  ('real', 0.00043),
#  ('seriously', 0.00043),
#  ('few', 0.00042),
#  ('girl', 0.00042),
#  ('kendall', 0.00042),
#  ('mm', 0.00042),
#  ('needs', 0.00042),
#  ('tonight', 0.00042),
#  ('totally', 0.00041),
#  ('days', 0.0004),
#  ('eat', 0.0004),
#  ('hold', 0.0004),
#  ('kids', 0.0004),
#  ('money', 0.0004),
#  ('place', 0.0004),
#  ('pregnant', 0.0004),
#  ('probably', 0.0004),
#  ('same', 0.0004),
#  ('sisters', 0.0004),
#  ('told', 0.0004),
#  ('dinner', 0.00039),
#  ('perfect', 0.00039),
#  ('won', 0.00039),
#  ('believe', 0.00038),
#  ('called', 0.00038),
#  ('dog', 0.00038),
#  ('email', 0.00038),
#  ('haven', 0.00038),
#  ('party', 0.00038),
#  ('reggie', 0.00038),
#  ('still', 0.00038),
#  ('beautiful', 0.00037),
#  ('each', 0.00037),
#  ('hair', 0.00037),
#  ('myself', 0.00037),
#  ('sex', 0.00037),
#  ('year', 0.00037),
#  ('access', 0.00036),
#  ('anymore', 0.00036),
#  ('hear', 0.00036),
#  ('support', 0.00036),
#  ('went', 0.00036),
#  ('clean', 0.00035),
#  ('kourt', 0.00035),
#  ('move', 0.00035),
#  ('person', 0.00035),
#  ('saying', 0.00035),
#  ('set', 0.00035),
#  ('thanks', 0.00035),
#  ('wear', 0.00035),
#  ('wgbh', 0.00035),
#  ('cool', 0.00034),
#  ('five', 0.00034),
#  ('looking', 0.00034),
#  ('many', 0.00034),
#  ('pretty', 0.00034),
#  ('since', 0.00034),
#  ('sister', 0.00034),
#  ('stay', 0.00034),
#  ('whatever', 0.00034),
#  ('already', 0.00033),
#  ('another', 0.00033),
#  ('funny', 0.00033),
#  ('phone', 0.00033),
#  ('second', 0.00033),
#  ('shopping', 0.00033),
#  ('birthday', 0.00032),
#  ('bring', 0.00032),
#  ('enough', 0.00032),
#  ('friends', 0.00032),
#  ('hotel', 0.00032),
#  ('live', 0.00032),
#  ('says', 0.00032),
#  ('taking', 0.00032),
#  ('which', 0.00032),
#  ('different', 0.00031),
#  ('doctor', 0.00031),
#  ('friend', 0.00031),
#  ('game', 0.00031),
#  ('gets', 0.00031),
#  ('kardashian', 0.00031),
#  ('nervous', 0.00031),
#  ('ring', 0.00031),
#  ('somebody', 0.00031),
#  ('supposed', 0.00031),
#  ('watch', 0.00031),
#  ('ask', 0.0003),
#  ('comes', 0.0003),
#  ('fight', 0.0003),
#  ('honestly', 0.0003),
#  ('minutes', 0.0003),
#  ('most', 0.0003),
#  ('play', 0.0003),
#  ('shoot', 0.0003),
#  ('sit', 0.0003),
#  ('use', 0.0003),
#  ('weird', 0.0003),
#  ('welcome', 0.0003),
#  ('yourself', 0.0003),
#  ('also', 0.00029),
#  ('hit', 0.00029),
#  ('hope', 0.00029),
#  ('matter', 0.00029),
#  ('met', 0.00029),
#  ('mind', 0.00029),
#  ('miss', 0.00029),
#  ('point', 0.00029),
#  ('relationship', 0.00029),
#  ('robert', 0.00029),
#  ('thinking', 0.00029),
#  ('walk', 0.00029),
#  ('whoo', 0.00029),
#  ('working', 0.00029),
#  ('business', 0.00028),
#  ('cannot', 0.00028),
#  ('seen', 0.00028),
#  ('serious', 0.00028),
#  ('came', 0.00027),
#  ('card', 0.00027),
#  ('easy', 0.00027),
#  ('might', 0.00027),
#  ('morning', 0.00027),
#  ('telling', 0.00027),
#  ('wasn', 0.00027),
#  ('week', 0.00027),
#  ('ass', 0.00026),
#  ('brother', 0.00026),
#  ('eyes', 0.00026),
#  ('happen', 0.00026),
#  ('later', 0.00026),
#  ('obviously', 0.00026),
#  ('bitch', 0.00025),
#  ('comfortable', 0.00025),
#  ('dating', 0.00025),
#  ('goes', 0.00025),
#  ('gotta', 0.00025),
#  ('knew', 0.00025),
#  ('left', 0.00025),
#  ('rather', 0.00025),
#  ('though', 0.00025),
#  ('used', 0.00025),
#  ('wouldn', 0.00025),
#  ('ago', 0.00024),
#  ('dash', 0.00024),
#  ('listen', 0.00024),
#  ('meeting', 0.00024),
#  ('open', 0.00024),
#  ('rude', 0.00024),
#  ('situation', 0.00024),
#  ('tomorrow', 0.00024),
#  ('afraid', 0.00023),
#  ('agree', 0.00023),
#  ('control', 0.00023),
#  ('couple', 0.00023),
#  ('front', 0.00023),
#  ('gone', 0.00023),
#  ('hell', 0.00023),
#  ('jonathan', 0.00023),
#  ('kidding', 0.00023),
#  ('learn', 0.00023),
#  ('months', 0.00023),
#  ('ooh', 0.00023),
#  ('school', 0.00023),
#  ('shut', 0.00023),
#  ('sick', 0.00023),
#  ('took', 0.00023),
#  ('while', 0.00023),
#  ('yay', 0.00023),
#  ('close', 0.00022),
#  ('engaged', 0.00022),
#  ('four', 0.00022),
#  ('guess', 0.00022),
#  ('hate', 0.00022),
#  ('kardashians', 0.00022),
#  ('l', 0.00022),
#  ('mad', 0.00022),
#  ('may', 0.00022),
#  ('media', 0.00022),
#  ('miami', 0.00022),
#  ('mother', 0.00022),
#  ('name', 0.00022),
#  ('single', 0.00022),
#  ('sitting', 0.00022),
#  ('skin', 0.00022),
#  ('wearing', 0.00022),
#  ('wife', 0.00022),
#  ('able', 0.00021),
#  ('drink', 0.00021),
#  ('exactly', 0.00021),
#  ('feeling', 0.00021),
#  ('hours', 0.00021),
#  ('makeup', 0.00021),
#  ('once', 0.00021),
#  ('pictures', 0.00021),
#  ('promise', 0.00021),
#  ('shorty', 0.00021),
#  ('times', 0.00021),
#  ('almost', 0.0002),
#  ('asked', 0.0002),
#  ('body', 0.0002),
#  ('buy', 0.0002),
#  ('change', 0.0002),
#  ('class', 0.0002),
#  ('especially', 0.0002),
#  ('hand', 0.0002),
#  ('huge', 0.0002),
#  ('important', 0.0002),
#  ('line', 0.0002),
#  ('literally', 0.0002),
#  ('living', 0.0002),
#  ('lose', 0.0002),
#  ('org', 0.0002),
#  ('remember', 0.0002),
#  ('run', 0.0002),
#  ('shouldn', 0.0002),
#  ('side', 0.0002),
#  ('understand', 0.0002),
#  ('until', 0.0002),
#  ('alone', 0.00019),
#  ('black', 0.00019),
#  ('boyfriend', 0.00019),
#  ('chance', 0.00019),
#  ('door', 0.00019),
#  ('em', 0.00019),
#  ('fur', 0.00019),
#  ('group', 0.00019),
#  ('happened', 0.00019),
#  ('heart', 0.00019),
#  ('month', 0.00019),
#  ('naked', 0.00019),
#  ('proud', 0.00019),
#  ('started', 0.00019),
#  ('starting', 0.00019),
#  ('test', 0.00019),
#  ('throw', 0.00019),
#  ('under', 0.00019),
#  ('vegas', 0.00019),
#  ('world', 0.00019),
#  ('biggest', 0.00018),
#  ('embarrassing', 0.00018),
#  ('ew', 0.00018),
#  ('far', 0.00018),
#  ('finally', 0.00018),
#  ('found', 0.00018),
#  ('hot', 0.00018),
#  ('hug', 0.00018),
#  ('kid', 0.00018),
#  ('knows', 0.00018),
#  ('manager', 0.00018),
#  ('normal', 0.00018),
#  ('part', 0.00018),
#  ('realize', 0.00018),
#  ('stupid', 0.00018),
#  ('trip', 0.00018),
#  ('wish', 0.00018),
#  ('wow', 0.00018),
#  ('absolutely', 0.00017),
#  ('anyone', 0.00017),
#  ('bed', 0.00017),
#  ('both', 0.00017),
#  ('course', 0.00017),
#  ('eye', 0.00017),
#  ('father', 0.00017),
#  ('feelings', 0.00017),
#  ('feels', 0.00017),
#  ('gives', 0.00017),
#  ('hang', 0.00017),
#  ('happens', 0.00017),
#  ('head', 0.00017),
#  ('joke', 0.00017),
#  ('malika', 0.00017),
#  ('means', 0.00017),
#  ('office', 0.00017),
#  ('ow', 0.00017),
#  ('peta', 0.00017),
#  ('photo', 0.00017),
#  ('picture', 0.00017),
#  ('shot', 0.00017),
#  ('six', 0.00017),
#  ('soon', 0.00017),
#  ('spend', 0.00017),
#  ('true', 0.00017),
#  ('without', 0.00017),
#  ('worry', 0.00017),
#  ('yet', 0.00017),
#  ('acting', 0.00016),
#  ('calling', 0.00016),
#  ('charity', 0.00016),
#  ('clothes', 0.00016),
#  ('com', 0.00016),
#  ('crying', 0.00016),
#  ('decided', 0.00016),
#  ('drive', 0.00016),
#  ('dude', 0.00016),
#  ('end', 0.00016),
#  ('figure', 0.00016),
#  ('forever', 0.00016),
#  ('gorgeous', 0.00016),
#  ('heard', 0.00016),
#  ('khlo', 0.00016),
#  ('least', 0.00016),
#  ('push', 0.00016),
#  ('rest', 0.00016),
#  ('ridiculous', 0.00016),
#  ('saw', 0.00016),
#  ('scared', 0.00016),
#  ('shoes', 0.00016),
#  ('sometimes', 0.00016),
#  ('space', 0.00016),
#  ('ten', 0.00016),
#  ('top', 0.00016),
#  ('turn', 0.00016),
#  ('upset', 0.00016),
#  ('aisle', 0.00015),
#  ('annoying', 0.00015),
#  ('answer', 0.00015),
#  ('boy', 0.00015),
#  ('brought', 0.00015),
#  ('check', 0.00015),
#  ('disgusting', 0.00015),
#  ('doll', 0.00015),
#  ('food', 0.00015),
#  ('grow', 0.00015),
#  ('high', 0.00015),
#  ('husband', 0.00015),
#  ('inside', 0.00015),
#  ('kill', 0.00015),
#  ('kiss', 0.00015),
#  ('mason', 0.00015),
#  ('mess', 0.00015),
#  ('minute', 0.00015),
#  ('mouth', 0.00015),
#  ('pick', 0.00015),
#  ('possible', 0.00015),
#  ('princess', 0.00015),
#  ('sexy', 0.00015),
#  ('shower', 0.00015),
#  ('step', 0.00015),
#  ('sweet', 0.00015),
#  ('walking', 0.00015),
#  ('watching', 0.00015),
#  ('whoa', 0.00015),
#  ('woman', 0.00015),
#  ('anger', 0.00014),
#  ('anybody', 0.00014),
#  ('between', 0.00014),
#  ('birth', 0.00014),
#  ('bunim', 0.00014),
#  ('captioned', 0.00014),
#  ('captioning', 0.00014),
#  ('child', 0.00014),
#  ('color', 0.00014),
#  ('credit', 0.00014),
#  ('daughter', 0.00014),
#  ('decision', 0.00014),
#  ('dream', 0.00014),
#  ('enjoy', 0.00014),
#  ('fast', 0.00014),
#  ('free', 0.00014),
#  ('g', 0.00014),
#  ('garage', 0.00014),
#  ('huh', 0.00014),
#  ('jealous', 0.00014),
#  ('jenner', 0.00014),
#  ('kendal', 0.00014),
#  ('late', 0.00014),
#  ('lunch', 0.00014),
#  ('miles', 0.00014),
#  ('murray', 0.00014),
#  ('plus', 0.00014),
#  ('pounds', 0.00014),
#  ('productions', 0.00014),
#  ('reason', 0.00014),
#  ('sad', 0.00014),
#  ('sleep', 0.00014),
#  ('smart', 0.00014),
#  ('special', 0.00014),
#  ('sponsored', 0.00014),
#  ('stick', 0.00014),
#  ('team', 0.00014),
#  ('tired', 0.00014),
#  ('touch', 0.00014),
#  ('trust', 0.00014),
#  ('water', 0.00014),
#  ('weeks', 0.00014),
#  ('armenian', 0.00013),
#  ('atm', 0.00013),
#  ('babe', 0.00013),
#  ('broke', 0.00013),
#  ('coffee', 0.00013),
#  ('college', 0.00013),
#  ('completely', 0.00013),
#  ('cut', 0.00013),
#  ('either', 0.00013),
#  ('entire', 0.00013),
#  ('extra', 0.00013),
#  ('fighting', 0.00013),
#  ('gave', 0.00013),
#  ('girlfriend', 0.00013),
#  ('glad', 0.00013),
#  ('gosh', 0.00013),
#  ('half', 0.00013),
#  ('known', 0.00013),
#  ('leaving', 0.00013),
#  ('lost', 0.00013),
#  ('moment', 0.00013),
#  ('news', 0.00013),
#  ('onkeeping', 0.00013),
#  ('prove', 0.00013),
#  ('red', 0.00013),
#  ('respect', 0.00013),
#  ('shengo', 0.00013),
#  ('surprise', 0.00013),
#  ('suzy', 0.00013),
#  ('taken', 0.00013),
#  ('teach', 0.00013),
#  ('thinks', 0.00013),
#  ('turning', 0.00013),
#  ('young', 0.00013),
#  ('airport', 0.00012),
#  ('asking', 0.00012),
#  ('beat', 0.00012),
#  ('boys', 0.00012),
#  ('buddy', 0.00012),
#  ('cry', 0.00012),
#  ('daddy', 0.00012),
#  ('experience', 0.00012),
#  ('felt', 0.00012),
#  ('forward', 0.00012),
#  ('handle', 0.00012),
#  ('kimmy', 0.00012),
#  ('lives', 0.00012),
#  ('loves', 0.00012),
#  ('major', 0.00012),
#  ('mine', 0.00012),
#  ('number', 0.00012),
#  ('ones', 0.00012),
#  ('pay', 0.00012),
#  ('perfume', 0.00012),
#  ('seems', 0.00012),
#  ('sign', 0.00012),
#  ('son', 0.00012),
#  ('sucks', 0.00012),
#  ('voice', 0.00012),
#  ('ya', 0.00012),
#  ('yo', 0.00012),
#  ('appreciate', 0.00011),
#  ('aren', 0.00011),
#  ('awkward', 0.00011),
#  ('bathroom', 0.00011),
#  ('behind', 0.00011),
#  ('brand', 0.00011),
#  ('cream', 0.00011),
#  ('eating', 0.00011),
#  ('exciting', 0.00011),
#  ('excuse', 0.00011),
#  ('fact', 0.00011),
#  ('favorite', 0.00011),
#  ('flowers', 0.00011),
#  ('games', 0.00011),
#  ('giving', 0.00011),
#  ('hands', 0.00011),
#  ('healthy', 0.00011),
#  ('kick', 0.00011),
#  ('lie', 0.00011),
#  ('moving', 0.00011),
#  ('must', 0.00011),
#  ('nine', 0.00011),
#  ('nobody', 0.00011),
#  ('nude', 0.00011),
#  ('outside', 0.00011),
#  ('pregnancy', 0.00011),
#  ('price', 0.00011),
#  ('problems', 0.00011),
#  ('questions', 0.00011),
#  ('results', 0.00011),
#  ('running', 0.00011),
#  ('save', 0.00011),
#  ('seven', 0.00011),
#  ('shop', 0.00011),
#  ('sounds', 0.00011),
#  ('stand', 0.00011),
#  ('tickets', 0.00011),
#  ('tough', 0.00011),
#  ('wine', 0.00011),
#  ('women', 0.00011),
#  ('ah', 0.0001),
#  ('air', 0.0001),
#  ('allowed', 0.0001),
#  ('animals', 0.0001),
#  ('b', 0.0001),
#  ('bachelorette', 0.0001),
#  ('balls', 0.0001),
#  ('beach', 0.0001),
#  ('bentley', 0.0001),
#  ('box', 0.0001),
#  ('break', 0.0001),
#  ('butt', 0.0001),
#  ('calm', 0.0001),
#  ('campaign', 0.0001),
#  ('chicken', 0.0001),
#  ('complete', 0.0001),
#  ('conversation', 0.0001),
#  ('cover', 0.0001),
#  ('decide', 0.0001),
#  ('diaper', 0.0001),
#  ('die', 0.0001),
#  ('dressed', 0.0001),
#  ('everywhere', 0.0001),
#  ('fabulous', 0.0001),
#  ('fault', 0.0001),
#  ('fit', 0.0001),
#  ('fresh', 0.0001),
#  ('herself', 0.0001),
#  ('holding', 0.0001),
#  ('homeless', 0.0001),
#  ('kelly', 0.0001),
#  ('ladies', 0.0001),
#  ('mail', 0.0001),
#  ('management', 0.0001),
#  ('model', 0.0001),
#  ('mood', 0.0001),
#  ('movie', 0.0001),
#  ('parents', 0.0001),
#  ('period', 0.0001),
#  ('plan', 0.0001),
#  ('pull', 0.0001),
#  ('relax', 0.0001),
#  ('road', 0.0001),
#  ('scream', 0.0001),
#  ('season', 0.0001),
#  ('site', 0.0001),
#  ('ta', 0.0001),
#  ('talked', 0.0001),
#  ('throwing', 0.0001),
#  ('tried', 0.0001),
#  ('tush', 0.0001),
#  ('video', 0.0001),
#  ('waiting', 0.0001),
#  ('worried', 0.0001),
#  ('act', 9e-05),
#  ('along', 9e-05),
#  ('anyway', 9e-05),
#  ('apartment', 9e-05),
#  ('apologize', 9e-05),
#  ('attitude', 9e-05),
#  ('aw', 9e-05),
#  ('basically', 9e-05),
#  ('bigger', 9e-05),
#  ('blood', 9e-05),
#  ('bringing', 9e-05),
#  ('bush', 9e-05),
#  ('cane', 9e-05),
#  ('cares', 9e-05),
#  ('children', 9e-05),
#  ('clear', 9e-05),
#  ('club', 9e-05),
#  ('cold', 9e-05),
#  ('cookies', 9e-05),
#  ('couldn', 9e-05),
#  ('dance', 9e-05),
#  ('diamond', 9e-05),
#  ('drama', 9e-05),
#  ('driving', 9e-05),
#  ('drunk', 9e-05),
#  ('e', 9e-05),
#  ('event', 9e-05),
#  ('fall', 9e-05),
#  ('fashion', 9e-05),
#  ('fbi', 9e-05),
#  ('feet', 9e-05),
#  ('freak', 9e-05),
#  ('full', 9e-05),
#  ('happening', 9e-05),
#  ('hat', 9e-05),
#  ('helping', 9e-05),
#  ('honest', 9e-05),
#  ('hour', 9e-05),
#  ('jail', 9e-05),
#  ('keeping', 9e-05),
#  ('kimberly', 9e-05),
#  ('kitchen', 9e-05),
#  ('kmart', 9e-05),
#  ('lauren', 9e-05),
#  ('light', 9e-05),
#  ('lying', 9e-05),
#  ('middle', 9e-05),
#  ('missed', 9e-05),
#  ('modeling', 9e-05),
#  ('movies', 9e-05),
#  ('nuts', 9e-05),
#  ('opportunity', 9e-05),
#  ('order', 9e-05),
#  ('past', 9e-05),
#  ('penis', 9e-05),
#  ('picking', 9e-05),
#  ('piece', 9e-05),
#  ('pills', 9e-05),
#  ('pressure', 9e-05),
#  ('question', 9e-05),
#  ('rock', 9e-05),
#  ('security', 9e-05),
#  ('seeing', 9e-05),
#  ('self', 9e-05),
#  ('share', 9e-05),
#  ('shirt', 9e-05),
#  ('sleeping', 9e-05),
#  ('speak', 9e-05),
#  ('spending', 9e-05),
#  ('standing', 9e-05),
#  ('star', 9e-05),
#  ('straight', 9e-05),
#  ('suck', 9e-05),
#  ('surgery', 9e-05),
#  ('swear', 9e-05),
#  ('takes', 9e-05),
#  ('tape', 9e-05),
#  ('treat', 9e-05),
#  ('wash', 9e-05),
#  ('web', 9e-05),
#  ('white', 9e-05),
#  ('word', 9e-05),
#  ('addiction', 8e-05),
#  ('agreed', 8e-05),
#  ('ahead', 8e-05),
#  ('announcer', 8e-05),
#  ('apart', 8e-05),
#  ('attention', 8e-05),
#  ('awful', 8e-05),
#  ('bar', 8e-05),
#  ('bible', 8e-05),
#  ('boxes', 8e-05),
#  ('breakfast', 8e-05),
#  ('breast', 8e-05),
#  ('bucks', 8e-05),
#  ('busy', 8e-05),
#  ('buying', 8e-05),
#  ('case', 8e-05),
#  ('city', 8e-05),
#  ('classes', 8e-05),
#  ('cleaning', 8e-05),
#  ('death', 8e-05),
#  ('dry', 8e-05),
#  ('energy', 8e-05),
#  ('engagement', 8e-05),
#  ('erika', 8e-05),
#  ('fair', 8e-05),
#  ('fat', 8e-05),
#  ('floor', 8e-05),
#  ('forget', 8e-05),
#  ('gabbana', 8e-05),
#  ('golf', 8e-05),
#  ('grab', 8e-05),
#  ('guarantee', 8e-05),
#  ('hiding', 8e-05),
#  ('himself', 8e-05),
#  ('hurry', 8e-05),
#  ('hurts', 8e-05),
#  ('information', 8e-05),
#  ('its', 8e-05),
#  ('joking', 8e-05),
#  ('laker', 8e-05),
#  ('legs', 8e-05),
#  ('letting', 8e-05),
#  ('longer', 8e-05),
#  ('looked', 8e-05),
#  ('meant', 8e-05),
#  ('moved', 8e-05),
#  ('music', 8e-05),
#  ('natural', 8e-05),
#  ('necessary', 8e-05),
#  ('needed', 8e-05),
#  ('none', 8e-05),
#  ('older', 8e-05),
#  ('passed', 8e-05),
#  ('pee', 8e-05),
#  ('periods', 8e-05),
#  ('pill', 8e-05),
#  ('pool', 8e-05),
#  ('reading', 8e-05),
#  ('ruin', 8e-05),
#  ('rules', 8e-05),
#  ('sees', 8e-05),
#  ('shine', 8e-05),
#  ('simon', 8e-05),
#  ('snack', 8e-05),
#  ('spent', 8e-05),
#  ('staying', 8e-05),
#  ('story', 8e-05),
#  ('strong', 8e-05),
#  ('super', 8e-05),
#  ('taste', 8e-05),
#  ('tells', 8e-05),
#  ('th', 8e-05),
#  ('town', 8e-05),
#  ('uncomfortable', 8e-05),
#  ('usually', 8e-05),
#  ('weekend', 8e-05),
#  ('weren', 8e-05),
#  ('whenever', 8e-05),
#  ('wind', 8e-05),
#  ('wonderful', 8e-05),
#  ('woo', 8e-05),
#  ('words', 8e-05),
#  ('works', 8e-05),
#  ('yell', 8e-05),
#  ('yelling', 8e-05),
#  ('younger', 8e-05),
#  ('yours', 8e-05),
#  ('active', 7e-05),
#  ('age', 7e-05),
#  ('angry', 7e-05),
#  ('anxious', 7e-05),
#  ('apparently', 7e-05),
#  ('bag', 7e-05),
#  ('basketball', 7e-05),
#  ('boob', 7e-05),
#  ('book', 7e-05),
#  ('bought', 7e-05),
#  ('calendar', 7e-05),
#  ('calls', 7e-05),
#  ('carmen', 7e-05),
#  ('catch', 7e-05),
#  ('celebrity', 7e-05),
#  ('chickens', 7e-05),
#  ...]

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that create_ranked_good_types returns the correct output"""
words_only = [word for word, freq in ranked_frequencies]
frequencies_only = np.array([freq for word, freq in ranked_frequencies])
assert words_only[0:2] == ['i','you']
assert np.isclose(frequencies_only[0:2], 
            np.array([0.04858, 0.03797]), atol=1e-3).all()

# %% [markdown]
# Note: the autograder uses some additional numpy utility functions. You don't need to be familiar with these right now, but in case you are curious:
#
# - `np.isclose` is a useful function for comparing floats, that gets around the problem of floating-point imprecision;
# - `.all()` is True whenever all the entries of a boolean array are True.

# %% [markdown]
# ## Characterizing characters' language
#
# Moving on, we will only be considering a subset of characters, arguably the most important ones.

# %%
good_speakers = [u'BRUCE',
                 u'JONATHAN',
                 u'KHLOE',
                 u'KIM',
                 u'KOURTNEY',
                 u'KRIS',
                 u'ROBERT',
                 u'SCOTT']

n_speakers = len(good_speakers)

# %% [markdown]
# ## Question 9 (Code Completion): Character Word Occurrences
#
# In the cell below you will be asked to determine *how often each word is said by each character*.
#
# This function **requires** you to return a numpy array of shape `n_speakers` rows by `n_good_types` columns, such that the entry `(i,j)` indicates how many times speaker i says word j. **You will lose points if you do not use numpy!**

# %%
deduped_transcripts[0][1]
# Out:
# [{'timestamp': '00:00:23',
#   'speaker': 'KHLOE',
#   'text': "You don't have your own credit card?"},
#  {'timestamp': '00:00:25',
#   'speaker': 'BRUCE',
#   'text': "I don't even have a credit card."},
#  {'timestamp': '00:00:26', 'speaker': 'BRUCE', 'text': 'I know.'},
#  {'timestamp': '00:00:27',
#   'speaker': 'KHLOE',
#   'text': 'You are such a little girl.'},
#  {'timestamp': '00:00:31', 'speaker': 'BRUCE', 'text': 'I know.'},
#  {'timestamp': '00:00:32', 'speaker': 'BRUCE', 'text': "I'm a wuss, yeah."},
#  {'timestamp': '00:00:33',
#   'speaker': 'BRUCE',
#   'text': 'When it comes to that stuff.'},
#  {'timestamp': '00:00:34', 'speaker': 'KHLOE', 'text': "You're a puss."},
#  {'timestamp': '00:00:35', 'speaker': 'BRUCE', 'text': "I'm a puss."},
#  {'timestamp': '00:00:36',
#   'speaker': 'KHLOE',
#   'text': 'I feel so bad that you need to, like, ask me for money.'},
#  {'timestamp': '00:00:39', 'speaker': 'BRUCE', 'text': 'Yeah, I know.'},
#  {'timestamp': '00:00:40', 'speaker': 'BRUCE', 'text': 'I feel bad, too.'},
#  {'timestamp': '00:00:40',
#   'speaker': 'BRUCE',
#   'text': 'How do you think I feel?'},
#  {'timestamp': '00:00:41',
#   'speaker': 'KHLOE',
#   'text': "Like, that's so embarrassing for you."},
#  {'timestamp': '00:00:42',
#   'speaker': 'KHLOE',
#   'text': 'I definitely feel sorry for Bruce.'},
#  {'timestamp': '00:00:45',
#   'speaker': 'KHLOE',
#   'text': 'And I really want to help him out.'},
#  {'timestamp': '00:00:46',
#   'speaker': 'KHLOE',
#   'text': 'I mean, I want him to feel like a man.'},
#  {'timestamp': '00:00:48',
#   'speaker': 'KHLOE',
#   'text': "Like, here's money, buy yourself something, jeez."},
#  {'timestamp': '00:00:51',
#   'speaker': 'BRUCE',
#   'text': "You're diving in for the cash?"},
#  {'timestamp': '00:00:53',
#   'speaker': 'KHLOE',
#   'text': 'Well, I have $400 on me now.'},
#  {'timestamp': '00:00:56', 'speaker': 'BRUCE', 'text': "You've got $400?!"},
#  {'timestamp': '00:00:57', 'speaker': 'KHLOE', 'text': 'So you can go...'},
#  {'timestamp': '00:00:58', 'speaker': 'BRUCE', 'text': "My God, I'm rich."},
#  {'timestamp': '00:00:59',
#   'speaker': 'KHLOE',
#   'text': 'And then if you could take out the trash, and then if you go to Dash, maybe tomorrow or whatever, later today and just...'},
#  {'timestamp': '00:01:05',
#   'speaker': 'BRUCE',
#   'text': 'You got a couple more?'},
#  {'timestamp': '00:01:06', 'speaker': 'BRUCE', 'text': 'I love it.'},
#  {'timestamp': '00:01:07',
#   'speaker': 'BRUCE',
#   'text': "All right, I'm gonna go start on my chores."},
#  {'timestamp': '00:01:10',
#   'speaker': 'BRUCE',
#   'text': "And remember, don't tell Mom, okay?"},
#  {'timestamp': '00:01:14',
#   'speaker': 'KHLOE',
#   'text': 'Your secret is safe with me.'},
#  {'timestamp': '00:01:25', 'speaker': 'KHLOE', 'text': 'Hi.'},
#  {'timestamp': '00:01:26', 'speaker': 'BRUCE', 'text': "I'm trying to..."},
#  {'timestamp': '00:01:27',
#   'speaker': 'KHLOE',
#   'text': 'I see you got started already on doing all the light bulbs.'},
#  {'timestamp': '00:01:29',
#   'speaker': 'BRUCE',
#   'text': 'None of them are working.'},
#  {'timestamp': '00:01:31',
#   'speaker': 'KHLOE',
#   'text': 'Well, you know, all these little light bulbs I need to be changed.'},
#  {'timestamp': '00:01:35',
#   'speaker': 'KHLOE',
#   'text': "Like, me and Lily can't reach those."},
#  {'timestamp': '00:01:37',
#   'speaker': 'KHLOE',
#   'text': "There's spider webs all on it and at the very top."},
#  {'timestamp': '00:01:39', 'speaker': 'KHLOE', 'text': "Like, that's sick."},
#  {'timestamp': '00:01:40', 'speaker': 'KHLOE', 'text': "I can't do that."},
#  {'timestamp': '00:01:40', 'speaker': 'BRUCE', 'text': 'All right.'},
#  {'timestamp': '00:01:41',
#   'speaker': 'KIM',
#   'text': 'You just need a duster.'},
#  {'timestamp': '00:01:42', 'speaker': 'BRUCE', 'text': 'I am the duster.'},
#  {'timestamp': '00:01:44',
#   'speaker': 'KHLOE',
#   'text': 'Bruce is doing a really good job at everything.'},
#  {'timestamp': '00:01:47',
#   'speaker': 'KHLOE',
#   'text': 'But I just feel bad even telling him to do stuff.'},
#  {'timestamp': '00:01:57', 'speaker': 'KHLOE', 'text': 'That should do it.'},
#  {'timestamp': '00:01:59',
#   'speaker': 'BRUCE',
#   'text': "It's been a pleasure doing business with you."},
#  {'timestamp': '00:02:01', 'speaker': 'KHLOE', 'text': 'Any time, dude.'},
#  {'timestamp': '00:02:02', 'speaker': 'BRUCE', 'text': 'Okay.'},
#  {'timestamp': '00:02:05',
#   'speaker': 'ADRIENNE',
#   'text': "Hey, I'm unavailable to take your call right now, but if you leave your name and number, I'll get back to you."},
#  {'timestamp': '00:02:14', 'speaker': 'ROBERT', 'text': "Hey, it's Rob."},
#  {'timestamp': '00:02:16',
#   'speaker': 'ROBERT',
#   'text': 'Just wanted to call and say it was nice seeing you at the wedding.'},
#  {'timestamp': '00:02:20',
#   'speaker': 'ROBERT',
#   'text': 'Nice talking to you and everything.'},
#  {'timestamp': '00:02:22',
#   'speaker': 'ROBERT',
#   'text': "I've been trying to call Adrienne, trying to make things right, but she won't pick up."},
#  {'timestamp': '00:02:26',
#   'speaker': 'ROBERT',
#   'text': "Hey, Adrienne, it's me again."},
#  {'timestamp': '00:02:29',
#   'speaker': 'ROBERT',
#   'text': "Hey, it's me again, uh, Rob."},
#  {'timestamp': '00:02:32',
#   'speaker': 'ROBERT',
#   'text': "Just wanted to see how your day's going."},
#  {'timestamp': '00:02:36', 'speaker': 'ROBERT', 'text': "Uh, it's 9:20."},
#  {'timestamp': '00:02:40',
#   'speaker': 'ROBERT',
#   'text': 'Just calling to say hi.'},
#  {'timestamp': '00:02:42',
#   'speaker': 'ROBERT',
#   'text': 'Call me back, please.'},
#  {'timestamp': '00:02:44',
#   'speaker': 'ROBERT',
#   'text': "The reason I'm calling Adrienne so much is just because I want her to see how much I truly care, and how much I truly want to be with her."},
#  {'timestamp': '00:02:52',
#   'speaker': 'ROBERT',
#   'text': 'I want to get my girl back.'},
#  {'timestamp': '00:02:53', 'speaker': 'ROBERT', 'text': "Hey, it's Rob."},
#  {'timestamp': '00:02:55',
#   'speaker': 'ROBERT',
#   'text': "I'm just calling you to see what's going on."},
#  {'timestamp': '00:02:58',
#   'speaker': 'BRUCE',
#   'text': 'Is that the strip club?'},
#  {'timestamp': '00:03:08',
#   'speaker': 'KIM',
#   'text': 'When did you start to get gray hair?'},
#  {'timestamp': '00:03:10', 'speaker': 'KRIS', 'text': 'Like last week.'},
#  {'timestamp': '00:03:11', 'speaker': 'KIM', 'text': 'Oh, please.'},
#  {'timestamp': '00:03:13',
#   'speaker': 'KRIS',
#   'text': 'I have one gray hair, and in order for her make it all blend, she has to do the whole head.'},
#  {'timestamp': '00:03:19', 'speaker': 'KRIS', 'text': 'Right, K?'},
#  {'timestamp': '00:03:19', 'speaker': 'KENDALL', 'text': 'Right.'},
#  {'timestamp': '00:03:20', 'speaker': 'KRIS', 'text': 'Right.'},
#  {'timestamp': '00:03:21',
#   'speaker': 'KRIS',
#   'text': 'Will you guys look at this new dress I have in my closet?'},
#  {'timestamp': '00:03:23', 'speaker': 'KHLOE', 'text': 'Why?'},
#  {'timestamp': '00:03:24',
#   'speaker': 'KHLOE',
#   'text': "I'm going to an event tomorrow night and I need to make sure that you guys think my dress is cute."},
#  {'timestamp': '00:03:28',
#   'speaker': 'KHLOE',
#   'text': "Mom, Kim and I have told you this before-- you can't buy clothes unless you approve them between us."},
#  {'timestamp': '00:03:32',
#   'speaker': 'KRIS',
#   'text': "I'm asking you to approve."},
#  {'timestamp': '00:03:34',
#   'speaker': 'KRIS',
#   'text': 'I have 24 hours, okay?'},
#  {'timestamp': '00:03:35',
#   'speaker': 'KRIS',
#   'text': "It's right over there."},
#  {'timestamp': '00:03:36', 'speaker': 'KRIS', 'text': 'Look at the dress.'},
#  {'timestamp': '00:03:37',
#   'speaker': 'KHLOE',
#   'text': 'Is it this one hanging right here?'},
#  {'timestamp': '00:03:39', 'speaker': 'KRIS', 'text': 'Yep.'},
#  {'timestamp': '00:03:40', 'speaker': 'KIM', 'text': 'Oh, my God.'},
#  {'timestamp': '00:03:41', 'speaker': 'KRIS', 'text': 'What?'},
#  {'timestamp': '00:03:42', 'speaker': 'KIM', 'text': 'It is like $4,000.'},
#  {'timestamp': '00:03:44', 'speaker': 'KHLOE', 'text': 'Mom!'},
#  {'timestamp': '00:03:45', 'speaker': 'KRIS', 'text': 'What?'},
#  {'timestamp': '00:03:45',
#   'speaker': 'KHLOE',
#   'text': 'You just spent $4,000 on a dress?'},
#  {'timestamp': '00:03:48',
#   'speaker': 'KRIS',
#   'text': "I couldn't find anything else to wear."},
#  {'timestamp': '00:03:51',
#   'speaker': 'KHLOE',
#   'text': 'Mom, that is ridiculous.'},
#  {'timestamp': '00:03:53', 'speaker': 'KHLOE', 'text': 'Are you kidding?'},
#  {'timestamp': '00:03:54', 'speaker': 'KIM', 'text': "That's crazy."},
#  {'timestamp': '00:03:55',
#   'speaker': 'KIM',
#   'text': "That's way too much money, Mom."},
#  {'timestamp': '00:03:57',
#   'speaker': 'KIM',
#   'text': "You have so many dresses, and it's just a plain black dress."},
#  {'timestamp': '00:04:00', 'speaker': 'KIM', 'text': "It's nothing special."},
#  {'timestamp': '00:04:01',
#   'speaker': 'KRIS',
#   'text': "I can't keep wearing the same dress over and over."},
#  {'timestamp': '00:04:03',
#   'speaker': 'KRIS',
#   'text': 'You have to have, like, something new every time we go to an event.'},
#  {'timestamp': '00:04:06',
#   'speaker': 'KHLOE',
#   'text': 'Kris is such a hypocrite.'},
#  {'timestamp': '00:04:08',
#   'speaker': 'KHLOE',
#   'text': "Bruce is not allowed to spend any money on helicopters because it's wasteful, but yet my mom can go around and spend $4,000 on a dress that she's only going to wear once."},
#  {'timestamp': '00:04:18',
#   'speaker': 'KRIS',
#   'text': 'Get out of my wallet, Khloe.'},
#  {'timestamp': '00:04:19', 'speaker': 'KHLOE', 'text': 'Credit card...'},
#  {'timestamp': '00:04:20', 'speaker': 'KRIS', 'text': 'Khloe, Khloe...'},
#  {'timestamp': '00:04:21',
#   'speaker': 'KHLOE',
#   'text': '...credit card, credit card...'},
#  {'timestamp': '00:04:24',
#   'speaker': 'KHLOE',
#   'text': "Ooh, Bruce Jenner's credit card."},
#  {'timestamp': '00:04:26',
#   'speaker': 'KHLOE',
#   'text': 'No wonder he has no money.'},
#  {'timestamp': '00:04:28',
#   'speaker': 'KIM',
#   'text': 'Capitol One, Wells Fargo...'},
#  {'timestamp': '00:04:29', 'speaker': 'KRIS', 'text': 'Put my stuff away.'},
#  {'timestamp': '00:04:31', 'speaker': 'KRIS', 'text': 'That is not okay.'},
#  {'timestamp': '00:04:32',
#   'speaker': 'KRIS',
#   'text': "You don't go through somebody's wallet, it's rude and disrespectful."},
#  {'timestamp': '00:04:36',
#   'speaker': 'KHLOE',
#   'text': "Oh, come on, she's too sensitive."},
#  {'timestamp': '00:04:37', 'speaker': 'KHLOE', 'text': 'Come on, Kim.'},
#  {'timestamp': '00:04:47',
#   'speaker': 'ROBERT',
#   'text': 'To wives and mistresses.'},
#  {'timestamp': '00:04:49', 'speaker': 'SCOTT', 'text': 'To goomahs.'},
#  {'timestamp': '00:04:50', 'speaker': 'SCOTT', 'text': 'To you.'},
#  {'timestamp': '00:04:52',
#   'speaker': 'JJ',
#   'text': 'What were you saying about last night?'},
#  {'timestamp': '00:04:55',
#   'speaker': 'SCOTT',
#   'text': 'Do you know how many times he called Adrienne last night?'},
#  {'timestamp': '00:04:58', 'speaker': 'JJ', 'text': '80, I know.'},
#  {'timestamp': '00:04:59', 'speaker': 'ROBERT', 'text': 'Shut up.'},
#  {'timestamp': '00:05:00', 'speaker': 'SCOTT', 'text': '70 he told me.'},
#  {'timestamp': '00:05:01',
#   'speaker': 'JJ',
#   'text': "If she doesn't pick up after five calls..."},
#  {'timestamp': '00:05:02',
#   'speaker': 'JJ',
#   'text': 'I want to know where the other 65 came from.'},
#  {'timestamp': '00:05:04',
#   'speaker': 'SCOTT',
#   'text': 'What is going on with you and Adrienne?'},
#  {'timestamp': '00:05:06',
#   'speaker': 'SCOTT',
#   'text': 'Where are you with her right now?'},
#  {'timestamp': '00:05:08', 'speaker': 'ROBERT', 'text': 'To be honest...'},
#  {'timestamp': '00:05:08',
#   'speaker': 'SCOTT',
#   'text': 'Do you know what I mean?'},
#  {'timestamp': '00:05:10',
#   'speaker': 'JJ',
#   'text': 'I felt like post-wedding, you were really close, and then you screwed it up.'},
#  {'timestamp': '00:05:14',
#   'speaker': 'SCOTT',
#   'text': 'I felt like the wedding night he was good, until she woke up the next day and he called her 19 times to see when she woke up.'},
#  {'timestamp': '00:05:20', 'speaker': 'ROBERT', 'text': 'I deny...'},
#  {'timestamp': '00:05:21',
#   'speaker': 'SCOTT',
#   'text': 'Sent nine kinds of flowers.'},
#  {'timestamp': '00:05:22', 'speaker': 'ROBERT', 'text': "I didn't..."},
#  {'timestamp': '00:05:22',
#   'speaker': 'SCOTT',
#   'text': "He's going to send her a dog, by the way."},
#  {'timestamp': '00:05:24',
#   'speaker': 'JJ',
#   'text': 'Did you send her flowers?'},
#  {'timestamp': '00:05:25', 'speaker': 'ROBERT', 'text': 'No, I did not.'},
#  {'timestamp': '00:05:26', 'speaker': 'ROBERT', 'text': 'Before the wedding.'},
#  {'timestamp': '00:05:27', 'speaker': 'ROBERT', 'text': "She liked 'em."},
#  {'timestamp': '00:05:27', 'speaker': 'SCOTT', 'text': 'Bet she did, Focker.'},
#  {'timestamp': '00:05:28',
#   'speaker': 'SCOTT',
#   'text': 'What is she going to say, "Hey, by the way, I hated your flowers See you at the wedding."?'},
#  {'timestamp': '00:05:31',
#   'speaker': 'ROBERT',
#   'text': 'You know, JJ and Scott are constantly making fun of me, but little do they know, like Adrienne and I have a special relationship.'},
#  {'timestamp': '00:05:38',
#   'speaker': 'SCOTT',
#   'text': 'What do you think is going to happen at this point?'},
#  {'timestamp': '00:05:40',
#   'speaker': 'SCOTT',
#   'text': 'I mean, are you stalking her?'},
#  {'timestamp': '00:05:41', 'speaker': 'ROBERT', 'text': "No, I'm done."},
#  {'timestamp': '00:05:42',
#   'speaker': 'SCOTT',
#   'text': "She's probably going to have a restraining order before you know it."},
#  {'timestamp': '00:05:47',
#   'speaker': 'ROBERT',
#   'text': 'She understands how I am.'},
#  {'timestamp': '00:05:49',
#   'speaker': 'ROBERT',
#   'text': "She doesn't think I'm crazy."},
#  {'timestamp': '00:05:50',
#   'speaker': 'KHLOE',
#   'text': "Robert, she definitely thinks you're crazy."},
#  {'timestamp': '00:05:52',
#   'speaker': 'KHLOE',
#   'text': 'This is an intervention, okay?'},
#  {'timestamp': '00:05:54', 'speaker': 'KHLOE', 'text': "We're intervening."},
#  {'timestamp': '00:05:56', 'speaker': 'KOURTNEY', 'text': "I'm done."},
#  {'timestamp': '00:05:58',
#   'speaker': 'KOURTNEY',
#   'text': "If you don't start helping me out and getting on my team, this relationship is done."},
#  {'timestamp': '00:08:39', 'speaker': 'KOURTNEY', 'text': 'Is this a joke?'},
#  {'timestamp': '00:08:45', 'speaker': 'KOURTNEY', 'text': 'Answer my phone.'},
#  {'timestamp': '00:08:46',
#   'speaker': 'KOURTNEY',
#   'text': 'When I call someone, like, answer.'},
#  {'timestamp': '00:08:48', 'speaker': 'KHLOE', 'text': 'Who are you calling?'},
#  {'timestamp': '00:08:49', 'speaker': 'KOURTNEY', 'text': 'Scott.'},
#  {'timestamp': '00:08:50',
#   'speaker': 'KOURTNEY',
#   'text': "I said I wanted to go to this-- to these classes, and like, he doesn't answer."},
#  {'timestamp': '00:08:55', 'speaker': 'KHLOE', 'text': 'Class for what?'},
#  {'timestamp': '00:08:56',
#   'speaker': 'KOURTNEY',
#   'text': 'Like breast pumping.'},
#  {'timestamp': '00:08:59',
#   'speaker': 'KHLOE',
#   'text': "Maybe that's why he's not answering."},
#  {'timestamp': '00:09:01', 'speaker': 'KOURTNEY', 'text': "It's still rude."},
#  {'timestamp': '00:09:03',
#   'speaker': 'KOURTNEY',
#   'text': 'I said, "Let\'s go."'},
#  {'timestamp': '00:09:05', 'speaker': 'KOURTNEY', 'text': 'Call him again.'},
#  {'timestamp': '00:09:07',
#   'speaker': 'KOURTNEY',
#   'text': 'I just called like, three times.'},
#  {'timestamp': '00:09:08',
#   'speaker': 'KOURTNEY',
#   'text': "I don't want to be a stalker."},
#  {'timestamp': '00:09:10', 'speaker': 'KOURTNEY', 'text': 'Answer my call.'},
#  {'timestamp': '00:09:10',
#   'speaker': 'KHLOE',
#   'text': "Kourtney, that's your baby daddy."},
#  {'timestamp': '00:09:12', 'speaker': 'KHLOE', 'text': 'You can stalk.'},
#  {'timestamp': '00:09:13', 'speaker': 'KHLOE', 'text': 'Stalk that ass.'},
#  {'timestamp': '00:09:14',
#   'speaker': 'KOURTNEY',
#   'text': "I've called Scott over and over."},
#  {'timestamp': '00:09:16',
#   'speaker': 'KOURTNEY',
#   'text': "He's totally avoiding my calls, and I'm really pissed off because he's totally flaking on me to go to this breast feeding class."},
#  {'timestamp': '00:09:24',
#   'speaker': 'KOURTNEY',
#   'text': 'I mean, I refuse to go alone.'},
#  {'timestamp': '00:09:25',
#   'speaker': 'KHLOE',
#   'text': 'Honey, why would anyone want to pump their breast by themselves?'},
#  {'timestamp': '00:09:30',
#   'speaker': 'KHLOE',
#   'text': 'I could go with you and give you moral support.'},
#  {'timestamp': '00:09:32',
#   'speaker': 'KHLOE',
#   'text': "I mean, I'm not going to pump your breast, but I'll pump mine."},
#  {'timestamp': '00:09:34', 'speaker': 'KOURTNEY', 'text': "I don't get it."},
#  {'timestamp': '00:09:34',
#   'speaker': 'KOURTNEY',
#   'text': 'And I feel like when I go to these classes...'},
#  {'timestamp': '00:09:36', 'speaker': 'KHLOE', 'text': 'I wonder if I can.'},
#  {'timestamp': '00:09:37',
#   'speaker': 'KHLOE',
#   'text': 'Can I really be that supportive and pump mine, too?'},
#  {'timestamp': '00:09:39',
#   'speaker': 'KOURTNEY',
#   'text': "Bruce told me he's tasted breast milk."},
#  {'timestamp': '00:09:41', 'speaker': 'KHLOE', 'text': "Bruce I'm sure has."},
#  {'timestamp': '00:09:43', 'speaker': 'KOURTNEY', 'text': 'How sick.'},
#  {'timestamp': '00:09:44',
#   'speaker': 'KHLOE',
#   'text': 'Bruce is just very...'},
#  {'timestamp': '00:09:45', 'speaker': 'LILY', 'text': 'By accident?'},
#  {'timestamp': '00:09:46',
#   'speaker': 'KOURTNEY',
#   'text': 'Are you going to taste mine, just to see what it tastes like?'},
#  {'timestamp': '00:09:49',
#   'speaker': 'KHLOE',
#   'text': 'Drink your breast milk?'},
#  {'timestamp': '00:09:51', 'speaker': 'KOURTNEY', 'text': 'Not from my boob.'},
#  {'timestamp': '00:09:53',
#   'speaker': 'KHLOE',
#   'text': 'Obviously, you sick .'},
#  {'timestamp': '00:09:55',
#   'speaker': 'KOURTNEY',
#   'text': "If I'm... taste it."},
#  {'timestamp': '00:09:56', 'speaker': 'KHLOE', 'text': "Yeah, I'll taste it."},
#  {'timestamp': '00:09:57',
#   'speaker': 'KHLOE',
#   'text': "I'm not sucking on your  though."},
#  {'timestamp': '00:10:00', 'speaker': 'KOURTNEY', 'text': "Let's hope."},
#  {'timestamp': '00:10:10', 'speaker': 'BRUCE', 'text': 'What are you doing?'},
#  {'timestamp': '00:10:11',
#   'speaker': 'KYLIE',
#   'text': 'Rob told me to bring beers for them.'},
#  {'timestamp': '00:10:14',
#   'speaker': 'BRUCE',
#   'text': 'To bring beers for them?'},
#  {'timestamp': '00:10:16',
#   'speaker': 'BRUCE',
#   'text': 'What are you, their bartender?'},
#  {'timestamp': '00:10:17', 'speaker': 'KYLIE', 'text': 'Yeah.'},
#  {'timestamp': '00:10:19', 'speaker': 'BRUCE', 'text': 'Great.'},
#  {'timestamp': '00:10:19',
#   'speaker': 'BRUCE',
#   'text': "Okay, get them their beers and don't be drinking any of it."},
#  {'timestamp': '00:10:22', 'speaker': 'KYLIE', 'text': 'Oh, I will.'},
#  {'timestamp': '00:10:24',
#   'speaker': 'BRUCE',
#   'text': 'Sometimes I get real disappointed with Scott.'},
#  {'timestamp': '00:10:27',
#   'speaker': 'BRUCE',
#   'text': "Here he's got a pregnant girlfriend, okay?"},
#  {'timestamp': '00:10:29',
#   'speaker': 'BRUCE',
#   'text': "Instead, he's over here with my little Kylie being a little barmaid, bringing beers out there so he can work on his tan."},
#  {'timestamp': '00:10:35',
#   'speaker': 'BRUCE',
#   'text': 'It does not work for me.'},
#  {'timestamp': '00:10:37',
#   'speaker': 'SCOTT',
#   'text': 'Having a little brewski, Bruce?'},
#  {'timestamp': '00:10:40',
#   'speaker': 'BRUCE',
#   'text': "Yeah, I'm trying to keep up with you guys."},
#  {'timestamp': '00:10:43',
#   'speaker': 'BRUCE',
#   'text': "Anyway, why aren't you with Kourtney?"},
#  {'timestamp': '00:10:45', 'speaker': 'SCOTT', 'text': 'What?'},
#  {'timestamp': '00:10:46',
#   'speaker': 'SCOTT',
#   'text': "I mean, I'm always with her."},
#  {'timestamp': '00:10:48',
#   'speaker': 'ROBERT',
#   'text': 'The guy needs a little breather.'},
#  {'timestamp': '00:10:51', 'speaker': 'BRUCE', 'text': 'Oh?'},
#  {'timestamp': '00:10:52',
#   'speaker': 'SCOTT',
#   'text': "She's doing some class that doesn't involve me today anyway."},
#  {'timestamp': '00:10:55',
#   'speaker': 'BRUCE',
#   'text': "She say she didn't want you to go?"},
#  {'timestamp': '00:10:57', 'speaker': 'SCOTT', 'text': 'Of course not.'},
#  {'timestamp': '00:10:58',
#   'speaker': 'SCOTT',
#   'text': 'She said she wanted me to go, but...'},
#  {'timestamp': '00:11:00', 'speaker': 'SCOTT', 'text': 'I know.'},
#  {'timestamp': '00:11:01', 'speaker': 'SCOTT', 'text': "I don't need to go."},
#  {'timestamp': '00:11:03',
#   'speaker': 'BRUCE',
#   'text': 'Yeah, well, yes, you do, you need to go.'},
#  {'timestamp': '00:11:06',
#   'speaker': 'SCOTT',
#   'text': 'Look, Bruce, I know how to handle my lady, and you know how to handle yours.'},
#  {'timestamp': '00:11:10', 'speaker': 'SCOTT', 'text': "We'll be just fine."},
#  {'timestamp': '00:11:12',
#   'speaker': 'BRUCE',
#   'text': 'You know how to handle Kourtney?'},
#  {'timestamp': '00:11:14',
#   'speaker': 'BRUCE',
#   'text': 'Nobody knows how to handle Kourtney.'},
#  {'timestamp': '00:11:17',
#   'speaker': 'SCOTT',
#   'text': 'I handled her well enough to get her pregnant.'},
#  {'timestamp': '00:11:20', 'speaker': 'BRUCE', 'text': 'Yeah. Good luck.'},
#  {'timestamp': '00:11:28', 'speaker': 'TEACHER', 'text': 'Hi. How are you?'},
#  {'timestamp': '00:11:30', 'speaker': 'TEACHER', 'text': 'Hi, come on in.'},
#  {'timestamp': '00:11:35',
#   'speaker': 'KHLOE',
#   'text': "You don't like your baby?"},
#  {'timestamp': '00:11:36', 'speaker': 'KOURTNEY', 'text': 'This one.'},
#  {'timestamp': '00:11:37',
#   'speaker': 'KHLOE',
#   'text': 'Here, you want this one?'},
#  {'timestamp': '00:11:38', 'speaker': 'KOURTNEY', 'text': 'Yes, thank you.'},
#  {'timestamp': '00:11:41', 'speaker': 'KOURTNEY', 'text': 'Okay.'},
#  {'timestamp': '00:11:42',
#   'speaker': 'KOURTNEY',
#   'text': 'I like that one better.'},
#  {'timestamp': '00:11:45', 'speaker': 'KHLOE', 'text': 'Like a girl.'},
#  {'timestamp': '00:11:45',
#   'speaker': 'KOURTNEY',
#   'text': "Ooh, look at that one's eyes."},
#  {'timestamp': '00:11:47',
#   'speaker': 'KOURTNEY',
#   'text': 'Khloe, look at it.'},
#  {'timestamp': '00:11:48', 'speaker': 'TEACHER', 'text': 'So, hi, everyone.'},
#  {'timestamp': '00:11:50',
#   'speaker': 'TEACHER',
#   'text': "So today we're gonna take you through some of the, uh, basics that you guys need to know, how to take care of these little ones."},
#  {'timestamp': '00:11:56',
#   'speaker': 'TEACHER',
#   'text': "And we're gonna just, um, talk about and learn about some of the things that you're gonna be doing every day."},
#  {'timestamp': '00:12:00',
#   'speaker': 'TEACHER',
#   'text': 'Um, so I think hopefully it will be useful to you.'},
#  {'timestamp': '00:12:04',
#   'speaker': 'KOURTNEY',
#   'text': 'How many times a day does your baby eat?'},
#  {'timestamp': '00:12:07',
#   'speaker': 'TEACHER',
#   'text': 'Um, new babies that are breast-fed, eight to 12 times.'},
#  {'timestamp': '00:12:11', 'speaker': 'KOURTNEY', 'text': 'No.'},
#  {'timestamp': '00:12:12', 'speaker': 'TEACHER', 'text': 'Yeah.'},
#  {'timestamp': '00:12:12', 'speaker': 'KOURTNEY', 'text': 'A day?'},
#  {'timestamp': '00:12:13', 'speaker': 'TEACHER', 'text': 'Pretty often.'},
#  {'timestamp': '00:12:14',
#   'speaker': 'TEACHER',
#   'text': 'Uh-huh, in 24 hours.'},
#  {'timestamp': '00:12:15',
#   'speaker': 'KOURTNEY',
#   'text': "Going to these classes makes me more nervous because it just reminds me of all the information that I don't know."},
#  {'timestamp': '00:12:23',
#   'speaker': 'TEACHER',
#   'text': "Put the front of the diaper underneath your baby's tush so you've got a clean surface."},
#  {'timestamp': '00:12:27',
#   'speaker': 'KHLOE',
#   'text': 'Kourtney, his two legs like this.'},
#  {'timestamp': '00:12:30', 'speaker': 'KOURTNEY', 'text': 'Sorry.'},
#  {'timestamp': '00:12:31',
#   'speaker': 'TEACHER',
#   'text': 'And have that cloth diaper handy.'},
#  {'timestamp': '00:12:33',
#   'speaker': 'TEACHER',
#   'text': 'Everybody got that?'},
#  {'timestamp': '00:12:35', 'speaker': 'TEACHER', 'text': 'Perfect.'},
#  {'timestamp': '00:12:36', 'speaker': 'KHLOE', 'text': 'No, you wrap it...'},
#  {'timestamp': '00:12:37', 'speaker': 'KOURTNEY', 'text': 'Bingo.'},
#  {'timestamp': '00:12:38',
#   'speaker': 'KOURTNEY',
#   'text': "I don't know how to change a diaper."},
#  {'timestamp': '00:12:40',
#   'speaker': 'KOURTNEY',
#   'text': "I don't know how to swaddle a baby."},
#  {'timestamp': '00:12:43',
#   'speaker': 'KOURTNEY',
#   'text': "I don't know when you swaddle a baby."},
#  {'timestamp': '00:12:45',
#   'speaker': 'KOURTNEY',
#   'text': "I don't know even how to hold the baby."},
#  {'timestamp': '00:12:47',
#   'speaker': 'KOURTNEY',
#   'text': "Just thinking about all these tasks and things that I'm gonna need to know just makes me really nervous and anxious."},
#  {'timestamp': '00:12:56', 'speaker': 'KOURTNEY', 'text': 'Did you do it?'},
#  {'timestamp': '00:12:57',
#   'speaker': 'TEACHER',
#   'text': "You guys, how'd you do?"},
#  {'timestamp': '00:12:59', 'speaker': 'TEACHER', 'text': 'It looks good.'},
#  {'timestamp': '00:12:59',
#   'speaker': 'KOURTNEY',
#   'text': "I don't think I did very well."},
#  {'timestamp': '00:13:01', 'speaker': 'TEACHER', 'text': "Okay, let's see."},
#  {'timestamp': '00:13:02',
#   'speaker': 'KHLOE',
#   'text': "Kourtney's just off right now."},
#  {'timestamp': '00:13:03',
#   'speaker': 'KHLOE',
#   'text': "I think she's really getting stressed, and the pregnancy's finally starting to hit her and it's becoming more serious."},
#  {'timestamp': '00:13:09',
#   'speaker': 'KHLOE',
#   'text': "And also, I think the fact that she's the only one without a dad here right now, I think that's really affecting her."},
#  {'timestamp': '00:13:15',
#   'speaker': 'TEACHER',
#   'text': 'How are the dads back there feeling about all of this going on?'},
#  {'timestamp': '00:13:18',
#   'speaker': 'TEACHER',
#   'text': 'You guys plan to be pretty involved or...?'},
#  {'timestamp': '00:13:21',
#   'speaker': 'TEACHER',
#   'text': "Yeah, he's better than you are."},
#  {'timestamp': '00:13:22',
#   'speaker': 'TEACHER',
#   'text': 'How about the rest of you?'},
#  {'timestamp': '00:13:23',
#   'speaker': 'TEACHER',
#   'text': 'Dads involved or...?'},
#  {'timestamp': '00:13:25', 'speaker': 'KHLOE', 'text': "I'm the dad today."},
#  {'timestamp': '00:13:26', 'speaker': 'TEACHER', 'text': 'Got it.'},
#  {'timestamp': '00:13:27', 'speaker': 'TEACHER', 'text': 'Good.'},
#  {'timestamp': '00:13:27',
#   'speaker': 'TEACHER',
#   'text': "You're gonna be busy."},
#  {'timestamp': '00:13:28', 'speaker': 'KHLOE', 'text': 'Mm.'},
#  {'timestamp': '00:13:29',
#   'speaker': 'KHLOE',
#   'text': "I will still be the dad, even when he is around, I'm sure."},
#  {'timestamp': '00:13:39', 'speaker': 'SCOTT', 'text': 'Hello.'},
#  {'timestamp': '00:13:45', 'speaker': 'SCOTT', 'text': 'Okay.'},
#  {'timestamp': '00:13:46', 'speaker': 'SCOTT', 'text': 'What are you up to?'},
#  {'timestamp': '00:13:50',
#   'speaker': 'SCOTT',
#   'text': 'All right, good talking to you.'},
#  {'timestamp': '00:13:51',
#   'speaker': 'KOURTNEY',
#   'text': "I'm sick and tired of Scott not putting in an effort with the baby and I."},
#  {'timestamp': '00:13:56',
#   'speaker': 'KOURTNEY',
#   'text': 'And him not coming to that class was the last straw.'},
#  {'timestamp': '00:13:59',
#   'speaker': 'SCOTT',
#   'text': 'You have a bad attitude.'},
#  {'timestamp': '00:14:01',
#   'speaker': 'KOURTNEY',
#   'text': "Yeah, 'cause you ditched me in my breast-feeding class today."},
#  {'timestamp': '00:14:05',
#   'speaker': 'SCOTT',
#   'text': "It's a woman's breast-feeding class."},
#  {'timestamp': '00:14:08',
#   'speaker': 'KOURTNEY',
#   'text': 'We learned about other things.'},
#  {'timestamp': '00:14:10',
#   'speaker': 'KOURTNEY',
#   'text': "It wasn't just about breast-feeding!"},
#  {'timestamp': '00:14:12',
#   'speaker': 'KOURTNEY',
#   'text': "You just don't get it."},
#  {'timestamp': '00:14:13',
#   'speaker': 'KOURTNEY',
#   'text': 'What are you bringing to the table?'},
#  {'timestamp': '00:14:15', 'speaker': 'KOURTNEY', 'text': 'Nothing.'},
#  {'timestamp': '00:14:16', 'speaker': 'SCOTT', 'text': 'Everything.'},
#  {'timestamp': '00:14:16', 'speaker': 'KOURTNEY', 'text': 'Nothing!'},
#  {'timestamp': '00:14:17',
#   'speaker': 'KOURTNEY',
#   'text': "You're not helping with any  thing."},
#  {'timestamp': '00:14:20', 'speaker': 'KOURTNEY', 'text': "I'm done."},
#  {'timestamp': '00:14:21',
#   'speaker': 'KOURTNEY',
#   'text': 'Like, I am so  done with you.'},
#  {'timestamp': '00:14:23', 'speaker': 'SCOTT', 'text': 'Oh, relax.'},
#  {'timestamp': '00:14:24',
#   'speaker': 'SCOTT',
#   'text': "You-you don't mean that."},
#  {'timestamp': '00:14:25', 'speaker': 'KOURTNEY', 'text': 'Relax?'},
#  {'timestamp': '00:14:25', 'speaker': 'SCOTT', 'text': 'No, okay...'},
#  {'timestamp': '00:14:26', 'speaker': 'KOURTNEY', 'text': 'Test me!'},
#  {'timestamp': '00:14:27', 'speaker': 'KOURTNEY', 'text': 'test me and see.'},
#  {'timestamp': '00:14:28', 'speaker': 'SCOTT', 'text': 'Test you?'},
#  {'timestamp': '00:14:29', 'speaker': 'KOURTNEY', 'text': 'Yeah!'},
#  {'timestamp': '00:14:29',
#   'speaker': 'KOURTNEY',
#   'text': "If you don't start helping me out and getting on my team, this relationship is done."},
#  {'timestamp': '00:14:36', 'speaker': 'KRIS', 'text': "Where's my dress?"},
#  {'timestamp': '00:14:38',
#   'speaker': 'BRUCE',
#   'text': 'Bitch, I want my damn ATM card!'},
#  {'timestamp': '00:14:41',
#   'speaker': 'KIM',
#   'text': "So what's, like, your plan?"},
#  {'timestamp': '00:14:44',
#   'speaker': 'KIM',
#   'text': 'Like, where are you gonna stay?'},
#  {'timestamp': '00:14:45',
#   'speaker': 'ROBERT',
#   'text': 'When I get tre, m just gonna go get a hotel room and, uh...'},
#  {'timestamp': '00:14:48',
#   'speaker': 'KIM',
#   'text': "I'm just afraid if you go to New York, you'll come back hurt."},
#  {'timestamp': '00:14:52',
#   'speaker': 'KIM',
#   'text': "As much as I don't agree with Rob going to New York, he's my little brother."},
#  {'timestamp': '00:14:57',
#   'speaker': 'KIM',
#   'text': "I'm gonna support him no matter what."},
#  {'timestamp': '00:17:39', 'speaker': 'ROBERT', 'text': 'Hello?'},
#  {'timestamp': '00:17:41',
#   'speaker': 'KIM',
#   'text': "So I call Rob to see what's going on with Adrienne."},
#  {'timestamp': '00:17:43',
#   'speaker': 'ROBERT',
#   'text': 'I freaked out last night and I called her, like, 60 times, literally, like crazy.'},
#  {'timestamp': '00:17:48',
#   'speaker': 'ROBERT',
#   'text': 'Like, more than that.'},
#  {'timestamp': '00:17:49',
#   'speaker': 'ROBERT',
#   'text': 'Like, from the house and from my cell.'},
#  {'timestamp': '00:17:52', 'speaker': 'KIM', 'text': "Rob, you're crazy."},
#  {'timestamp': '00:17:54',
#   'speaker': 'ROBERT',
#   'text': "I think if I show her that I'm serious about wanting her back, I think she'll come back to me."},
#  {'timestamp': '00:17:59',
#   'speaker': 'ROBERT',
#   'text': "I don't want to be with anybody but her."},
#  {'timestamp': '00:18:01',
#   'speaker': 'ROBERT',
#   'text': "I don't want to even date."},
#  {'timestamp': '00:18:02',
#   'speaker': 'ROBERT',
#   'text': "And I can't just be lonely and single anymore."},
#  {'timestamp': '00:18:05',
#   'speaker': 'ROBERT',
#   'text': 'Literally, every single day, I send her an e-mail or a text.'},
#  {'timestamp': '00:18:09',
#   'speaker': 'ROBERT',
#   'text': "And I'm not talking about just one."},
#  {'timestamp': '00:18:10',
#   'speaker': 'ROBERT',
#   'text': 'Like, "Oh, this just reminded me of you." "I\'m so sorry, like, that I treated you that way."'},
#  {'timestamp': '00:18:21',
#   'speaker': 'ROBERT',
#   'text': 'I think that at some point, you just need to stop calling her.'},
#  {'timestamp': '00:18:24',
#   'speaker': 'ROBERT',
#   'text': 'And I think this is now, like, the turning point.'},
#  {'timestamp': '00:18:27',
#   'speaker': 'ROBERT',
#   'text': 'You have to let it go.'},
#  {'timestamp': '00:18:29',
#   'speaker': 'ROBERT',
#   'text': "All right, I'm gonna shower."},
#  {'timestamp': '00:18:30', 'speaker': 'KIM', 'text': 'Bye.'},
#  {'timestamp': '00:18:31', 'speaker': 'SCOTT', 'text': 'Hey, Bruce.'},
#  {'timestamp': '00:18:43', 'speaker': 'BRUCE', 'text': 'Scotty.'},
#  {'timestamp': '00:18:44', 'speaker': 'SCOTT', 'text': 'Rob here?'},
#  {'timestamp': '00:18:45', 'speaker': 'BRUCE', 'text': 'No, he left.'},
#  {'timestamp': '00:18:46', 'speaker': 'SCOTT', 'text': 'What?'},
#  {'timestamp': '00:18:47',
#   'speaker': 'SCOTT',
#   'text': 'He just told me to come here.'},
#  {'timestamp': '00:18:49', 'speaker': 'BRUCE', 'text': 'Did he really?'},
#  {'timestamp': '00:18:49',
#   'speaker': 'SCOTT',
#   'text': "I figure I'll talk to you then, Bruce, if Rob ain't here."},
#  {'timestamp': '00:18:53',
#   'speaker': 'SCOTT',
#   'text': "I need somebody to speak to, because, you know, it's all women everywhere."},
#  {'timestamp': '00:18:56', 'speaker': 'BRUCE', 'text': 'Yeah.'},
#  {'timestamp': '00:18:57',
#   'speaker': 'SCOTT',
#   'text': "There's nothing but..."},
#  {'timestamp': '00:18:58',
#   'speaker': 'BRUCE',
#   'text': 'And you got a pregnant one.'},
#  {'timestamp': '00:19:00',
#   'speaker': 'SCOTT',
#   'text': "It's not simple, I've come to realize."},
#  {'timestamp': '00:19:02',
#   'speaker': 'BRUCE',
#   'text': "You're just realizing that now?"},
#  {'timestamp': '00:19:04',
#   'speaker': 'SCOTT',
#   'text': 'She, I guess, asked me to go to some class that I thought I had no part in.'},
#  {'timestamp': '00:19:08', 'speaker': 'SCOTT', 'text': 'Breast-feeding?'},
#  {'timestamp': '00:19:09',
#   'speaker': 'SCOTT',
#   'text': "I thought that's just her."},
#  {'timestamp': '00:19:11',
#   'speaker': 'SCOTT',
#   'text': 'What-what do I bring to the table in breast-feeding?'},
#  {'timestamp': '00:19:13', 'speaker': 'BRUCE', 'text': 'Support.'},
#  {'timestamp': '00:19:14',
#   'speaker': 'SCOTT',
#   'text': "I mean, I want to be there for her and be sensitive, I've just never been this person before."},
#  {'timestamp': '00:19:19',
#   'speaker': 'BRUCE',
#   'text': 'Scott has really lived a very easy life.'},
#  {'timestamp': '00:19:22',
#   'speaker': 'BRUCE',
#   'text': "He's been really very selfish and just kind of dealing with Scott."},
#  {'timestamp': '00:19:25',
#   'speaker': 'BRUCE',
#   'text': "It's time to give a little bit of advice about being a father."},
#  {'timestamp': '00:19:28',
#   'speaker': 'BRUCE',
#   'text': "You just got to realize that it's just not about you anymore."},
#  {'timestamp': '00:19:32', 'speaker': 'SCOTT', 'text': 'Yeah.'},
#  {'timestamp': '00:19:32',
#   'speaker': 'BRUCE',
#   'text': "It's not about Kourtney anymore."},
#  {'timestamp': '00:19:34',
#   'speaker': 'BRUCE',
#   'text': "It's about this family structure."},
#  {'timestamp': '00:19:36', 'speaker': 'BRUCE', 'text': "It's easier now."},
#  {'timestamp': '00:19:37',
#   'speaker': 'BRUCE',
#   'text': 'Because when little guy comes...'},
#  {'timestamp': '00:19:40',
#   'speaker': 'SCOTT',
#   'text': "It's a whole 'nother level."},
#  {'timestamp': '00:19:41',
#   'speaker': 'BRUCE',
#   'text': "It's 24 hours a day, seven days a week, 365 days out of the year for the next 20 years of your life."},
#  {'timestamp': '00:19:47',
#   'speaker': 'SCOTT',
#   'text': "I'm getting to realize that now."},
#  {'timestamp': '00:19:49',
#   'speaker': 'SCOTT',
#   'text': "Being an only child, I never really did care too much about other people's needs."},
#  {'timestamp': '00:19:54',
#   'speaker': 'SCOTT',
#   'text': "But I realize, I'm not the most important person anymore, and I can't be selfish."},
#  {'timestamp': '00:19:58',
#   'speaker': 'SCOTT',
#   'text': 'I need to think about my family.'},
#  {'timestamp': '00:19:59',
#   'speaker': 'BRUCE',
#   'text': 'All you can do right now is just dote on her, take care of her and just realize that this stage of pregnancy, you just got to get through it.'},
#  {'timestamp': '00:20:16',
#   'speaker': 'KOURTNEY',
#   'text': 'They came with me to look at the...'},
#  {'timestamp': '00:20:18', 'speaker': 'KHLOE', 'text': 'Yeah.'},
#  {'timestamp': '00:20:18', 'speaker': 'KHLOE', 'text': 'Kathy comes with us.'},
#  {'timestamp': '00:20:19', 'speaker': 'KIM', 'text': 'Yummy.'},
#  {'timestamp': '00:20:21', 'speaker': 'KHLOE', 'text': 'Hey, Rob.'},
#  {'timestamp': '00:20:22',
#   'speaker': 'KHLOE',
#   'text': "Kourt, Kim and I decide that it's time to intervene on Rob with this whole Adrienne situation."},
#  {'timestamp': '00:20:28',
#   'speaker': 'KHLOE',
#   'text': "Thank God you're here, because honestly you have a major problem."},
#  {'timestamp': '00:20:32', 'speaker': 'ROBERT', 'text': 'What did I do?'},
#  {'timestamp': '00:20:33',
#   'speaker': 'KHLOE',
#   'text': 'Uh, you are obsessed with Adrienne.'},
#  {'timestamp': '00:20:40',
#   'speaker': 'ROBERT',
#   'text': 'She understands how I am.'},
#  {'timestamp': '00:20:42',
#   'speaker': 'ROBERT',
#   'text': "She doesn't think I'm crazy."},
#  {'timestamp': '00:20:43',
#   'speaker': 'KHLOE',
#   'text': "Um, Robert, she definitely thinks you're crazy."},
#  {'timestamp': '00:20:46',
#   'speaker': 'KOURTNEY',
#   'text': "Who wouldn't think someone's crazy if they call them that many times?"},
#  {'timestamp': '00:20:49',
#   'speaker': 'KHLOE',
#   'text': 'This is an intervention, okay?'},
#  {'timestamp': '00:20:51', 'speaker': 'KHLOE', 'text': "We're intervening."},
#  {'timestamp': '00:20:52',
#   'speaker': 'KOURTNEY',
#   'text': "If Rob and Adrienne are meant to be together, they'll be."},
#  {'timestamp': '00:20:56',
#   'speaker': 'KOURTNEY',
#   'text': "You don't need to try this hard."},
#  {'timestamp': '00:20:57', 'speaker': 'KOURTNEY', 'text': "I'm over it now."},
#  {'timestamp': '00:20:58',
#   'speaker': 'KOURTNEY',
#   'text': 'Like, at first, I was like, "Oh, cute, Rob and Adrienne." Like, I\'m over it, okay?'},
#  {'timestamp': '00:21:02',
#   'speaker': 'KIM',
#   'text': 'She knows that you love her.'},
#  {'timestamp': '00:21:03', 'speaker': 'KIM', 'text': 'What else can you do?'},
#  {'timestamp': '00:21:04',
#   'speaker': 'KIM',
#   'text': "There's nothing else you can do."},
#  {'timestamp': '00:21:06',
#   'speaker': 'ROBERT',
#   'text': "The love that Adrienne and I had doesn't just go away overnight."},
#  {'timestamp': '00:21:10',
#   'speaker': 'ROBERT',
#   'text': "It's just so frustrating that my own family doesn't even understand their own brother."},
#  {'timestamp': '00:21:14',
#   'speaker': 'ROBERT',
#   'text': "I don't feel content and, like, at peace."},
#  {'timestamp': '00:21:17',
#   'speaker': 'ROBERT',
#   'text': "I can't just drop everything and be cold turkey not talk to her anymore."},
#  {'timestamp': '00:21:20',
#   'speaker': 'KHLOE',
#   'text': "Well, that's not gonna happen."},
#  {'timestamp': '00:21:22',
#   'speaker': 'KHLOE',
#   'text': 'She went back to New York.'},
#  {'timestamp': '00:21:23', 'speaker': 'KIM', 'text': "She's in New York."},
#  {'timestamp': '00:21:23',
#   'speaker': 'ROBERT',
#   'text': "Then if I have to go to New York, I'll go to New York."},
#  {'timestamp': '00:21:26',
#   'speaker': 'ROBERT',
#   'text': 'If I look like an idiot-- How much more stupid can I look?'},
#  {'timestamp': '00:21:28',
#   'speaker': 'KHLOE',
#   'text': "You're just gonna go to her house?"},
#  {'timestamp': '00:21:30',
#   'speaker': 'ROBERT',
#   'text': "I'm gonna go try and make things right."},
#  {'timestamp': '00:21:32',
#   'speaker': 'KHLOE',
#   'text': 'You know, honestly, maybe you need to go to New York to open up your eyes that you guys are not meant to be.'},
#  {'timestamp': '00:21:37',
#   'speaker': 'ROBERT',
#   'text': "Well, I don't agree with that."},
#  {'timestamp': '00:21:39',
#   'speaker': 'KHLOE',
#   'text': 'Enjoy Adrienne in New York, you freak of the week.'},
#  {'timestamp': '00:21:46',
#   'speaker': 'KIM',
#   'text': 'We should go and get her dress from the dry cleaners and hold it captive until she gives back the ATM card.'},
#  {'timestamp': '00:21:53',
#   'speaker': 'ROBERT',
#   'text': "I've decided to fly back to New York to see Adrienne face-to-face."},
#  {'timestamp': '00:21:57',
#   'speaker': 'KRIS',
#   'text': "Does she know you're coming?"},
#  {'timestamp': '00:21:58', 'speaker': 'ROBERT', 'text': "No, she doesn't."},
#  {'timestamp': '00:24:46',
#   'speaker': 'BRUCE',
#   'text': "Where'd these cookies come from?"},
#  {'timestamp': '00:24:48',
#   'speaker': 'KHLOE',
#   'text': "They're Armenian cookies."},
#  {'timestamp': '00:24:50',
#   'speaker': 'BRUCE',
#   'text': "What's the difference between, like, an American cookie and an Armenian cookie?"},
#  {'timestamp': '00:24:54',
#   'speaker': 'KHLOE',
#   'text': 'An Armenian made them.'},
#  {'timestamp': '00:24:56',
#   'speaker': 'BRUCE',
#   'text': 'Oh, that makes them Armenian cookies?'},
#  {'timestamp': '00:24:58',
#   'speaker': 'KIM',
#   'text': 'Those pants-- I mean, are you a doctor?'},
#  {'timestamp': '00:25:00', 'speaker': 'BRUCE', 'text': 'Yeah.'},
#  {'timestamp': '00:25:01',
#   'speaker': 'KHLOE',
#   'text': 'I mean, do you have a washing machine?'},
#  {'timestamp': '00:25:02', 'speaker': 'KHLOE', 'text': "They're filthy."},
#  {'timestamp': '00:25:03',
#   'speaker': 'BRUCE',
#   'text': "They are, but I've been working all day, moving stuff for your mother."},
#  {'timestamp': '00:25:07',
#   'speaker': 'KHLOE',
#   'text': "Don't you have any, like, balls?"},
#  {'timestamp': '00:25:09', 'speaker': 'BRUCE', 'text': 'No, not with her.'},
#  {'timestamp': '00:25:10', 'speaker': 'KHLOE', 'text': 'Apparently not.'},
#  {'timestamp': '00:25:11',
#   'speaker': 'KHLOE',
#   'text': "They're in the blender."},
#  {'timestamp': '00:25:11', 'speaker': 'KIM', 'text': 'Balls in a blender.'},
#  {'timestamp': '00:25:12', 'speaker': 'KHLOE', 'text': 'Balls in a blender.'},
#  {'timestamp': '00:25:14',
#   'speaker': 'KHLOE',
#   'text': 'Kris already has your balls in a blender.'},
#  {'timestamp': '00:25:16', 'speaker': 'BRUCE', 'text': 'I know.'},
#  {'timestamp': '00:25:17',
#   'speaker': 'BRUCE',
#   'text': 'Well, what are you gonna do?'},
#  {'timestamp': '00:25:18',
#   'speaker': 'BRUCE',
#   'text': "I'm...  I'm scared of her!"},
#  {'timestamp': '00:25:20',
#   'speaker': 'KHLOE',
#   'text': "Honey, she's the one that walked in with a $5,000 all-black basic dress."},
#  {'timestamp': '00:25:25', 'speaker': 'KHLOE', 'text': 'Like, hello.'},
#  {'timestamp': '00:25:26', 'speaker': 'BRUCE', 'text': 'Really?'},
#  {'timestamp': '00:25:27',
#   'speaker': 'KHLOE',
#   'text': 'Yeah, $5,000 for one black gown.'},
#  {'timestamp': '00:25:30',
#   'speaker': 'KHLOE',
#   'text': "It wasn't even special."},
#  {'timestamp': '00:25:32',
#   'speaker': 'BRUCE',
#   'text': 'Thousands of dollars she paid, for a dress!'},
#  {'timestamp': '00:25:35', 'speaker': 'BRUCE', 'text': 'Are you kidding me?!'},
#  {'timestamp': '00:25:37',
#   'speaker': 'KIM',
#   'text': "We've got to get her back."},
#  {'timestamp': '00:25:38',
#   'speaker': 'KIM',
#   'text': "I don't know how, but..."},
#  {'timestamp': '00:25:42',
#   'speaker': 'BRUCE',
#   'text': 'Maybe I should trade in the dress or something, huh?'},
#  {'timestamp': '00:25:44',
#   'speaker': 'KIM ',
#   'text': 'Wait, I have the best idea!'},
#  {'timestamp': '00:25:47', 'speaker': 'KHLOE & BRUCE', 'text': 'What?'},
#  {'timestamp': '00:25:47',
#   'speaker': 'KIM',
#   'text': 'We should go and get her dress from the dry cleaners and hold it captive until she gives back the ATM card.'},
#  {'timestamp': '00:25:54',
#   'speaker': 'KIM',
#   'text': 'I really want to help Bruce get his financial freedom back.'},
#  {'timestamp': '00:25:58', 'speaker': 'KIM', 'text': "He's worked so hard."},
#  {'timestamp': '00:25:59',
#   'speaker': 'KIM',
#   'text': "There's no way that my mom should have control over the money."},
#  {'timestamp': '00:26:03',
#   'speaker': 'BRUCE',
#   'text': 'So we get her dress from the cleaners, and we hold her hostage.'},
#  {'timestamp': '00:26:07', 'speaker': 'BRUCE', 'text': "I like it. I'm in."},
#  {'timestamp': '00:26:23',
#   'speaker': 'SCOTT',
#   'text': "I'm gonna show Kourtney that I'm gonna be there for whatever she needs, whenever she needs it."},
#  {'timestamp': '00:26:40', 'speaker': 'KOURTNEY', 'text': 'Hey.'},
#  {'timestamp': '00:26:41', 'speaker': 'SCOTT', 'text': 'Hello, hello.'},
#  {'timestamp': '00:26:43',
#   'speaker': 'KOURTNEY',
#   'text': 'What are you doing?'},
#  {'timestamp': '00:26:44',
#   'speaker': 'SCOTT',
#   'text': 'Getting this room put together.'},
#  {'timestamp': '00:26:46',
#   'speaker': 'KOURTNEY',
#   'text': "Oh, that's cute, with the animals there on the blanket."},
#  {'timestamp': '00:26:49',
#   'speaker': 'SCOTT',
#   'text': 'What about the whole crib is all done?'},
#  {'timestamp': '00:26:51', 'speaker': 'KOURTNEY', 'text': 'Oh, no way.'},
#  {'timestamp': '00:26:52',
#   'speaker': 'SCOTT',
#   'text': 'I never in a million years pictured myself putting a crib together.'},
#  {'timestamp': '00:26:57',
#   'speaker': 'SCOTT',
#   'text': "I know that I'm doing it for my son, and I'm taking pride in it."},
#  {'timestamp': '00:27:01',
#   'speaker': 'KOURTNEY',
#   'text': "It's so cute that you put those animals out here like that."},
#  {'timestamp': '00:27:04',
#   'speaker': 'SCOTT',
#   'text': 'Just wanted you to be happy.'},
#  {'timestamp': '00:27:06', 'speaker': 'KOURTNEY', 'text': 'Thank you.'},
#  {'timestamp': '00:27:07',
#   'speaker': 'KOURTNEY',
#   'text': 'It makes me happy.'},
#  {'timestamp': '00:27:21',
#   'speaker': 'KHLOE',
#   'text': 'Our mission is to teach Kris a lesson and give Bruce his balls back for life.'},
#  {'timestamp': '00:27:26', 'speaker': 'KHLOE', 'text': "So, we're here."},
#  {'timestamp': '00:27:33',
#   'speaker': 'KIM',
#   'text': 'Hi. We are picking up a dress under "Kris Jenner."'},
#  {'timestamp': '00:27:37',
#   'speaker': 'KIM',
#   'text': "We're just gonna take this dress."},
#  {'timestamp': '00:27:39', 'speaker': 'KHLOE', 'text': 'Thank you.'},
#  {'timestamp': '00:27:39',
#   'speaker': 'KIM',
#   'text': 'You can charge it to her.'},
#  {'timestamp': '00:27:41',
#   'speaker': 'KHLOE',
#   'text': 'Yeah, charge it to her account. Bye.'},
#  {'timestamp': '00:27:43', 'speaker': 'KIM', 'text': 'Bye-bye.'},
#  {'timestamp': '00:27:44', 'speaker': 'KHLOE', 'text': 'Bruce, got it.'},
#  {'timestamp': '00:27:45', 'speaker': 'KHLOE', 'text': 'Come on.'},
#  {'timestamp': '00:27:46', 'speaker': 'KIM', 'text': 'Mission accomplished.'},
#  {'timestamp': '00:27:47', 'speaker': 'BRUCE', 'text': 'Right.'},
#  {'timestamp': '00:27:48',
#   'speaker': 'BRUCE',
#   'text': 'Should we wait here, or what?'},
#  {'timestamp': '00:27:50',
#   'speaker': 'KHLOE',
#   'text': "Yeah, we're gonna wait here."},
#  {'timestamp': '00:27:52',
#   'speaker': 'KHLOE',
#   'text': "She said she's on her way."},
#  {'timestamp': '00:27:53',
#   'speaker': 'BRUCE',
#   'text': "I feel like it's, like, we're the cops."},
#  {'timestamp': '00:27:55', 'speaker': 'BRUCE', 'text': "We're on stakeout."},
#  {'timestamp': '00:27:56', 'speaker': 'BRUCE', 'text': 'This is wonderful.'},
#  {'timestamp': '00:27:57', 'speaker': 'KHLOE', 'text': 'This is a stakeout.'},
#  {'timestamp': '00:27:58',
#   'speaker': 'BRUCE',
#   'text': 'This is the stakeout?'},
#  {'timestamp': '00:28:01',
#   'speaker': 'KHLOE',
#   'text': "So, now that we're playing a waiting game..."},
#  {'timestamp': '00:28:03',
#   'speaker': 'BRUCE',
#   'text': "All right, I can't see."},
#  {'timestamp': '00:28:05',
#   'speaker': 'BRUCE',
#   'text': "I'm gonna move up to the front seat."},
#  {'timestamp': '00:28:08', 'speaker': 'KHLOE', 'text': 'Oh, sorry.'},
#  {'timestamp': '00:28:13',
#   'speaker': 'BRUCE',
#   'text': 'All right, where is she?'},
#  {'timestamp': '00:28:15',
#   'speaker': 'BRUCE',
#   'text': 'And I think you should make...'},
#  {'timestamp': '00:28:16',
#   'speaker': 'BRUCE',
#   'text': 'Oh, you got the phone call already?'},
#  {'timestamp': '00:28:18', 'speaker': 'KHLOE', 'text': 'Yeah.'},
#  {'timestamp': '00:28:19', 'speaker': 'BRUCE', 'text': 'Okay.'},
#  {'timestamp': '00:28:20', 'speaker': 'KHLOE', 'text': 'Come on, Kris.'},
#  {'timestamp': '00:28:22', 'speaker': 'BRUCE', 'text': 'Come on, Kris.'},
#  {'timestamp': '00:28:25',
#   'speaker': 'KHLOE',
#   'text': "Here we are at a stakeout, and literally it's been an hour, Kris is still not here, my ass is numb-- I mean, being a spy is really hard."},
#  {'timestamp': '00:28:37',
#   'speaker': 'BRUCE',
#   'text': "There... she's parking."},
#  {'timestamp': '00:28:39', 'speaker': 'KHLOE', 'text': 'Oh... yeah.'},
#  {'timestamp': '00:28:41',
#   'speaker': 'KHLOE',
#   'text': "You don't need to show 'em that."},
#  {'timestamp': '00:28:52', 'speaker': 'BRUCE', 'text': 'All right, call her.'},
#  {'timestamp': '00:28:53', 'speaker': 'BRUCE', 'text': 'Now.'},
#  {'timestamp': '00:28:55', 'speaker': 'KRIS ', 'text': 'Hello?'},
#  {'timestamp': '00:29:02', 'speaker': 'KHLOE', 'text': 'Kris Jenner...'},
# ...
#   'text': 'Everything is gentle in and gentle out.'},
#  {'timestamp': '00:38:57',
#   'speaker': 'TEACHER',
#   'text': 'So I want you to take a deep breath through your nose.'},
#  {'timestamp': '00:39:03',
#   'speaker': 'TEACHER',
#   'text': 'Open your mouth and relax it.'},
#  {'timestamp': '00:39:14',
#   'speaker': 'KOURTNEY',
#   'text': "I believe that everything's going to be okay."},
#  {'timestamp': '00:39:16',
#   'speaker': 'KOURTNEY',
#   'text': "We're both totally on the same page now, and just moving forward in the right direction."},
#  {'timestamp': '00:39:41',
#   'speaker': 'KIM',
#   'text': "So, what's, like, your plan?"},
#  {'timestamp': '00:39:44',
#   'speaker': 'KIM',
#   'text': 'Like, where are you going to stay?'},
#  {'timestamp': '00:39:46',
#   'speaker': 'ROBERT',
#   'text': 'When I get there, I\'m just going to go get a hotel room and, uh, I\'ll probably hit her up when I\'m out there, and just let her know, like, "Look, I\'m out here.'},
#  {'timestamp': '00:39:54',
#   'speaker': 'ROBERT',
#   'text': 'I came out here to see you, and like, I\'m being for real."'},
#  {'timestamp': '00:40:01',
#   'speaker': 'ROBERT',
#   'text': "As much as I don't agree with Rob going to New York, I really get what Rob is going through because I used to go and fly to see Reggie when we were broken up."},
#  {'timestamp': '00:40:10',
#   'speaker': 'ROBERT',
#   'text': "He's my little brother."},
#  {'timestamp': '00:40:11',
#   'speaker': 'ROBERT',
#   'text': "I'm going to support him no matter what."},
#  {'timestamp': '00:40:13', 'speaker': 'KIM', 'text': 'Hey, okay.'},
#  {'timestamp': '00:40:18',
#   'speaker': 'KIM',
#   'text': 'I am just taking Rob to the airport.'},
#  {'timestamp': '00:40:21',
#   'speaker': 'KIM',
#   'text': "I'm going to call you as soon as I'm done."},
#  {'timestamp': '00:40:23', 'speaker': 'KIM', 'text': 'Bye.'},
#  {'timestamp': '00:40:25',
#   'speaker': 'ROBERT',
#   'text': 'I just got this email from Adrienne.'},
#  {'timestamp': '00:40:27', 'speaker': 'KIM', 'text': 'What?'},
#  {'timestamp': '00:40:28', 'speaker': 'KIM', 'text': 'What does it say?'},
#  {'timestamp': '00:40:29', 'speaker': 'ROBERT', 'text': 'Wait, pull over.'},
#  {'timestamp': '00:40:30',
#   'speaker': 'ROBERT',
#   'text': 'All of a sudden, I get an email.'},
#  {'timestamp': '00:40:33', 'speaker': 'KIM', 'text': "What's going on?"},
#  {'timestamp': '00:40:34',
#   'speaker': 'KIM',
#   'text': 'Why are you making me pull over?'},
#  {'timestamp': '00:40:35',
#   'speaker': 'ROBERT',
#   'text': "Because I just got an email that's from her.[ Female Announcer ] We were learned regenerist beat the $100 cream."},
#  {'timestamp': '00:40:47',
#   'speaker': 'ROBERT',
#   'text': 'Floored when we whipped the $350 cream.'},
#  {'timestamp': '00:40:50',
#   'speaker': 'ROBERT',
#   'text': 'And finally, flabbergasted when we creamed the $700 cream!'},
#  {'timestamp': '00:40:55',
#   'speaker': 'ROBERT',
#   'text': "For under $30 olay regenerist micro-sculpting cream, according to a european independent study, hydrates better and longer than 32 of the world's most expensive creams."},
#  {'timestamp': '00:41:05',
#   'speaker': 'ROBERT',
#   'text': 'Fantastic. phenomenal.'},
#  {'timestamp': '00:41:08', 'speaker': 'ROBERT', 'text': 'Olay regenerist.'},
#  {'timestamp': '00:41:09',
#   'speaker': 'ROBERT',
#   'text': "Love the skin you're in."},
#  {'timestamp': '00:41:10',
#   'speaker': 'ROBERT',
#   'text': 'For hundreds and hundreds less.'},
#  {'timestamp': '00:43:17',
#   'speaker': 'ROBERT',
#   'text': 'I just got this email from Adrienne.'},
#  {'timestamp': '00:43:19', 'speaker': 'KIM', 'text': 'What?'},
#  {'timestamp': '00:43:20', 'speaker': 'KIM', 'text': 'What does it say?'},
#  {'timestamp': '00:43:21', 'speaker': 'ROBERT', 'text': 'Wait, pull over.'},
#  {'timestamp': '00:43:22', 'speaker': 'KIM', 'text': "What's going on?"},
#  {'timestamp': '00:43:23',
#   'speaker': 'KIM',
#   'text': 'Why are you making me pull over?'},
#  {'timestamp': '00:43:24',
#   'speaker': 'ROBERT',
#   'text': "Because I just got an email that's from her."},
#  {'timestamp': '00:43:28',
#   'speaker': 'ROBERT',
#   'text': '"Don\'t take this email the wrong way, but this is from the new man in her life."'},
#  {'timestamp': '00:43:33', 'speaker': 'ROBERT', 'text': 'Yeah.'},
#  {'timestamp': '00:43:34',
#   'speaker': 'ROBERT',
#   'text': '"We\'re trying to start off on the right note and you\'re really not making it easy.'},
#  {'timestamp': '00:43:38',
#   'speaker': 'ROBERT',
#   'text': "Her Blackberry goes off every minute and it's you almost every time."},
#  {'timestamp': '00:43:43',
#   'speaker': 'ROBERT',
#   'text': "I can't imagine what you guys really have to discuss after all this time."},
#  {'timestamp': '00:43:47',
#   'speaker': 'ROBERT',
#   'text': "It's honestly annoying and unhealthy for our relationship."},
#  {'timestamp': '00:43:49',
#   'speaker': 'ROBERT',
#   'text': "I respect what you guys had in the past, but according to her, it's clearly over."},
#  {'timestamp': '00:43:55', 'speaker': 'ROBERT', 'text': 'Thanks, Dogs1."'},
#  {'timestamp': '00:44:02', 'speaker': 'ROBERT', 'text': "I'm turning around."},
#  {'timestamp': '00:44:03',
#   'speaker': 'ROBERT',
#   'text': "Like, you're not even going to New York."},
#  {'timestamp': '00:44:05', 'speaker': 'ROBERT', 'text': "I'm sorry."},
#  {'timestamp': '00:44:06', 'speaker': 'ROBERT', 'text': 'You just...'},
#  {'timestamp': '00:44:07',
#   'speaker': 'KIM',
#   'text': 'On our way to the airport, on our way to the airport, you get an email from him, like, "Sorry." But this isn\'t the biggest sign?'},
#  {'timestamp': '00:44:14',
#   'speaker': 'ROBERT',
#   'text': "I've done every single thing."},
#  {'timestamp': '00:44:17',
#   'speaker': 'ROBERT',
#   'text': "I've made myself look like an idiot."},
#  {'timestamp': '00:44:19',
#   'speaker': 'ROBERT',
#   'text': 'I made myself, you know...'},
#  {'timestamp': '00:44:21',
#   'speaker': 'KIM',
#   'text': "And that's what you do for someone that you love."},
#  {'timestamp': '00:44:23',
#   'speaker': 'KIM',
#   'text': "You do it and if you've tried everything you can, and they're not, you know, giving you back what you need in return..."},
#  {'timestamp': '00:44:30', 'speaker': 'ROBERT', 'text': 'And it sucks.'},
#  {'timestamp': '00:44:31',
#   'speaker': 'KIM',
#   'text': "After you've tried everything, then now you know you have to move on."},
#  {'timestamp': '00:44:34',
#   'speaker': 'KIM',
#   'text': 'And this was the biggest sign ever.'},
#  {'timestamp': '00:44:36',
#   'speaker': 'ROBERT',
#   'text': "As hard as it is to let go of the love of my life, I needed to learn that cheating isn't acceptable."},
#  {'timestamp': '00:44:42',
#   'speaker': 'ROBERT',
#   'text': "I'll never, ever do this to my wife, to my future girlfriend."},
#  {'timestamp': '00:44:45',
#   'speaker': 'ROBERT',
#   'text': "It sucks so much and I'm, like, in so much pain, but I have to move on and it just... sucks."},
#  {'timestamp': '00:44:53', 'speaker': 'ROBERT', 'text': 'I just...'},
#  {'timestamp': '00:44:54', 'speaker': 'ROBERT', 'text': "I'm, like..."},
#  {'timestamp': '00:44:57',
#   'speaker': 'ROBERT',
#   'text': "I just can't believe that, like, I loved her so much."},
#  {'timestamp': '00:45:19',
#   'speaker': 'BRUCE',
#   'text': "All right, we're here."},
#  {'timestamp': '00:45:34',
#   'speaker': 'KRIS',
#   'text': 'Okay, show me your fabulous toy store, honey.'},
#  {'timestamp': '00:45:39', 'speaker': 'BRUCE', 'text': 'Come on.'},
#  {'timestamp': '00:45:40', 'speaker': 'KRIS', 'text': 'I feel really bad.'},
#  {'timestamp': '00:45:41',
#   'speaker': 'KRIS',
#   'text': "I really didn't look at the big picture of Bruce's spending, so I have the perfect way to make this whole thing up to Bruce."},
#  {'timestamp': '00:45:49',
#   'speaker': 'BRUCE',
#   'text': "I'm very excited about this."},
#  {'timestamp': '00:45:51',
#   'speaker': 'BRUCE',
#   'text': "Don't dampen my enthusiasm."},
#  {'timestamp': '00:45:52',
#   'speaker': 'BRUCE',
#   'text': "It's like a good pair of Manolo Blahniks."},
#  {'timestamp': '00:45:55', 'speaker': 'KRIS', 'text': 'Knock yourself out.'},
#  {'timestamp': '00:45:56',
#   'speaker': 'BRUCE',
#   'text': 'Think of it that way.'},
#  {'timestamp': '00:45:58',
#   'speaker': 'BRUCE',
#   'text': 'We need that in the house.'},
#  {'timestamp': '00:45:59',
#   'speaker': 'BRUCE',
#   'text': 'The kids would like that.'},
#  {'timestamp': '00:46:00',
#   'speaker': 'KRIS',
#   'text': "No, we don't need that in the house."},
#  {'timestamp': '00:46:02',
#   'speaker': 'KRIS',
#   'text': 'Okay, show me what the 700 looks like.'},
#  {'timestamp': '00:46:04',
#   'speaker': 'BRUCE',
#   'text': 'Well, there it is, honey.'},
#  {'timestamp': '00:46:06', 'speaker': 'KRIS', 'text': "It's beautiful."},
#  {'timestamp': '00:46:07',
#   'speaker': 'BRUCE',
#   'text': "And you're buying it for me."},
#  {'timestamp': '00:46:09', 'speaker': 'KRIS', 'text': 'Okay, great.'},
#  {'timestamp': '00:46:09', 'speaker': 'KRIS', 'text': "I'm happy to do that."},
#  {'timestamp': '00:46:10',
#   'speaker': 'KRIS',
#   'text': 'All right, so how much is this helicopter?'},
#  {'timestamp': '00:46:13', 'speaker': 'CLERK', 'text': 'Close to $3,000.'},
#  {'timestamp': '00:46:16', 'speaker': 'CLERK', 'text': 'Mm-hmm.'},
#  {'timestamp': '00:46:18', 'speaker': 'CLERK', 'text': 'Yeah.'},
#  {'timestamp': '00:46:19',
#   'speaker': 'KRIS',
#   'text': 'For this-- For this toy?'},
#  {'timestamp': '00:46:21',
#   'speaker': 'BRUCE',
#   'text': "Well, it's not a toy, honey, this is a very sophisticated piece of equipment."},
#  {'timestamp': '00:46:25',
#   'speaker': 'BRUCE',
#   'text': 'I mean, this is like what the pros use.'},
#  {'timestamp': '00:46:27', 'speaker': 'KRIS', 'text': 'There you go, honey.'},
#  {'timestamp': '00:46:28', 'speaker': 'BRUCE', 'text': 'Throw it down.'},
#  {'timestamp': '00:46:29', 'speaker': 'KRIS', 'text': 'Have a good time.'},
#  {'timestamp': '00:46:30', 'speaker': 'BRUCE', 'text': 'Thanks.'},
#  {'timestamp': '00:46:31',
#   'speaker': 'KRIS',
#   'text': 'You work really hard and you deserve to have what you want and to have fun in life and this is your hobby, so go for it.'},
#  {'timestamp': '00:46:38', 'speaker': 'KRIS', 'text': "I think it's cool."},
#  {'timestamp': '00:46:39', 'speaker': 'BRUCE', 'text': 'All right.'},
#  {'timestamp': '00:46:40', 'speaker': 'BRUCE', 'text': 'Okay.'},
#  {'timestamp': '00:46:41',
#   'speaker': 'BRUCE',
#   'text': 'I have no problem with that.'},
#  {'timestamp': '00:46:43',
#   'speaker': 'BRUCE',
#   'text': "I guarantee, no matter what I spend here, it's a lot less than what you do."},
#  {'timestamp': '00:46:48',
#   'speaker': 'KRIS',
#   'text': "Honey, I think it's good you put your foot down."},
#  {'timestamp': '00:46:51',
#   'speaker': 'KRIS',
#   'text': 'I think actually, you getting mad at me was actually kind of sexy.'},
#  {'timestamp': '00:46:54', 'speaker': 'BRUCE', 'text': 'Really?'},
#  {'timestamp': '00:46:54', 'speaker': 'KRIS', 'text': 'Yeah.'},
#  {'timestamp': '00:46:55',
#   'speaker': 'BRUCE',
#   'text': 'I got to try that more often.'},
#  {'timestamp': '00:46:56',
#   'speaker': 'KRIS',
#   'text': 'I know, you ought to try that more often.'},
#  {'timestamp': '00:46:58',
#   'speaker': 'KRIS',
#   'text': "Get your toy and let's go."},
#  {'timestamp': '00:47:00', 'speaker': 'BRUCE', 'text': 'Okay, thank you.'},
#  {'timestamp': '00:47:01', 'speaker': 'BRUCE', 'text': 'Thank you, honey.'},
#  {'timestamp': '00:47:01', 'speaker': 'KRIS', 'text': "Let's go, baby."},
#  {'timestamp': '00:47:02',
#   'speaker': 'BRUCE',
#   'text': "You're so sweet, honey."},
#  {'timestamp': '00:47:04', 'speaker': 'KRIS', 'text': 'I know.'},
#  {'timestamp': '00:47:04', 'speaker': 'KRIS', 'text': 'So are you.'},
#  {'timestamp': '00:47:05', 'speaker': 'BRUCE', 'text': 'See you guys later.'},
#  {'timestamp': '00:47:06',
#   'speaker': 'BRUCE',
#   'text': "I promise I won't crash it."},
#  {'timestamp': '00:47:07', 'speaker': 'KRIS', 'text': 'Bye, everybody.'},
#  {'timestamp': '00:47:09', 'speaker': 'KRIS', 'text': 'Thank you!'},
#  {'timestamp': '00:47:13',
#   'speaker': 'KHLOE',
#   'text': 'So, are we not going to the movies?'},
#  {'timestamp': '00:47:15',
#   'speaker': 'KHLOE',
#   'text': "'Cause no one's doing anything."},
#  {'timestamp': '00:47:16', 'speaker': 'KHLOE', 'text': "I don't get it."},
#  {'timestamp': '00:47:17',
#   'speaker': 'ROBERT',
#   'text': "I'm actually trying to save this movie for this date that I have."},
#  {'timestamp': '00:47:21', 'speaker': 'KHLOE', 'text': 'Yeah, right.'},
#  {'timestamp': '00:47:22', 'speaker': 'KHLOE', 'text': 'Well, what?'},
#  {'timestamp': '00:47:23',
#   'speaker': 'KHLOE',
#   'text': 'When did you meet her?'},
#  {'timestamp': '00:47:24', 'speaker': 'KHLOE', 'text': "I'm so proud of you."},
#  {'timestamp': '00:47:25',
#   'speaker': 'ROBERT',
#   'text': 'Look, she gave this to me at Katsuya.'},
#  {'timestamp': '00:47:28', 'speaker': 'ROBERT', 'text': 'An Armenian girl.'},
#  {'timestamp': '00:47:31',
#   'speaker': 'KHLOE',
#   'text': '"Call me. Violet." With a happy face.'},
#  {'timestamp': '00:47:33',
#   'speaker': 'KHLOE',
#   'text': 'So, by going on this movie date, does that mean you are over Adrienne?'},
#  {'timestamp': '00:47:37',
#   'speaker': 'ROBERT',
#   'text': "I mean, it's my way of getting over her."},
#  {'timestamp': '00:47:41', 'speaker': 'KHLOE', 'text': 'I told you.'},
#  {'timestamp': '00:47:42',
#   'speaker': 'KHLOE',
#   'text': "Cutting yourself off from the outside world and, like, waiting for Adrienne, that's never going to do anything for you."},
#  {'timestamp': '00:47:47', 'speaker': 'KHLOE', 'text': 'So, wait.'},
#  {'timestamp': '00:47:47',
#   'speaker': 'KHLOE',
#   'text': 'So that means no movie for us.'},
#  {'timestamp': '00:47:49', 'speaker': 'ROBERT', 'text': "No, it isn't."},
#  {'timestamp': '00:47:50', 'speaker': 'KHLOE', 'text': "You're saving it?"},
#  {'timestamp': '00:47:51',
#   'speaker': 'SCOTT',
#   'text': 'We could still go, Khlo.'},
#  {'timestamp': '00:47:53', 'speaker': 'KYLIE', 'text': 'Can I come?'},
#  {'timestamp': '00:47:54', 'speaker': 'KHLOE', 'text': "We'll all just go."},
#  {'timestamp': '00:47:55', 'speaker': 'ROBERT', 'text': 'Yeah.'},
#  {'timestamp': '00:47:56',
#   'speaker': 'KHLOE',
#   'text': "Well, Rob, I'm so happy you're moving on."},
#  {'timestamp': '00:47:59',
#   'speaker': 'ROBERT',
#   'text': "There's more love out there."},
#  {'timestamp': '00:48:01',
#   'speaker': 'KHLOE',
#   'text': 'There is and it begins with us.'},
#  {'timestamp': '00:48:03', 'speaker': 'ROBERT', 'text': 'With Kylie.'},
#  {'timestamp': '00:48:05',
#   'speaker': 'KHLOE',
#   'text': "Kylie, don't go to him."},
#  {'timestamp': '00:48:07',
#   'speaker': 'KHLOE',
#   'text': 'Kylie, pick or choose, now.'},
#  {'timestamp': '00:48:08', 'speaker': 'KYLIE', 'text': "You're mean to me."},
#  {'timestamp': '00:48:09', 'speaker': 'KHLOE', 'text': "I'm mean?"},
#  {'timestamp': '00:48:10', 'speaker': 'KYLIE', 'text': 'Robert would never--'},
#  {'timestamp': '00:48:10',
#   'speaker': 'ROBERT',
#   'text': 'All right, all right, all right.'},
#  {'timestamp': '00:48:13', 'speaker': 'KHLOE', 'text': "You're dead, Kylie."},
#  {'timestamp': '00:48:18',
#   'speaker': 'KRIS',
#   'text': 'Next onKeeping Up With the Kardashians:'},
#  {'timestamp': '00:48:18',
#   'speaker': 'KIM',
#   'text': 'I found the dog walking around in Calabasas.'},
#  {'timestamp': '00:48:21',
#   'speaker': 'WOMAN',
#   'text': 'She has a condition called pyometra.'},
#  {'timestamp': '00:48:23', 'speaker': 'KIM', 'text': "I can't watch that."},
#  {'timestamp': '00:48:25', 'speaker': 'ROBERT', 'text': 'Just do it, bro.'},
#  {'timestamp': '00:48:27',
#   'speaker': 'BRUCE',
#   'text': 'Rob moving back in-- not a good thing.'},
#  {'timestamp': '00:48:30',
#   'speaker': 'BRUCE',
#   'text': 'Hey, what the hell are you guys doing?!'},
#  {'timestamp': '00:48:32',
#   'speaker': 'BRUCE',
#   'text': "I'm sick and tired of you babying this little kid."},
#  {'timestamp': '00:48:33', 'speaker': 'KRIS', 'text': "I don't baby him."},
#  {'timestamp': '00:48:34', 'speaker': 'BRUCE', 'text': "He's 22 years old!"},
#  {'timestamp': '00:48:39',
#   'speaker': 'BRUCE',
#   'text': 'Bill is getting his pilot license.'},
#  {'timestamp': '00:48:41',
#   'speaker': 'BRUCE',
#   'text': 'I have to get rid of my fear of flying.'}]

# %%
def create_word_occurrence_matrix(
    tokenize_method,
    input_transcripts,
    input_speakers,
    input_good_types):
    """Returns a numpy array of shape n_speakers by n_good_types such that the 
    entry (ij) indicates how often speaker i says word j.
    
    Params: {tokenize_method: Function (a -> b),
             input_transcripts: Tuple List,
             input_speakers: List,
             input_good_types: List}
    Returns: Numpy Array
    """

    # initialize the matrix
    word_occurrence_matrix = np.zeros((n_speakers,n_good_types))

    for transcript in input_transcripts:
        # deal with each sentence
        for sentence in transcript[1]:
            # get the speaker name
            speaker = sentence['speaker']
            if speaker in input_speakers:
                # tokenize the sentence
                tokens = tokenize_method(sentence['text'])
                for token in tokens:
                    if token in input_good_types:
                        word_occurrence_matrix[input_speakers.index(speaker)][input_good_types.index(token)] += 1
        
    return word_occurrence_matrix
# Out:
# array([[542.,   0.,   0., ...,   0.,   0.,   0.],
#        [122.,   0.,   0., ...,   1.,   0.,   1.],
#        [951.,   0.,   0., ...,   0.,   0.,   0.],
#        ...,
#        [927.,   0.,   0., ...,   0.,   1.,   0.],
#        [410.,   0.,   1., ...,   0.,   0.,   0.],
#        [268.,   4.,   0., ...,   0.,   0.,   1.]])

# %%
word_matrix = create_word_occurrence_matrix(tokenize,deduped_transcripts,good_speakers,good_types)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that create_word_freq_array returns the correct output"""
assert sum(word_matrix[0]) > 26000.0
assert sum(word_matrix[:,3]) > 40 and sum(word_matrix[:,3]) < 50
assert type(word_matrix) == np.ndarray

# %% [markdown]
# ## Question 9b (Free Response): Character Word Occurrences
#
# In the cell below, output the *top 10 most occurring words used by each character*, again in descending order, in the following format (if you encounter ties, then any ordering is acceptable):
#
# **Answer format**:
#
# ```
# CHARACTER_NAME_A
# word_1
# word_2
# ...
# word_10
#
# CHARACTER_NAME_B
# word_1
# word_2
# ...
# word_10
#
# ...
# ```

# %%
for speaker in range(n_speakers):
    print(good_speakers[speaker])
    word_array = np.array(word_matrix[speaker])
    for i in range(10):
        index = np.argmax(word_array)
        print(good_types[index])
        word_array[index] = 0
# Out:
# BRUCE
# t
# is
# of
# what
# m
# in
# re
# know
# all
# on
# JONATHAN
# m
# t
# is
# of
# we
# that
# what
# are
# don
# me
# KHLOE
# t
# is
# this
# m
# my
# so
# just
# me
# in
# of
# KIM
# m
# t
# my
# just
# so
# this
# is
# me
# have
# for
# KOURTNEY
# like
# is
# we
# this
# my
# just
# m
# so
# in
# don
# KRIS
# of
# what
# is
# have
# this
# re
# so
# in
# my
# really
# ROBERT
# m
# t
# her
# my
# get
# of
# like
# this
# got
# know
# SCOTT
# what
# me
# m
# in
# do
# like
# is
# just
# this
# re

# %% [markdown]
# ## Question 9c (Code Completion): Character Word Occurrences
#
# Using your `word_matrix`, identify the characters (in descending order of number of occurrences) who have said **all** of the following words: `["brother", "book", "best"]`.
#
# Please note: a character must have spoken each word at least once to be included in your answer (if you encounter ties, then any ordering is acceptable).
#
# In the cell below, output your answer in the following format:
#
# **Answer format**:
#
# ```
# brother
# CHARACTER_NAME_A occurrences_brother_A
# CHARACTER_NAME_B occurrences_brother_B
# ...
#
# book
# CHARACTER_NAME_A occurrences_book_A
# CHARACTER_NAME_B occurrences_book_B
# ...
#
# best
# CHARACTER_NAME_A occurrences_best_A
# CHARACTER_NAME_B occurrences_best_B
# ...
# ```

# %%
interesting_words = ["brother", "book", "best"]

# %%
interesting_words_index = [good_types.index(word) for word in interesting_words]
word_array = word_matrix[...,interesting_words_index]

# print(word_array)

sayitall_speaker = []

for speaker in range(n_speakers):
    if(word_array[speaker][0] > 0 and  word_array[speaker][1] > 0 and word_array[speaker][1] > 0 ):
        sayitall_speaker.append(good_speakers[speaker])

for word in interesting_words:
    print(word)
    for speaker in sayitall_speaker:
        print(speaker, int(word_array[good_speakers.index(speaker)][interesting_words.index(word)]))
    print('')
# Out:
# brother
# BRUCE 1
# KIM 44
# KOURTNEY 3
# KRIS 1
# SCOTT 2
#
# book
# BRUCE 2
# KIM 4
# KOURTNEY 1
# KRIS 6
# SCOTT 2
#
# best
# BRUCE 16
# KIM 20
# KOURTNEY 20
# KRIS 27
# SCOTT 4

# %% [markdown]
# ## Question 10 (Code Completion): Word Character Counts
#
# In the questions below you will now be asked to determine *how many characters have used a specific word*? For example, how many characters have ever said "botox" in the show?
#
# The function below will require you to use the `word_matrix` from above to return a 1-D numpy array that reports the number of `good_speakers` that have uttered each word within `good_types`.
# The i-th entry of your answer array `word_character_count_array[i]` should be the number of characters that have uttered the word `good_types[i]`.
#
# Hint! Numpy is your friend :-)

# %%
def create_word_character_count_array(word_freq_matrix):
    """Returns a numpy array of shape (n_good_types,) such that the 
    entry i indicates how many good_speakers have uttered word i.
    
    Params: { word_freq_matrix: a numpy matrix of shape (n_speakers, n_good_types) }
    
    Hint: You may want to consult the numpy documentation to make this easy.
    """
    word_freq_matrix = word_freq_matrix.astype(bool).astype(int)
    word_character_count_array = np.sum(word_freq_matrix, axis=0)
    return word_character_count_array

# %%
word_matrix
# Out:
# array([[542.,   0.,   0., ...,   0.,   0.,   0.],
#        [122.,   0.,   0., ...,   1.,   0.,   1.],
#        [951.,   0.,   0., ...,   0.,   0.,   0.],
#        ...,
#        [927.,   0.,   0., ...,   0.,   1.,   0.],
#        [410.,   0.,   1., ...,   0.,   0.,   0.],
#        [268.,   4.,   0., ...,   0.,   0.,   1.]])

# %%
word_character_count_array = create_word_character_count_array(word_matrix)
word_character_count_array
# Out:
# array([8, 2, 2, ..., 1, 1, 2])

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that create_character_word_count_array returns the correct output"""
assert type(word_character_count_array) == np.ndarray
assert word_character_count_array[0] == 8
assert word_character_count_array[1] == 2

# %% [markdown]
# ## Question 10b (Free Response): Word Character Counts
#
# What are the first 10 words (sorted in alphabetical order) that are said by **at least 5** characters?
#
# In the cell below, give your answer in the following format:
#
# **Answer format**:
#
# ```
# word_1
# word_2
# ...
# word_10
# ```

# %%
# Out:
# array([3063, 1191, 4049, ..., 2767, 2714,    0])

# %%
index = 0
for i in range(10):
    while not(word_character_count_array[index] >= 5):
        index += 1
    print(good_types[index])
    index += 1
# Out:
# a
# able
# about
# absolutely
# accept
# access
# account
# act
# acting
# active

# %% [markdown]
# ## Question 11 (Code Completion): Specific Word Usage by Character
#
# The exercise in 9b didn't help much in understanding each character's diction, because common words are used too commonly anyway. We want to give more weight to less frequent (that is, more "specific") words, as they carry more information on the particularities of the characters.
#
# A simple way to do this is to score the words according to the ratio between how often a given character said the word and how often any of the *good speakers* said it.
#
# This can be accomplished by dividing each column in the `word_array` matrix by its sum.
#
# **Note: as some words might never be said by the key characters we are considering, add 1 to the sum of each column to avoid division by 0**
#
# In the cell below, write a function that uses the methodology described above to return a weighted numpy array of *specific* words used by each character.

# %%
def create_weighted_word_freq_array(input_word_array):
    """Returns a numpy array of shape n_speakers by n_good_types such that the 
    entry (ij) indicates how often speaker i says word j weighted by the above ratio.
    
    Note: You must add 1 to the sum of each column to avoid divison by 0 issues.
    
    Params: {input_word_array: Numpy Array}
    Returns: Numpy Array
    """
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
weighted_words = create_weighted_word_freq_array(word_matrix)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that create_word_freq_array returns the correct output"""
assert sum(weighted_words[:,7]) > 0.7
assert type(weighted_words) == np.ndarray

# %% [markdown]
# ## Question 11b (Free Response): Specific Word Usage by Character
#
# Use the next cell to output the top 10 most *specific* words (in descending order) used by each character in the following format:
#
# **Answer format**:
#
# ```
# CHARACTER_NAME_A
# score_1 word_1
# score_2 word_2
# ...
# score_10 word_10
#
# CHARACTER_NAME_B
# score_1 word_1
# score_2 word_2
# ...
# score_10 word_10
#
# ...
# ```

# %%
print_top(weighted_words, show_scores=True)

# %% [markdown]
# ## Question 11c (Free Response): Specific Word Usage by Character
#
# Now we can start to see interesting differences between the characters.
#
# Create a new Markdown cell below and use it to write a paragraph discussing the differences you find most striking.

# %% [markdown]
# This is the end of Assignment 1
