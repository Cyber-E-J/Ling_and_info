# %% [markdown]
# # Assignment 2: Keeping up with social information (part 2)
#
# © Cristian Danescu-Niculescu-Mizil, 2023

# %% [markdown]
# <p style="text-align:center">
#     <img src="https://imgs.xkcd.com/comics/social_media.png" alt="xkcd Social Media: The social media reaction to this asteroid announcement has been sharply negative. Care to respond?" width="650"/><br/>(source: <a href="https://xkcd.com/1239/">xkcd.com/1239</a>)
# </p>
#
# - - -
#
# ## INFO/CS 4300: Language and Information <a class="anchor" id="guidelines"></a>
#
# > <font color='red'> **DUE**: </font>
# >
# > * <font color='red'> [PART 1] February 08, 2023 (Wednesday), 11:59pm </font>
# > * <font color='red'> [PART 2] February 15, 2023 (Wednesday), 11:59pm </font>
# >
# > (See [below](#contents) for what constitutes [part 1](#part1) and what constitutes [part 2](#part2).)
#
# This assignment is an **individual** component.
#
# In this assignment we will further build upon our analysis of the transcripts from the reality TV show "[*Keeping Up With The Kardashians*](https://en.wikipedia.org/wiki/Keeping_Up_with_the_Kardashians)" from where we left off since Assignment 1. We will try to uncover some simple social dynamics that are shown through language using various statistical and linguistic techniques, to better understand conversational behavior.
#
# **Note**: While the assignment is straightforward, it introduces several critical ways of analyzing conversations, and is expectedly (definitely) longer than completable-in-one-day's work. We strongly recommend that you start with the assignment early so as to not rush with it in the end. Happy conversational analysis!
#
# <u>Contributors</u>: In addition to the course staff for INFO/CS 4300 from the past runs, Tushaar Gangavarapu, Altria Wang, Kai Horstmann, and Jae Kim worked on updating this assignment, while Saif Mahmud, Raymond Chang, Yvette Hung, and Eunice Zhang were involved in testing the assignment.
#
# - - -
#
# #### Learning objectives
#
# This project aims to help you get comfortable working with the following tools, technologies, and/or concepts:
#
# * Text similarity measures (standard/generalized Jaccard similarity)
# * Plotting heatmaps in `matplotlib`
# * Advanced numpy functionality
# * Interaction strength
# * Social interaction analysis
# * Character priming
# * Conversation analysis
#
# - - -
#
# #### Academic integrity and collaboration
#
# As mentioned, this project should be completed **individually**. As a result, all University-standard academic integrity guidelines must be followed.
#
# - - -
#
# #### Guidelines
#
# * All (code) cells that contain the blocks that read `# YOUR CODE GOES HERE` are editable, and are to be completed to ensure you pass the test cases. Make sure to write your code only where it is indicated to do so.
#
# * Please delete `raise NotImplementedError()` after filling in the function code. It is only meant to be a temporary placeholder
#
# * All (text) cells that read `YOUR ANSWER GOES HERE` are free-response cells that are editable and are to be completed.
#
# * You may use any number of notebook cells to explore the data and test out your functions, although you will only be graded on the solution itself.
#
# * You are unable to modify the read-only cells.
#
# * **Do not delete the cells for optional questions, even if you do not choose to answer them.**
#
# * You should also use Markdown cells to explain your code and discuss your results when necessary. Instructions to use Markdown can be found [here](http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# * All floating point values should be printed with **2 decimal places** precision (unless otherwise stated). You can do so using the built-in round function.
#
# - - -
#
# #### Grading
#
# For code-completion questions, you will be graded on passing the public test cases we have included, as well as any hidden test cases that we have supplemented within a given amount of time to ensure that your logic is correct.
#
# For free-response questions, you will be manually graded on the quality of your answer.
#
# - - -
#
# #### Submission
#
# * This entire notebook is expected to run with an upper bound being ~1-2 minutes.
#
# * Also make sure to remove any **redundant print statements** to speed things up and prevent generating unnecessary outputs.
#
# * <font color='red'><u>Important</u></font>: You are expected to submit this notebook twice (once for part 1 submission and once for part 2 submission), as your submission for Assignment 2:
#   * For [PART 1](#part1) submission (due: 02/08), upload the entire notebook file, filling all cells *up to* [PART 2](#part2); you will *only* be graded on all the cells filled till part 2 (any cells filled beyond that will NOT be considered for part 1 grading).
#   * For [PART 2](#part2) submission (due: 02/15), ensure to have filled all the cells; you will *only* be graded on the cells spanning *between* part 2 and the end of the notebook. Any changes made to part 1 will NOT affect your part 1 score. However, you should fix any errors in your part 1 solutions because they might affect the correctness of your part 2 outputs.
#
# * Each time you submit the notebook, also submit an html copy of the notebook (you can create this by clicking File → Download as → HTML (.html)).

# %% [markdown]
# - - -
# ### Contents  <a class="anchor" id="contents"></a>
#
# * [Instructions and guidelines](#guidelines)
# * [Contents](#contents)
#
#
# * [[PART 1]](#part1) **Character interaction analyses** [<font color='red'>due: 02/08</font>]
#   * [Imports and data](#0)
#   * [[1](#1)] Similarity analysis to unfold character interactions
#     * [[1a](#1a)] Character similarity w/ Jaccard
#     * [[1b](#1b)] Character-level average similarity
#     * [[1c](#1c)] Relative uniqueness of speakers
#   * [[2](#2)] Character interaction analysis with generalized Jaccard
#     * [[2a](#2a)] Term frequency (for generalized Jaccard)
#     * [[2b](#2b)] Character similarity w/ generalized Jaccard
#     * [[2c](#2c)] Character similarity w/ Jaccard vs. generalized Jaccard
#   * [[3](#3)] Character-pair analysis
#     * [[3a](#3a)] Character-pair analysis w/ generalized Jaccard
#     * [[3b](#3b)] Relative speaker uniqueness
#   * [[4](#4)] Character interactions
#     * [[4a](#4a)] Character replies
#     * [[4b](#4b)] Communication between characters
#
#
# * [[PART 2]](#part2) **Interaction strength and social interaction patterns** [<font color='red'>due: 02/15</font>]
#   * [[5](#5)] Character-pair specific reply diction
#     * [[5a](#5a)] Words used most specifically by pairs of characters
#     * [[5b](#5b)] Building character-pair word occurrence matrix
#     * [[5c](#5c)] Weighting the character-pair word occurrences
#     * [[5d](#5d)] Analyzing character-pair specific diction
#   * [[6](#6)] Strength of interactions between speaker pairs
#     * [[6a](#6a)] Pair interaction strength
#     * [[6b](#6b)] Pair interaction strength and similarity
#     * [[6c](#6c)] Analyzing pair interaction strength and similarity
#     * [[6d](#6d)] Connecting pair interaction strength and similarity
#   * [[7](#7)] Speaker characteristics and social interaction
#     * [[7a](#7a)] Age-group and social interaction
#     * [[7b](#7b)] Weighting age-group interactions matrix
#     * [[7c](#7c)] Analyzing age-group and social interaction
#     * [[7d](#7d)] [<font color='green'>optional</font>] Other characteristics and social interaction
#   * [[8](#8)] Priming: Word choice influenced by the person being spoken to
#     * [[8a](#8a)] Character priming matrix
#     * [[8b](#8b)] Analyzing character priming findings
#     * [[8c](#8c)] Repeated words in replies
#     * [[8d](#8d)] Character priming word analysis
#     * [[8e](#8e)] [<font color='green'>optional</font>] Character priming and interaction strength
#
#
# * [Extra-credit assignment-2](#ec) [<font color='red'>due: 02/15</font>]
#
# (For those curious, the rendering of backlink to "contents" from each section, i.e., the right corner [[contents](#contents)] link, is only accessible via .ipynb notebook, it causes unexpected behavior when viewed in .html.)

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### [PART 1] Character interaction analyses <a class="anchor" id="part1"></a>
# > <font color='red'>due 02/08 11:59pm</font>

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Imports and data <a class="anchor" id="0"></a>
#
# Please do NOT import any additional modules; the following imports should be sufficient to work with. As such, you should try and use numpy functions as much as you can. To review numpy operations, see the resources on [Ed #60](https://edstem.org/us/courses/36001/discussion/2460122).

# %%
import re
import json
import os
from io import StringIO
import pickle

import numpy as np

# Plotting libraries.
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

# Imports that might help with various functionality.
import functools
import operator

# Testing libraries.
from numpy.testing import assert_almost_equal

# %%
import sys

# Ensure that your kernel is using Python-3.x.
assert sys.version_info.major == 3

# %% [markdown]
# To ensure that you are comfortable moving forward. Make sure that you are familair with the following data structures that were defined in Assignment 1, as you will be using these throughout Assignment 2:
# * `deduped_transcripts`
# * `good_types`
# * `word_matrix`
# * `good_speakers`

# %%
word_matrix [4][21]
# Out:
# 0.0

# %%
type(deduped_transcripts[0][1][0])
# Out:
# dict

# %%
# Load deduped transcripts from Assignment 1.
with open('deduped_transcripts.pickle', 'rb') as f:
    deduped_transcripts = pickle.load(f)

# Load `good_types` from Assignment 1.
with open('good_types.pickle', 'rb') as f:
    good_types = pickle.load(f)
n_good_types = len(good_types)

# Load the `word_matrix` from Assignment 1.
with open('word_matrix.pickle', 'rb') as f:
    word_matrix = pickle.load(f)

# Reusing `good_speakers` from Assignment 1.
good_speakers = [
    u'BRUCE', u'JONATHAN', u'KHLOE', u'KIM', u'KOURTNEY', u'KRIS', u'ROBERT', u'SCOTT'
]
n_good_speakers = len(good_speakers)

# %%
# Ensure that the pickled data stuctures are correct.
assert type(deduped_transcripts[0]) == tuple
assert n_good_types == 4517
assert n_good_speakers == 8

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Similarity analysis to unfold character interactions <a class="anchor" id="1"></a>
#
# #### <font color='blue'> Question 1a (code completion): Character similarity w/ Jaccard </font> <a class="anchor" id="1a"></a>
# We will begin by looking at which characters speak most similarly to each other. To analyze this, you will build a *symmetric* character-by-character matrix showing how similar each pair of characters is, then plot this matrix as a heatmap using `matplotlib imshow`. We will be using Jaccard similarity for this analysis.
#
# Jaccard similarity, $J(A, B)$, between two sets, $A$ and $B$, is computed as:
# \begin{equation}
# J(A, B) = \frac{\vert\, A \cap B \,\vert}{\vert\, A \cup B \,\vert}
# \end{equation}
#
# To fit the definition, we represent a character as a set of all words they use (as usual, we only consider "good types"). **Note that this formulation involves disregarding *how many times* a speaker said a word.**
#
# Therefore, the definition can be rewritten as ($A$ and $B$ are sets of words uttered by two distinct characters):
#
# $$ J(A, B) = \frac{\sum_{w\,\in\,\text{good types}} w \in A \,\text{and}\, w \in B}
# {\sum_{w\,\in\,\text{good types}}w \in A \,\text{or}\, w \in B} $$
#
# Since set intersection and union are symmetric operations, it follows that Jaccard similarity is also a symmetric:
#
# $$ J(A, B) = J(B, A) $$
#
# In the cell below, fulfill the function specification:

# %%
def create_j_sim_mat(input_n_speakers, input_word_matrix, input_good_types):
    """Create Jaccard similarity matrix for characters.

    Create Jaccard similarity matrix, a np.ndarray of size (`input_n_speakers`, `input_n_speakers`),
    computing the character similarity, where the entry (i, j) indicating the Jaccard similarity
    between the speakers `i` and `j`.

    Hint: To help you out, here are a few numpy operations you might find useful: np.zeros, 
    np.count_nonzero, np.sum.

    Parameters
    ----------
    input_n_speakers : int
        The number of input speakers to be chosen in constructing the Jaccard similarity matrix.
    input_word_matrix : np.ndarray
        The word occurrence matrix of (`n_good_speakers`, `n_good_types`), with the entry (i, j)
        indicating how often the speaker `i` utters word `j`.
    input_good_types : list
        An alphabetically-sorted list of all the words that appear in more than one episode 
        (referred to as "good types" in assignment 1).

    Returns
    -------
    np.ndarray
        The Jaccard similarity matrix of (`input_n_speakers`, `input_n_speakers`), with the entry
        (i, j) indicating the Jaccard similarity between the speakers `i` and `j`.
    """
    output_matrix = np.zeros((input_n_speakers, input_n_speakers))
    for i in range(input_n_speakers):
        for j in range(input_n_speakers):
            and_words = 0
            or_words = 0
            for k in range(n_good_types):
                if input_word_matrix[i][k] > 0 and input_word_matrix[j][k] > 0:
                    and_words += 1
                if input_word_matrix[i][k] > 0 or input_word_matrix[j][k] > 0:
                    or_words += 1
            output_matrix[i][j] = and_words / or_words

    return output_matrix

create_j_sim_mat(n_good_speakers, word_matrix, good_types)
# Out:
# array([[1.        , 0.28659161, 0.40452342, 0.38349515, 0.40566372,
#         0.42617215, 0.38314785, 0.36124722],
#        [0.28659161, 1.        , 0.23533594, 0.23880597, 0.24959677,
#         0.2462077 , 0.26663429, 0.30935252],
#        [0.40452342, 0.23533594, 1.        , 0.50028653, 0.47620473,
#         0.48847518, 0.39522463, 0.33810793],
#        [0.38349515, 0.23880597, 0.50028653, 1.        , 0.49492464,
#         0.46850044, 0.44525306, 0.36741768],
#        [0.40566372, 0.24959677, 0.47620473, 0.49492464, 1.        ,
#         0.45884194, 0.43335684, 0.3760393 ],
#        [0.42617215, 0.2462077 , 0.48847518, 0.46850044, 0.45884194,
#         1.        , 0.42369409, 0.35185853],
#        [0.38314785, 0.26663429, 0.39522463, 0.44525306, 0.43335684,
#         0.42369409, 1.        , 0.36481802],
#        [0.36124722, 0.30935252, 0.33810793, 0.36741768, 0.3760393 ,
#         0.35185853, 0.36481802, 1.        ]])

# %%
j_sim_matrix = create_j_sim_mat(n_good_speakers, word_matrix, good_types)

# %%
# This is an autograder test; we can test the function you just wrote above.
"""Check that `create_j_sim_mat` returns the correct output."""
assert type(j_sim_matrix) == np.ndarray
assert j_sim_matrix.shape == (8, 8)
assert j_sim_matrix[4][4] == 1
assert_almost_equal(round(j_sim_matrix[2][5], 1), 0.5)

# %% [markdown]
# To make our heatmap more interpretable we have explicitly set the range of our heatmap gradient using `vmin` and `vmax`. This means that values less than `vmin` will have the same shade as `vmin` (white) and that values more than `vmax` will have the same shade as `vmax` (black).
#
# Try varying `vmin` and `vmax` to get a better sense of speaker similarities.

# %%
plt.figure(figsize=(5, 5))
plt.imshow(j_sim_matrix, interpolation='none', cmap=plt.cm.Blues, vmin=0, vmax=0.6)
plt.colorbar()

plt.xticks(range(n_good_speakers), good_speakers, rotation=90)
plt.yticks(range(n_good_speakers), good_speakers)
plt.show()

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 1b (code completion): Character-level average similarity </font>  <a class="anchor" id="1b"></a>
#
# To better understand the relative uniqueness of speakers, we will examine average similarity measurements for each character. You will build a dictionary that contains the mean similarity measurement for each speaker ignoring the speaker's self-similarity measurement. This function should take an arbitrary matrix (for the sake of future analysis that we will do) that is ordered by `good_speakers`.
#
# Please define the function below which returns a dictionary with the following format:
# ```json
# {CHARACTER_NAME_A: avg_score_a,
#  CHARACTER_NAME_B: avg_score_b,
#  ...
# }
# ```

# %%
def avg_sim_dict(input_sim_matrix, input_good_speakers):
    """A dictionary of average Jaccard similarity scores.
    
    Returns a dictionary with the keys being speakers and the values being that character's average 
    similarity scores with all other characters (i.e., ignoring the speaker's self-similarity
    measurement).
    
    Hint: To help you out, here are a few numpy operations that might be useful: np.sum, np.average.
    
    Parameters
    ----------
    input_sim_matrix : np.ndarray
        The input similarity matrix, ordered by `input_good_speakers`.
    input_good_speakers : list
        A list of chosen "good" speakers.
    
    Returns
    -------
    dict
        A dictionary with speakers as keys and associated average similarity score as values.
    """
    output_dict = dict.fromkeys(input_good_speakers)

    for i in range(len(input_good_speakers)):
        output_dict[input_good_speakers[i]] = (np.average(input_sim_matrix[i]) * len(input_good_speakers) - 1 ) / (len(input_good_speakers) - 1)
    
    return output_dict
    
avg_sim_dict(j_sim_matrix, good_speakers)
# Out:
# {'BRUCE': 0.3786915874873376,
#  'JONATHAN': 0.2617892570484121,
#  'KHLOE': 0.40545119477639396,
#  'KIM': 0.4140976383539084,
#  'KOURTNEY': 0.41351827778098266,
#  'KRIS': 0.4091071485005812,
#  'ROBERT': 0.38744697019752167,
#  'SCOTT': 0.3526916004873333}

# %%
avg_jaccard_sim_dict = avg_sim_dict(j_sim_matrix, good_speakers)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `sim_dict` returns the correct output."""
assert type(avg_jaccard_sim_dict) == dict
assert avg_jaccard_sim_dict['JONATHAN'] > 0.2
assert avg_jaccard_sim_dict['KHLOE'], 1 > 0.4

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 1c (code completion): Relative uniqueness of speakers </font>  <a class="anchor" id="1c"></a>
#
# To more easily analyze the relative uniqueness of speakers, where the most unique speaker is the most dissimilar (i.e. lowest similarity score) to the other speakers. We will take an input average similarity dictionary and return the most and least unique speakers and their corresponding average similarity scores. As a result, we want to return a tuple of tuples in the following format:
# ```json
# ((MOST_UNIQUE_CHARACTER_NAME, LEAST_SIM_SCORE),
#  (LEAST_UNIQUE_CHARACTER_NAME, MOST_SIM_SCORE))
# ```

# %%
avg_jaccard_sim_dict
# Out:
# {'BRUCE': 0.3786915874873376,
#  'JONATHAN': 0.2617892570484121,
#  'KHLOE': 0.40545119477639396,
#  'KIM': 0.4140976383539084,
#  'KOURTNEY': 0.41351827778098266,
#  'KRIS': 0.4091071485005812,
#  'ROBERT': 0.38744697019752167,
#  'SCOTT': 0.3526916004873333}

# %%
def most_least_unique_characters(input_avg_sim_dict):
    """Returns a tuple which shows the most and least unique characters. 

    The desired tuple format should be the following: 
    ```((MOST_UNIQUE_CHARACTER_NAME, LEAST_SIM_SCORE),
        (LEAST_UNIQUE_CHARACTER_NAME, MOST_SIM_SCORE))```.
         
    Parameters
    ----------
    input_avg_sim_dict : dict
        A dictionary with speakers as keys and associated average similarity score as values.
    
    Returns
    -------
    tuple
        A tuple which shows the most and least unique characters, and their similarity scores.
    """
    
    most_unique = min(input_avg_sim_dict,key=input_avg_sim_dict.get)
    least_unique = max(input_avg_sim_dict,key=input_avg_sim_dict.get)
    return ((most_unique, input_avg_sim_dict[most_unique]), (least_unique, input_avg_sim_dict[least_unique]))
most_least_unique_characters(avg_jaccard_sim_dict)
# Out:
# (('JONATHAN', 0.2617892570484121), ('KIM', 0.4140976383539084))

# %%
most_least_tup = most_least_unique_characters(avg_jaccard_sim_dict)
print("MOST UNIQUE: {} - {:.2f}".format(*most_least_tup[0]))
print("LEAST UNIQUE: {} - {:.2f}".format(*most_least_tup[1]))
# Out:
# MOST UNIQUE: JONATHAN - 0.26
# LEAST UNIQUE: KIM - 0.41

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `most_least_sim_pairs` returns the correct output."""
assert type(most_least_tup) == tuple
assert len(most_least_tup) == 2

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Character interaction analysis with generalized Jaccard  <a class="anchor" id="2"></a>
#
# #### <font color='blue'> Question 2a (code completion): Term frequency (for generalized Jaccard) </font>  <a class="anchor" id="2a"></a>
#
# The similarity measure that we took above doesn't take into account how often the characters say a word. To account for this, we can use *generalized Jaccard*, an extension of Jaccard to weighted sets.
#
# For each word $w$ and each character $C$, we compute the frequency weight $\text{tf}(w, C)$ as the ratio between the number of times $C$ says the word $w$, and the total number of words (good types) said by $C$. For example, if we had a character named Ned, and all of the words that he said were "my name is ned stark of house stark" the $\text{tf}(stark, ned)$ would be $\frac{2}{8}$
#
# Generalized Jaccard is:
#
# $$ GJ(A, B) = \frac{\sum_{w \,\in \text{ good types}} \text{min}(\text{tf}(w, A), \text{tf}(w, B))}
# {\sum_{w \,\in \text{ good types}} \text{max}(\text{tf}(w, A), \text{tf}(w, B))} $$
#
# Note that Jaccard is equivalent to generalized Jaccard if the weights are binarized by truncating all positive weights to 1.
#
# Firstly, you will begin by defining a `tf` function below.

# %%
# To help you, we have incuded this variable which is an inverse index for `good_types`.
good_types_reverse_index = {t: i for i, t in enumerate(good_types)}
good_types_reverse_index
# Out:
# {'a': 0,
#  'aah': 1,
#  'ability': 2,
#  'able': 3,
#  'about': 4,
#  'absolute': 5,
#  'absolutely': 6,
#  'absurd': 7,
#  'accent': 8,
#  'accept': 9,
#  'acceptable': 10,
#  'accepted': 11,
#  'access': 12,
#  'accessories': 13,
#  'accessory': 14,
#  'accident': 15,
#  'accomplice': 16,
#  'accomplish': 17,
#  'account': 18,
#  'accurate': 19,
#  'acne': 20,
#  'acquaintance': 21,
#  'across': 22,
#  'act': 23,
#  'acted': 24,
#  'acting': 25,
#  'action': 26,
#  'active': 27,
#  'actor': 28,
#  'actress': 29,
#  'acts': 30,
#  'actual': 31,
#  'actually': 32,
#  'ad': 33,
#  'adam': 34,
#  'add': 35,
#  'addict': 36,
#  'addiction': 37,
#  'adding': 38,
#  'additional': 39,
#  'adjusts': 40,
#  'admit': 41,
#  'admitting': 42,
#  'adopted': 43,
#  'adopting': 44,
#  'adorable': 45,
#  'adore': 46,
#  'adrenal': 47,
#  'adrenaline': 48,
#  'adrian': 49,
#  'adrienne': 50,
#  'ads': 51,
#  'adult': 52,
#  'adults': 53,
#  'advanced': 54,
#  'advantage': 55,
#  'adventurous': 56,
#  'advice': 57,
#  'advisor': 58,
#  'advisors': 59,
#  'affect': 60,
#  'affection': 61,
#  'affectionate': 62,
#  'afford': 63,
#  'afraid': 64,
#  'africa': 65,
#  'after': 66,
#  'afternoon': 67,
#  'again': 68,
#  'against': 69,
#  'age': 70,
#  'agency': 71,
#  'agent': 72,
#  'ages': 73,
#  'aggressive': 74,
#  'ago': 75,
#  'agree': 76,
#  'agreed': 77,
#  'ah': 78,
#  'ahead': 79,
#  'ahh': 80,
#  'ain': 81,
#  'air': 82,
#  'airplanes': 83,
#  'airport': 84,
#  'airwick': 85,
#  'aisle': 86,
#  'alabama': 87,
#  'alcoholic': 88,
#  'ale': 89,
#  'alecko': 90,
#  'alex': 91,
#  'alive': 92,
#  'all': 93,
#  'allergic': 94,
#  'alley': 95,
#  'allison': 96,
#  'allow': 97,
#  'allowance': 98,
#  'allowed': 99,
#  'allowing': 100,
#  'almay': 101,
#  'almond': 102,
#  'almost': 103,
#  'alone': 104,
#  'along': 105,
#  'already': 106,
#  'also': 107,
#  'although': 108,
#  'always': 109,
#  'am': 110,
#  'amazing': 111,
#  'amen': 112,
#  'america': 113,
#  'american': 114,
#  'amigos': 115,
#  'among': 116,
#  'amount': 117,
#  'amplify': 118,
#  'amusing': 119,
#  'amy': 120,
#  'an': 121,
#  'anal': 122,
#  'and': 123,
#  'andfabric': 124,
#  'andhow': 125,
#  'ands': 126,
#  'angel': 127,
#  'angeles': 128,
#  'angels': 129,
#  'anger': 130,
#  'angry': 131,
#  'animal': 132,
#  'animals': 133,
#  'anncr': 134,
#  'anniversary': 135,
#  'announcement': 136,
#  'announcer': 137,
#  'annoy': 138,
#  'annoyed': 139,
#  'annoying': 140,
#  'anorexic': 141,
#  'another': 142,
#  'answer': 143,
#  'answering': 144,
#  'answers': 145,
#  'anti': 146,
#  'anxiety': 147,
#  'anxious': 148,
#  'any': 149,
#  'anybody': 150,
#  'anymore': 151,
#  'anyone': 152,
#  'anything': 153,
#  'anytime': 154,
#  'anyway': 155,
#  'anyways': 156,
#  'anywhere': 157,
#  'apart': 158,
#  'apartment': 159,
#  'apologize': 160,
#  'apologized': 161,
#  'apologizing': 162,
#  'apology': 163,
#  'app': 164,
#  'apparently': 165,
#  'appear': 166,
#  'appearance': 167,
#  'applause': 168,
#  'apple': 169,
#  'appliances': 170,
#  'applicator': 171,
#  'applied': 172,
#  'appointment': 173,
#  'appreciate': 174,
#  'appreciative': 175,
#  'approach': 176,
#  'appropriate': 177,
#  'approval': 178,
#  'approve': 179,
#  'approved': 180,
#  'approvedfor': 181,
#  'approving': 182,
#  'apps': 183,
#  'appsthat': 184,
#  'are': 185,
#  'area': 186,
#  'areas': 187,
#  'aren': 188,
#  'argue': 189,
#  'arguing': 190,
#  'argument': 191,
#  'arm': 192,
#  'armenia': 193,
#  'armenian': 194,
#  'arms': 195,
#  'around': 196,
#  'arrangements': 197,
#  'arrest': 198,
#  'arrested': 199,
#  'arrived': 200,
#  'arrives': 201,
#  'art': 202,
#  'articles': 203,
#  'arts': 204,
#  'as': 205,
#  'asap': 206,
#  'aside': 207,
#  'asinstructed': 208,
#  'ask': 209,
#  'asked': 210,
#  'asking': 211,
#  'asks': 212,
#  'asleep': 213,
#  'aspect': 214,
#  'ass': 215,
#  'assaulted': 216,
#  'assessment': 217,
#  'assignment': 218,
#  'assistant': 219,
#  'assuming': 220,
#  'at': 221,
#  'ata': 222,
#  'ate': 223,
#  'athlete': 224,
#  'athletic': 225,
#  'atm': 226,
#  'attack': 227,
#  'attacked': 228,
#  'attacks': 229,
#  'attention': 230,
#  'attitude': 231,
#  'attorney': 232,
#  'attracted': 233,
#  'attractive': 234,
#  'audience': 235,
#  'audition': 236,
#  'australia': 237,
#  'autograph': 238,
#  'automatic': 239,
#  'automatically': 240,
#  'available': 241,
#  'avoiding': 242,
#  'aw': 243,
#  'awake': 244,
#  'awakening': 245,
#  'awareness': 246,
#  'away': 247,
#  'awesome': 248,
#  'awful': 249,
#  'awkward': 250,
#  'aww': 251,
#  'aye': 252,
#  'b': 253,
#  'ba': 254,
#  'babe': 255,
#  'babies': 256,
#  'baby': 257,
#  'babysit': 258,
#  'baccarat': 259,
#  'bachelorette': 260,
#  'back': 261,
#  'background': 262,
#  'backhanded': 263,
#  'backpack': 264,
#  'backup': 265,
#  'backyard': 266,
#  'bacon': 267,
#  'bad': 268,
#  'badly': 269,
#  'bag': 270,
#  'bags': 271,
#  'bailing': 272,
#  'bake': 273,
#  'balance': 274,
#  'ball': 275,
#  'balls': 276,
#  'bananas': 277,
#  'band': 278,
#  'bangin': 279,
#  'bangs': 280,
#  'bar': 281,
#  'barbecue': 282,
#  'barbeque': 283,
#  'barely': 284,
#  'barf': 285,
#  'bartender': 286,
#  'based': 287,
#  'bash': 288,
#  'bashing': 289,
#  'basic': 290,
#  'basically': 291,
#  'basics': 292,
#  'basketball': 293,
#  'bassist': 294,
#  'bateman': 295,
#  'bath': 296,
#  'bathe': 297,
#  'bathroom': 298,
#  'bathtub': 299,
#  'battle': 300,
#  'bay': 301,
#  'bayer': 302,
#  'bbms': 303,
#  'be': 304,
#  'beach': 305,
#  'bear': 306,
#  'beast': 307,
#  'beat': 308,
#  'beau': 309,
#  'beautiful': 310,
#  'beauty': 311,
#  'because': 312,
#  'becauseit': 313,
#  'beckham': 314,
#  'become': 315,
#  'becoming': 316,
#  'bed': 317,
#  'bedroom': 318,
#  'bee': 319,
#  'beef': 320,
#  'been': 321,
#  'beer': 322,
#  'beers': 323,
#  'before': 324,
#  'beg': 325,
#  'begging': 326,
#  'beginning': 327,
#  'begins': 328,
#  'behave': 329,
#  'behavior': 330,
#  'behind': 331,
#  'being': 332,
#  'believe': 333,
#  'believer': 334,
#  'bella': 335,
#  'belly': 336,
#  'belt': 337,
#  'bemy': 338,
#  'ben': 339,
#  'bend': 340,
#  'benefit': 341,
#  'benefits': 342,
#  'bentley': 343,
#  'bentleys': 344,
#  'beret': 345,
#  'besides': 346,
#  'best': 347,
#  'bet': 348,
#  'beth': 349,
#  'better': 350,
#  'betty': 351,
#  'between': 352,
#  'beverly': 353,
#  'beyond': 354,
#  'bffs': 355,
#  'bg': 356,
#  'bible': 357,
#  'bid': 358,
#  'bidder': 359,
#  'bieber': 360,
#  'big': 361,
#  'bigger': 362,
#  'biggest': 363,
#  'bike': 364,
#  'biking': 365,
#  'bikini': 366,
#  'bill': 367,
#  'billboard': 368,
#  'bingo': 369,
#  'birth': 370,
#  'birthday': 371,
#  'bit': 372,
#  'bitch': 373,
#  'bitches': 374,
#  'bite': 375,
#  'bizarre': 376,
#  'black': 377,
#  'blackberry': 378,
#  'blade': 379,
#  'blah': 380,
#  'blame': 381,
#  'blaming': 382,
#  'blank': 383,
#  'blanket': 384,
#  'blast': 385,
#  'bleeding': 386,
#  'blend': 387,
#  'blending': 388,
#  'bless': 389,
#  'blessed': 390,
#  'blessing': 391,
#  'blew': 392,
#  'blind': 393,
#  'bling': 394,
#  'block': 395,
#  'blocked': 396,
#  'blog': 397,
#  'blonde': 398,
#  'blood': 399,
#  'blow': 400,
#  'blown': 401,
#  'blue': 402,
#  'blurry': 403,
#  'board': 404,
#  'boat': 405,
#  'bob': 406,
#  'bobby': 407,
#  'bod': 408,
#  'body': 409,
#  'bodyguard': 410,
#  'bold': 411,
#  'bomb': 412,
#  'bombshell': 413,
#  'bond': 414,
#  'bonding': 415,
#  'bone': 416,
#  'boned': 417,
#  'bonus': 418,
#  'boo': 419,
#  'boob': 420,
#  'boobs': 421,
#  'book': 422,
#  'booked': 423,
#  'books': 424,
#  'boom': 425,
#  'booster': 426,
#  'boots': 427,
#  'booty': 428,
#  'bore': 429,
#  'bored': 430,
#  'boring': 431,
#  'born': 432,
#  'borrow': 433,
#  'borrowed': 434,
#  'boss': 435,
#  'both': 436,
#  'bother': 437,
#  'bothering': 438,
#  'bothers': 439,
#  'botox': 440,
#  'bottle': 441,
#  'bottles': 442,
#  'bottom': 443,
#  'bottoms': 444,
#  'bought': 445,
#  'bounce': 446,
#  'boundaries': 447,
#  'bouquet': 448,
#  'bouquets': 449,
#  'bout': 450,
#  'bow': 451,
#  'bowl': 452,
#  'bowling': 453,
#  'box': 454,
#  'boxes': 455,
#  'boxing': 456,
#  'boy': 457,
#  'boyfriend': 458,
#  'boyfriends': 459,
#  'boys': 460,
#  'bra': 461,
#  'bracelet': 462,
#  'brad': 463,
#  'brain': 464,
#  'brainstorm': 465,
#  'brainwashing': 466,
#  'brake': 467,
#  'brand': 468,
#  'brandon': 469,
#  'brands': 470,
#  'bras': 471,
#  'brat': 472,
#  'break': 473,
#  'breakers': 474,
#  'breakfast': 475,
#  'breaking': 476,
#  'breaks': 477,
#  'breakup': 478,
#  'breast': 479,
#  'breath': 480,
#  'breathe': 481,
#  'breathing': 482,
#  'breckenridge': 483,
#  'bride': 484,
#  'bridesmaids': 485,
#  'bright': 486,
#  'brighten': 487,
#  'brilliant': 488,
#  'bring': 489,
#  'bringing': 490,
#  'brings': 491,
#  'britney': 492,
#  'bro': 493,
#  'brody': 494,
#  'broke': 495,
#  'broken': 496,
#  'broom': 497,
#  'brother': 498,
#  'brothers': 499,
#  'brought': 500,
#  'brown': 501,
#  'brr': 502,
#  'bruce': 503,
#  'brucey': 504,
#  'brucinator': 505,
#  'bruise': 506,
#  'bruised': 507,
#  'bruiser': 508,
#  'bruising': 509,
#  'brush': 510,
#  'bs': 511,
#  'bubbly': 512,
#  'bucks': 513,
#  'buddy': 514,
#  'budget': 515,
#  'budgets': 516,
#  'buffalo': 517,
#  'bug': 518,
#  'bugging': 519,
#  'bugs': 520,
#  'buh': 521,
#  'build': 522,
#  'building': 523,
#  'builds': 524,
#  'built': 525,
#  'bull': 526,
#  'bunch': 527,
#  'bunches': 528,
#  'bunim': 529,
#  'bunnies': 530,
#  'bunny': 531,
#  'burger': 532,
#  'burn': 533,
#  'burned': 534,
#  'burning': 535,
#  'burnt': 536,
#  'bus': 537,
#  'bush': 538,
#  'business': 539,
#  'businesses': 540,
#  'businesswomen': 541,
#  'bust': 542,
#  'busted': 543,
#  'buster': 544,
#  'busy': 545,
#  'but': 546,
#  'buts': 547,
#  'butt': 548,
#  'butter': 549,
#  'button': 550,
#  'buttons': 551,
#  'buttwith': 552,
#  'buy': 553,
#  'buying': 554,
#  'buys': 555,
#  'buzz': 556,
#  'by': 557,
#  'bye': 558,
#  'bynice': 559,
#  'c': 560,
#  'cab': 561,
#  'cabo': 562,
#  'cake': 563,
#  'calabasas': 564,
#  'calendar': 565,
#  'calendars': 566,
#  'california': 567,
#  'call': 568,
#  'called': 569,
#  'calling': 570,
#  'calls': 571,
#  'calm': 572,
#  'calories': 573,
#  'calves': 574,
#  'came': 575,
#  'camel': 576,
#  'camera': 577,
#  'cameras': 578,
#  'campaign': 579,
#  'camping': 580,
#  'campus': 581,
#  'can': 582,
#  'cancel': 583,
#  'canceled': 584,
#  'cancer': 585,
#  'cancers': 586,
#  'candidates': 587,
#  'candles': 588,
#  'candy': 589,
#  'cane': 590,
#  'canmake': 591,
#  'cannon': 592,
#  'cannot': 593,
#  'cans': 594,
#  'canyon': 595,
#  'capisce': 596,
#  'captioned': 597,
#  'captioning': 598,
#  'car': 599,
#  'carats': 600,
#  'card': 601,
#  'cardio': 602,
#  'cards': 603,
#  'care': 604,
#  'career': 605,
#  'careful': 606,
#  'cares': 607,
#  'carl': 608,
#  'carmen': 609,
#  'carol': 610,
#  'carpet': 611,
#  'carpets': 612,
#  'carpool': 613,
#  'carried': 614,
#  'carry': 615,
#  'cars': 616,
#  'case': 617,
#  'cash': 618,
#  'cashmere': 619,
#  'casual': 620,
#  'cat': 621,
#  'catch': 622,
#  'catches': 623,
#  'catching': 624,
#  'category': 625,
#  'caterer': 626,
#  'catherine': 627,
#  'cats': 628,
#  'caught': 629,
#  'cause': 630,
#  'caused': 631,
#  'cave': 632,
#  'cece': 633,
#  'celebrate': 634,
#  'celebrities': 635,
#  'celebrity': 636,
#  'cell': 637,
#  'cellulite': 638,
#  'center': 639,
#  'ceremony': 640,
#  'certain': 641,
#  'certainly': 642,
#  'certificate': 643,
#  'cha': 644,
#  'chair': 645,
#  'chairs': 646,
#  'challenge': 647,
#  'champagne': 648,
#  'champion': 649,
#  'championship': 650,
#  'chance': 651,
#  'chances': 652,
#  'chanel': 653,
#  'change': 654,
#  'changed': 655,
#  'changei': 656,
#  'changes': 657,
#  'changing': 658,
#  'chapel': 659,
#  'character': 660,
#  'charge': 661,
#  'charging': 662,
#  'charities': 663,
#  'charity': 664,
#  'charlie': 665,
#  'charm': 666,
#  'chat': 667,
#  'cheat': 668,
#  'cheated': 669,
#  'cheating': 670,
#  'cheban': 671,
#  'check': 672,
#  'checked': 673,
#  'checking': 674,
#  'cheeks': 675,
#  'cheer': 676,
#  'cheering': 677,
#  'cheerleader': 678,
#  'cheers': 679,
#  'cheese': 680,
#  'cheetah': 681,
#  'chemistry': 682,
#  'chest': 683,
#  'chew': 684,
#  'chic': 685,
#  'chick': 686,
#  'chicken': 687,
#  'chickens': 688,
#  'chicks': 689,
#  'chihuahua': 690,
#  'child': 691,
#  'children': 692,
#  'chill': 693,
#  'chillin': 694,
#  'chilling': 695,
#  'chilly': 696,
#  'chitty': 697,
#  'chloe': 698,
#  'chocolate': 699,
#  'chocolaty': 700,
#  'choice': 701,
#  'choked': 702,
#  'choline': 703,
#  'choose': 704,
#  'chop': 705,
#  'chores': 706,
#  'chose': 707,
#  'chosen': 708,
#  'chris': 709,
#  'christmas': 710,
#  'christofle': 711,
#  'christopher': 712,
#  'chronic': 713,
#  'chronicinflammatory': 714,
#  'ciao': 715,
#  'cigarette': 716,
#  'cigarettes': 717,
#  'circle': 718,
#  'city': 719,
#  'civilized': 720,
#  'class': 721,
#  'classes': 722,
#  'classic': 723,
#  'classroom': 724,
#  'classy': 725,
#  'claus': 726,
#  'clean': 727,
#  'cleaned': 728,
#  'cleaner': 729,
#  'cleanest': 730,
#  'cleaning': 731,
#  'cleans': 732,
#  'clear': 733,
#  'clearblue': 734,
#  'clearly': 735,
#  'click': 736,
#  'client': 737,
#  'clients': 738,
#  'clinically': 739,
#  'close': 740,
#  'closed': 741,
#  'closely': 742,
#  'closer': 743,
#  'closest': 744,
#  'closet': 745,
#  'closure': 746,
#  'clot': 747,
#  'clothes': 748,
#  'clothing': 749,
#  'cloths': 750,
#  'clots': 751,
#  'club': 752,
#  'clubs': 753,
#  'co': 754,
#  'coast': 755,
#  'coat': 756,
#  'coats': 757,
#  'cocaine': 758,
#  'cocktail': 759,
#  'cocktails': 760,
#  'coco': 761,
#  'coconut': 762,
#  'code': 763,
#  'coffee': 764,
#  'coincidence': 765,
#  'coke': 766,
#  'cold': 767,
#  'collagen': 768,
#  'collateral': 769,
#  'collection': 770,
#  'college': 771,
#  'color': 772,
#  'colored': 773,
#  'colorings': 774,
#  'colors': 775,
#  'com': 776,
#  'combo': 777,
#  'come': 778,
#  'comes': 779,
#  'cometo': 780,
#  'comfort': 781,
#  'comfortable': 782,
#  'comforting': 783,
#  'comfy': 784,
#  'coming': 785,
#  'command': 786,
#  'comment': 787,
#  'comments': 788,
#  'commercial': 789,
#  'commission': 790,
#  'commit': 791,
#  'commitment': 792,
#  'committed': 793,
#  'common': 794,
#  'commotion': 795,
#  'communicate': 796,
#  'communication': 797,
#  'community': 798,
#  'compak': 799,
#  'company': 800,
#  'compare': 801,
#  'compared': 802,
#  'compassion': 803,
#  'compatible': 804,
#  'competition': 805,
#  'competitive': 806,
#  'complaining': 807,
#  'complete': 808,
#  'completely': 809,
#  'component': 810,
#  'compromise': 811,
#  'compulsive': 812,
#  'computer': 813,
#  'concern': 814,
#  'concerned': 815,
#  'concert': 816,
#  'conclusion': 817,
#  'condition': 818,
#  'conditions': 819,
#  'condo': 820,
#  'condoms': 821,
#  'confidence': 822,
#  'confident': 823,
#  'confined': 824,
#  'confront': 825,
#  'confused': 826,
#  'congrats': 827,
#  'congratulations': 828,
#  'connect': 829,
#  'connected': 830,
#  'connecting': 831,
#  'connection': 832,
#  'conned': 833,
#  'conquer': 834,
#  'conscious': 835,
#  'consequences': 836,
#  'conservative': 837,
#  'consider': 838,
#  'considering': 839,
#  'constant': 840,
#  'constantly': 841,
#  'consult': 842,
#  'consultation': 843,
#  'contact': 844,
#  'contactlenses': 845,
#  'contacts': 846,
#  'container': 847,
#  'continue': 848,
#  'continuous': 849,
#  'contraception': 850,
#  'contract': 851,
#  'control': 852,
#  'controlling': 853,
#  'controlof': 854,
#  'controls': 855,
#  'convenient': 856,
#  'conversation': 857,
#  'conversations': 858,
#  'convince': 859,
#  'convo': 860,
#  'cook': 861,
#  'cookies': 862,
#  'cooking': 863,
#  'cool': 864,
#  'coolest': 865,
#  'coordinated': 866,
#  'core': 867,
#  'corner': 868,
#  'correct': 869,
#  'correcta': 870,
#  'cost': 871,
#  'costs': 872,
#  'costumes': 873,
#  'cotton': 874,
#  'couch': 875,
#  'couches': 876,
#  'could': 877,
#  'couldn': 878,
#  'counseling': 879,
#  'count': 880,
#  'counter': 881,
#  'country': 882,
#  'county': 883,
#  'couple': 884,
#  'coupon': 885,
#  'course': 886,
#  'court': 887,
#  'courthouse': 888,
#  'cover': 889,
#  'coverage': 890,
#  'covered': 891,
#  'covergirl': 892,
#  'covering': 893,
#  'covers': 894,
#  'crack': 895,
#  'cranky': 896,
#  'crap': 897,
#  'crappy': 898,
#  'crash': 899,
#  'crawl': 900,
#  'crazier': 901,
#  'craziest': 902,
#  'crazy': 903,
#  'cream': 904,
#  'creamed': 905,
#  'creams': 906,
#  'creamy': 907,
#  'create': 908,
#  'creative': 909,
#  'credit': 910,
#  'creepy': 911,
#  'crest': 912,
#  'crew': 913,
#  'crib': 914,
#  'crime': 915,
#  'crippling': 916,
#  'crisis': 917,
#  'crisp': 918,
#  'crispy': 919,
#  'cristal': 920,
#  'critic': 921,
#  'critical': 922,
#  'crocker': 923,
#  'crossed': 924,
#  'crossing': 925,
#  'crotch': 926,
#  'crowd': 927,
#  'crowee': 928,
#  'cruisers': 929,
#  'crumbs': 930,
#  'cry': 931,
#  'cryfest': 932,
#  'crying': 933,
#  'crystals': 934,
#  'cube': 935,
#  'cubicle': 936,
#  'cucumbers': 937,
#  'cuddle': 938,
#  'culture': 939,
#  'cup': 940,
#  'cupcake': 941,
#  'cupcakes': 942,
#  'curious': 943,
#  'currently': 944,
#  'cursed': 945,
#  'cushion': 946,
#  'custom': 947,
#  'customers': 948,
#  'cut': 949,
#  'cute': 950,
#  'cuter': 951,
#  'cutie': 952,
#  'cutsto': 953,
#  'cutting': 954,
#  'cuuuuut': 955,
#  'd': 956,
#  'da': 957,
#  'dad': 958,
#  'daddy': 959,
#  'daily': 960,
#  'dallas': 961,
#  'damage': 962,
#  'damaged': 963,
#  'damn': 964,
#  'dan': 965,
#  'dance': 966,
#  'dancer': 967,
#  'dancers': 968,
#  'dancing': 969,
#  'dangerous': 970,
#  'danother': 971,
#  'dare': 972,
#  'dark': 973,
#  'darkening': 974,
#  'darker': 975,
#  'darling': 976,
#  'dash': 977,
#  'dashing': 978,
#  'date': 979,
#  'dated': 980,
#  'dates': 981,
#  'dating': 982,
#  'daughter': 983,
#  'daughters': 984,
#  'dave': 985,
#  'david': 986,
#  'dawg': 987,
#  'day': 988,
#  'days': 989,
#  'daze': 990,
#  'de': 991,
#  'dead': 992,
#  'deal': 993,
#  'dealership': 994,
#  'dealing': 995,
#  'deals': 996,
#  'dealt': 997,
#  'dear': 998,
#  'dearest': 999,
#  ...}

# %%
def tf(word_w, character_c, input_word_matrix):
    """Compute the term frequency weight for a given word and character.
    
    This function determines the term frequency weight as the ratio between the number of times an 
    input character `character_c` utters word `word_w`, and the total number of words said by 
    character `character_c`.
    
    Note: Please use full precision in your answer (do NOT round). Also, be sure to use the global
    variable `good_types_reverse_index` in this method (to ensure a smaller arg list). Finally, you
    may realize that this TF compute is different from the unnormalized TF taught in the class.
    
    Hint: You may find it helpful to use np.sum.
    
    Parameters
    ----------
    word_w : str
        The word whose term frequency weight is to be computed.
    character_c : int
        The index of the character within `good_speakers`. 
    input_word_matrix : np.ndarray
        The word occurrence matrix of (`n_good_speakers`, `n_good_types`), with the entry (i, j)
        indicating how often the speaker `i` utters word `j`.
    
    Returns
    -------
    float
        The (unrounded) term frequency weight for a given word and character.
    """
    return input_word_matrix[character_c][good_types_reverse_index[word_w]] / np.sum(input_word_matrix[character_c])

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `tf` returns the correct output."""
assert (tf('hi', 3, word_matrix) * 100) > 0.10

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 2b (code completion): Character similarity w/ generalized Jaccard </font>  <a class="anchor" id="2b"></a>
#
# Now you will complete the function specification below, which will return a numpy array of character similarities computed via generalized Jaccard. For your convenience, here is the formulation of generalized Jaccard:
#
# $$ GJ(A, B) = \frac{\sum_{w \,\in \text{ good types}} \text{min}(\text{tf}(w, A), \text{tf}(w, B))}
# {\sum_{w \,\in \text{ good types}} \text{max}(\text{tf}(w, A), \text{tf}(w, B))} $$

# %%
def create_g_j_sim_mat(tf_method, input_word_matrix, input_good_types, input_n_speakers):
    """Create generalized Jaccard similarity matrix for characters.

    Create generalized Jaccard similarity matrix, an np.ndarray of size (`input_n_speakers`, 
    `input_n_speakers), computing the character similarity, where the entry (i, j) indicating the 
    generalized Jaccard similarity between the speakers `i` and `j`.

    Note: Try to minimize the use of `tf_method`.

    Parameters
    ----------
    tf_method : function
        A method to compute the term frequency weight for a given word and character. 
    input_word_matrix : np.ndarray
        The word occurrence matrix of (`n_good_speakers`, `n_good_types`), with the entry (i, j)
        indicating how often the speaker `i` utters word `j`.
    input_good_types : list
        An alphabetically-sorted list of all the words that appear in more than one episode 
        (referred to as "good types" in assignment 1).
    input_n_speakers : int
        The number of input speakers to be chosen in constructing the generalized Jaccard similarity
        matrix.

    Returns
    -------
    np.ndarray
        The generalized Jaccard similarity matrix of (`input_n_speakers`, `input_n_speakers`), with 
        the entry (i, j) indicating the generalized Jaccard similarity between the speakers `i` and
        `j`.
    """
    output_matrix = np.zeros((input_n_speakers, input_n_speakers))
    for i in range(input_n_speakers):
        for j in range(input_n_speakers):
            numerator = 0
            denominator = 0
            for word in input_good_types:
                numerator += min(tf_method(word, i, input_word_matrix), tf_method(word, j, input_word_matrix))
                denominator += max(tf_method(word, i, input_word_matrix), tf_method(word, j, input_word_matrix))
            output_matrix[i][j] = numerator / denominator
    return output_matrix

# %%
g_j_sim_matrix = create_g_j_sim_mat(tf, word_matrix, good_types, n_good_speakers)
g_avg_jaccard_sim_dict = avg_sim_dict(g_j_sim_matrix, good_speakers)
g_avg_jaccard_sim_dict
# Out:
# {'BRUCE': 0.5939768014190349,
#  'JONATHAN': 0.5411277189194043,
#  'KHLOE': 0.6409866755258911,
#  'KIM': 0.637641288014376,
#  'KOURTNEY': 0.6302798839702349,
#  'KRIS': 0.635060698209171,
#  'ROBERT': 0.5677746811151569,
#  'SCOTT': 0.5988840543411611}

# %%
g_most_least_tup = most_least_unique_characters(g_avg_jaccard_sim_dict)
print("MOST UNIQUE: {} - {:.2f}".format(*g_most_least_tup[0]))
print("LEAST UNIQUE: {} - {:.2f}".format(*g_most_least_tup[1]))
# Out:
# MOST UNIQUE: JONATHAN - 0.54
# LEAST UNIQUE: KHLOE - 0.64

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_g_j_sim_mat` returns the correct output."""
assert type(g_j_sim_matrix) == np.ndarray
assert g_j_sim_matrix.shape == (8, 8)
assert type(g_avg_jaccard_sim_dict) == dict
assert g_j_sim_matrix[4][4] == 1
assert_almost_equal(round(g_j_sim_matrix[2][5], 1), 0.7)
assert g_avg_jaccard_sim_dict['JONATHAN'] > 0.5
assert g_avg_jaccard_sim_dict['KHLOE'] > 0.6

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_g_j_sim_mat` and `most_least_sim_pairs` returns the correct output."""
assert g_most_least_tup[0][0] == 'JONATHAN'

# %%
plt.figure(figsize=(5, 5))
plt.imshow(g_j_sim_matrix, interpolation='none', cmap=plt.cm.Blues, vmin=0, vmax=1)
plt.colorbar()

plt.xticks(range(n_good_speakers), good_speakers, rotation=90)
plt.yticks(range(n_good_speakers), good_speakers)
plt.show()

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='green'> Question 2c (free response): Character similarity w/ Jaccard vs. generalized Jaccard </font>  <a class="anchor" id="2c"></a>
#
# Isn't it cool how we are able to analyze character similarity using just conversational data?! Be sure to investigate how the generalized Jaccard similarity matrix differs from the standard Jaccard matrix and how the character similarity pairs change.
#
# In the cell below, please use Markdown to note any differences that you observed between the heatmaps generated with Jaccard and generalized Jaccard similarity measurements.

# %% [markdown]
# **Solution**:
#
# 1. the GJ-matrix's color is generally more even-distributed than the J-matrix's.
#
# 2. In the J-matrix, we can observe from the heat map that colors of the columns & rows of the character Jonathan is significantly shallower than any other character, whereas in the GJ-matrix, Jonathan doesn't seem to be such a diffrence now.
#
# 2. On the other hand, some pattern has changed. For example, the least unique has become Khloe now instead of Kim.

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Character-pair analysis  <a class="anchor" id="3"></a>
#
# #### <font color='blue'> Question 3a (code completion): Character-pair analysis w/ generalized Jaccard </font> <a class="anchor" id="3a"></a>
#
# Leveraging the generalized Jaccard similarity matrix, `g_j_sim_matrix`, you will be measuring the relative similarity of "good speakers." The goal of this analysis is to determine which speaker is the most similar to everyone else, and which one is the least similar to everyone else.
#
# To start, we'll build a list of floats of size `input_n_speakers` that corresponds to the average (mean) similarity between that character and all the rest of the characters (not including self-similarity). In the cell below, satisfy the specification and ensure that you leverage numpy primitives.

# %%
def create_avg_sims(input_g_sim):
    """Compute average similarity between a speaker and others, for all speakers.
    
    Returns a np.ndarray (of size equal to the number of input speakers, `input_n_speakers`) that
    gives the average (mean) similarity between speaker `i` and everybody except the speaker itself.
    
    Hint: To help you out, here are a few numpy operations that might be useful: np.sum, np.average.
    
    Parameters
    ----------
    input_g_sim : np.ndarray
        The generalized Jaccard similarity matrix of (`input_n_speakers`, `input_n_speakers`), with 
        the entry (i, j) indicating the generalized Jaccard similarity between the speakers `i` and
        `j`.
    
    Returns
    -------
    np.ndarray
        An array that gives the average (mean) similarity between speaker `i` and everybody except 
        the speaker itself, for all the speakers.
    """
    output_array = np.zeros(len(input_g_sim))
    for i in range(len(input_g_sim)):
        output_array[i] = np.average(np.delete(input_g_sim[i], i))
    return output_array
create_avg_sims(g_j_sim_matrix)
# Out:
# array([0.5939768 , 0.54112772, 0.64098668, 0.63764129, 0.63027988,
#        0.6350607 , 0.56777468, 0.59888405])

# %%
avg_sims = create_avg_sims(g_j_sim_matrix)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_avg_sims` returns the correct output"""
assert type(avg_sims) == np.ndarray
assert avg_sims.shape == (8, )
assert sum(avg_sims) < 5

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 3b (code completion): Relative speaker uniqueness </font> <a class="anchor" id="3b"></a>
#
# This specific analysis concludes with the determination of which characters are the most and least similar to everyone else. In the cell bellow satisfy the above specification by returning a tuple in the following format:
# ```json
# (MOST_SIMILAR_CHARACTER_NAME, LEAST_SIMILAR_CHARACTER_NAME)
# ```

# %%
def most_least_char_sim(input_avg_sims, input_good_speakers):
    """Identify the most and least similar characters.
    
    Returns a tuple that reveals the most and least similar characters, relative to the rest of the
    characters in `input_good_speakers`. 

    The desired tuple format should be the following:
    ```(MOST_SIMILAR_CHARACTER_NAME, LEAST_SIMILAR_CHARACTER_NAME)```.
    
    Parameters
    ----------
    input_avg_sims : np.ndarray
        An array that gives the average (mean) similarity between speaker `i` and everybody except 
        the speaker itself, for all the speakers.
    input_good_speakers : list
        A list of chosen "good" speakers.
        
    Returns
    -------
    tuple
        A tuple of most and least similar characters, relative to the rest of the characters. 
    """
    most_similar = input_good_speakers[np.argmax(input_avg_sims)]
    least_similar = input_good_speakers[np.argmin(input_avg_sims)]
    return (most_similar, least_similar)

# %%
np.argmax(avg_sims)
# Out:
# 2

# %%
sim_pairs = most_least_char_sim(avg_sims, good_speakers)
print("MOST SIMILAR: %s" % sim_pairs[0])
print("LEAST SIMILAR: %s" % sim_pairs[1])
# Out:
# MOST SIMILAR: KHLOE
# LEAST SIMILAR: JONATHAN

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `most_least_char_sim` returns the correct output."""
assert type(sim_pairs) == tuple
assert len(sim_pairs) == 2

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Character interactions <a class="anchor" id="4"></a>
#
# In this section we will make the assumption that, if speaker B says something immediately after speaker A, then it is in reply to speaker A's utterance. While this assumption is not correct in all cases (particularly for noisy transcript data), it should still give us some insight into how our characters are behaving. In many cases, making reasonable assumptions about your data can lead to new insights.
#
# #### <font color='blue'> Question 4a (code completion): Character replies </font> <a class="anchor" id="4a"></a>
#
# In this question, we will be looking at how often each character replies to every other character. Note that here, we consider B to be replying to A **only when speaker A gets a reply from speaker B in the next utterance**. Do not merge consecutive lines by the same speaker as the same speech/reply. For instance, in the example:
#
# ```json
# Line 1: {speaker: A, text: ...}
# Line 2: {speaker: A, text: ...}
# Line 3: {speaker: B, text: ...}
# Line 4: {speaker: B, text: ...}
# ```
# Only line 3 should be considered a reply from speaker B to speaker A. Line 4 should NOT be considered (part of) a reply from speaker B to speaker A.

# %%
def create_reply_matrix(input_deduped_transcripts, input_good_speakers, input_n_speakers):
    """Create a reply matrix for character interactions.
    
    Returns a np.ndarray of shape (`input_n_speakers`, `input_n_speakers`) such that an entry (i, j)
    indicates the number of times speaker `j` replied to speaker `i`.
    
    Parameters
    ----------
    input_deduped_transcripts : list
        The list of input deduped transcripts, loaded from assignment 1.
    input_good_speakers : list
        A list of chosen "good" speakers.
    input_n_speakers : int
        The number of input speakers to be chosen in constructing the reply matrix (essentially, the
        number of good speakers).
    
    Returns
    -------
    np.ndarray
        The reply matrix of shape (`input_n_speakers`, `input_n_speakers`) such that an entry (i, j)
        indicates the number of times speaker `j` replied to speaker `i`.
    """

    reply_matrix = np.zeros((input_n_speakers, input_n_speakers))
    
    for transcript in input_deduped_transcripts:
        lines = transcript[1]
        for line_index in range(len(lines) - 1):
            line = lines[line_index]
            next_line = lines[line_index+1]

            speaker = line['speaker']
            next_speaker = next_line['speaker']
            
            if speaker!=next_speaker and speaker in input_good_speakers and next_speaker in input_good_speakers:
                reply_matrix[input_good_speakers.index(speaker)][input_good_speakers.index(next_speaker)] += 1
    return reply_matrix

reply_matrix = create_reply_matrix(deduped_transcripts, good_speakers, n_good_speakers)
reply_matrix
# Out:
# array([[  0.,   2., 357., 177., 102., 661., 169., 111.],
#        [  0.,   0.,  30.,  31.,  12.,   2.,   1.,   0.],
#        [359.,  28.,   0., 561., 685., 614., 184.,  76.],
#        [146.,  33., 585.,   0., 466., 544., 173.,  75.],
#        [101.,   9., 684., 468.,   0., 370.,  88., 486.],
#        [675.,   2., 588., 532., 390.,   0., 139.,  56.],
#        [191.,   0., 206., 199.,  81., 143.,   0., 112.],
#        [117.,   0.,  80.,  75., 476.,  64., 116.,   0.]])

# %%
deduped_transcripts[0][1]
# Out:
# [{'speaker': 'KHLOE',
#   'text': "You don't have your own credit card?",
#   'timestamp': '00:00:23'},
#  {'speaker': 'BRUCE',
#   'text': "I don't even have a credit card.",
#   'timestamp': '00:00:25'},
#  {'speaker': 'BRUCE', 'text': 'I know.', 'timestamp': '00:00:26'},
#  {'speaker': 'KHLOE',
#   'text': 'You are such a little girl.',
#   'timestamp': '00:00:27'},
#  {'speaker': 'BRUCE', 'text': 'I know.', 'timestamp': '00:00:31'},
#  {'speaker': 'BRUCE', 'text': "I'm a wuss, yeah.", 'timestamp': '00:00:32'},
#  {'speaker': 'BRUCE',
#   'text': 'When it comes to that stuff.',
#   'timestamp': '00:00:33'},
#  {'speaker': 'KHLOE', 'text': "You're a puss.", 'timestamp': '00:00:34'},
#  {'speaker': 'BRUCE', 'text': "I'm a puss.", 'timestamp': '00:00:35'},
#  {'speaker': 'KHLOE',
#   'text': 'I feel so bad that you need to, like, ask me for money.',
#   'timestamp': '00:00:36'},
#  {'speaker': 'BRUCE', 'text': 'Yeah, I know.', 'timestamp': '00:00:39'},
#  {'speaker': 'BRUCE', 'text': 'I feel bad, too.', 'timestamp': '00:00:40'},
#  {'speaker': 'BRUCE',
#   'text': 'How do you think I feel?',
#   'timestamp': '00:00:40'},
#  {'speaker': 'KHLOE',
#   'text': "Like, that's so embarrassing for you.",
#   'timestamp': '00:00:41'},
#  {'speaker': 'KHLOE',
#   'text': 'I definitely feel sorry for Bruce.',
#   'timestamp': '00:00:42'},
#  {'speaker': 'KHLOE',
#   'text': 'And I really want to help him out.',
#   'timestamp': '00:00:45'},
#  {'speaker': 'KHLOE',
#   'text': 'I mean, I want him to feel like a man.',
#   'timestamp': '00:00:46'},
#  {'speaker': 'KHLOE',
#   'text': "Like, here's money, buy yourself something, jeez.",
#   'timestamp': '00:00:48'},
#  {'speaker': 'BRUCE',
#   'text': "You're diving in for the cash?",
#   'timestamp': '00:00:51'},
#  {'speaker': 'KHLOE',
#   'text': 'Well, I have $400 on me now.',
#   'timestamp': '00:00:53'},
#  {'speaker': 'BRUCE', 'text': "You've got $400?!", 'timestamp': '00:00:56'},
#  {'speaker': 'KHLOE', 'text': 'So you can go...', 'timestamp': '00:00:57'},
#  {'speaker': 'BRUCE', 'text': "My God, I'm rich.", 'timestamp': '00:00:58'},
#  {'speaker': 'KHLOE',
#   'text': 'And then if you could take out the trash, and then if you go to Dash, maybe tomorrow or whatever, later today and just...',
#   'timestamp': '00:00:59'},
#  {'speaker': 'BRUCE',
#   'text': 'You got a couple more?',
#   'timestamp': '00:01:05'},
#  {'speaker': 'BRUCE', 'text': 'I love it.', 'timestamp': '00:01:06'},
#  {'speaker': 'BRUCE',
#   'text': "All right, I'm gonna go start on my chores.",
#   'timestamp': '00:01:07'},
#  {'speaker': 'BRUCE',
#   'text': "And remember, don't tell Mom, okay?",
#   'timestamp': '00:01:10'},
#  {'speaker': 'KHLOE',
#   'text': 'Your secret is safe with me.',
#   'timestamp': '00:01:14'},
#  {'speaker': 'KHLOE', 'text': 'Hi.', 'timestamp': '00:01:25'},
#  {'speaker': 'BRUCE', 'text': "I'm trying to...", 'timestamp': '00:01:26'},
#  {'speaker': 'KHLOE',
#   'text': 'I see you got started already on doing all the light bulbs.',
#   'timestamp': '00:01:27'},
#  {'speaker': 'BRUCE',
#   'text': 'None of them are working.',
#   'timestamp': '00:01:29'},
#  {'speaker': 'KHLOE',
#   'text': 'Well, you know, all these little light bulbs I need to be changed.',
#   'timestamp': '00:01:31'},
#  {'speaker': 'KHLOE',
#   'text': "Like, me and Lily can't reach those.",
#   'timestamp': '00:01:35'},
#  {'speaker': 'KHLOE',
#   'text': "There's spider webs all on it and at the very top.",
#   'timestamp': '00:01:37'},
#  {'speaker': 'KHLOE', 'text': "Like, that's sick.", 'timestamp': '00:01:39'},
#  {'speaker': 'KHLOE', 'text': "I can't do that.", 'timestamp': '00:01:40'},
#  {'speaker': 'BRUCE', 'text': 'All right.', 'timestamp': '00:01:40'},
#  {'speaker': 'KIM',
#   'text': 'You just need a duster.',
#   'timestamp': '00:01:41'},
#  {'speaker': 'BRUCE', 'text': 'I am the duster.', 'timestamp': '00:01:42'},
#  {'speaker': 'KHLOE',
#   'text': 'Bruce is doing a really good job at everything.',
#   'timestamp': '00:01:44'},
#  {'speaker': 'KHLOE',
#   'text': 'But I just feel bad even telling him to do stuff.',
#   'timestamp': '00:01:47'},
#  {'speaker': 'KHLOE', 'text': 'That should do it.', 'timestamp': '00:01:57'},
#  {'speaker': 'BRUCE',
#   'text': "It's been a pleasure doing business with you.",
#   'timestamp': '00:01:59'},
#  {'speaker': 'KHLOE', 'text': 'Any time, dude.', 'timestamp': '00:02:01'},
#  {'speaker': 'BRUCE', 'text': 'Okay.', 'timestamp': '00:02:02'},
#  {'speaker': 'ADRIENNE',
#   'text': "Hey, I'm unavailable to take your call right now, but if you leave your name and number, I'll get back to you.",
#   'timestamp': '00:02:05'},
#  {'speaker': 'ROBERT', 'text': "Hey, it's Rob.", 'timestamp': '00:02:14'},
#  {'speaker': 'ROBERT',
#   'text': 'Just wanted to call and say it was nice seeing you at the wedding.',
#   'timestamp': '00:02:16'},
#  {'speaker': 'ROBERT',
#   'text': 'Nice talking to you and everything.',
#   'timestamp': '00:02:20'},
#  {'speaker': 'ROBERT',
#   'text': "I've been trying to call Adrienne, trying to make things right, but she won't pick up.",
#   'timestamp': '00:02:22'},
#  {'speaker': 'ROBERT',
#   'text': "Hey, Adrienne, it's me again.",
#   'timestamp': '00:02:26'},
#  {'speaker': 'ROBERT',
#   'text': "Hey, it's me again, uh, Rob.",
#   'timestamp': '00:02:29'},
#  {'speaker': 'ROBERT',
#   'text': "Just wanted to see how your day's going.",
#   'timestamp': '00:02:32'},
#  {'speaker': 'ROBERT', 'text': "Uh, it's 9:20.", 'timestamp': '00:02:36'},
#  {'speaker': 'ROBERT',
#   'text': 'Just calling to say hi.',
#   'timestamp': '00:02:40'},
#  {'speaker': 'ROBERT',
#   'text': 'Call me back, please.',
#   'timestamp': '00:02:42'},
#  {'speaker': 'ROBERT',
#   'text': "The reason I'm calling Adrienne so much is just because I want her to see how much I truly care, and how much I truly want to be with her.",
#   'timestamp': '00:02:44'},
#  {'speaker': 'ROBERT',
#   'text': 'I want to get my girl back.',
#   'timestamp': '00:02:52'},
#  {'speaker': 'ROBERT', 'text': "Hey, it's Rob.", 'timestamp': '00:02:53'},
#  {'speaker': 'ROBERT',
#   'text': "I'm just calling you to see what's going on.",
#   'timestamp': '00:02:55'},
#  {'speaker': 'BRUCE',
#   'text': 'Is that the strip club?',
#   'timestamp': '00:02:58'},
#  {'speaker': 'KIM',
#   'text': 'When did you start to get gray hair?',
#   'timestamp': '00:03:08'},
#  {'speaker': 'KRIS', 'text': 'Like last week.', 'timestamp': '00:03:10'},
#  {'speaker': 'KIM', 'text': 'Oh, please.', 'timestamp': '00:03:11'},
#  {'speaker': 'KRIS',
#   'text': 'I have one gray hair, and in order for her make it all blend, she has to do the whole head.',
#   'timestamp': '00:03:13'},
#  {'speaker': 'KRIS', 'text': 'Right, K?', 'timestamp': '00:03:19'},
#  {'speaker': 'KENDALL', 'text': 'Right.', 'timestamp': '00:03:19'},
#  {'speaker': 'KRIS', 'text': 'Right.', 'timestamp': '00:03:20'},
#  {'speaker': 'KRIS',
#   'text': 'Will you guys look at this new dress I have in my closet?',
#   'timestamp': '00:03:21'},
#  {'speaker': 'KHLOE', 'text': 'Why?', 'timestamp': '00:03:23'},
#  {'speaker': 'KHLOE',
#   'text': "I'm going to an event tomorrow night and I need to make sure that you guys think my dress is cute.",
#   'timestamp': '00:03:24'},
#  {'speaker': 'KHLOE',
#   'text': "Mom, Kim and I have told you this before-- you can't buy clothes unless you approve them between us.",
#   'timestamp': '00:03:28'},
#  {'speaker': 'KRIS',
#   'text': "I'm asking you to approve.",
#   'timestamp': '00:03:32'},
#  {'speaker': 'KRIS',
#   'text': 'I have 24 hours, okay?',
#   'timestamp': '00:03:34'},
#  {'speaker': 'KRIS',
#   'text': "It's right over there.",
#   'timestamp': '00:03:35'},
#  {'speaker': 'KRIS', 'text': 'Look at the dress.', 'timestamp': '00:03:36'},
#  {'speaker': 'KHLOE',
#   'text': 'Is it this one hanging right here?',
#   'timestamp': '00:03:37'},
#  {'speaker': 'KRIS', 'text': 'Yep.', 'timestamp': '00:03:39'},
#  {'speaker': 'KIM', 'text': 'Oh, my God.', 'timestamp': '00:03:40'},
#  {'speaker': 'KRIS', 'text': 'What?', 'timestamp': '00:03:41'},
#  {'speaker': 'KIM', 'text': 'It is like $4,000.', 'timestamp': '00:03:42'},
#  {'speaker': 'KHLOE', 'text': 'Mom!', 'timestamp': '00:03:44'},
#  {'speaker': 'KRIS', 'text': 'What?', 'timestamp': '00:03:45'},
#  {'speaker': 'KHLOE',
#   'text': 'You just spent $4,000 on a dress?',
#   'timestamp': '00:03:45'},
#  {'speaker': 'KRIS',
#   'text': "I couldn't find anything else to wear.",
#   'timestamp': '00:03:48'},
#  {'speaker': 'KHLOE',
#   'text': 'Mom, that is ridiculous.',
#   'timestamp': '00:03:51'},
#  {'speaker': 'KHLOE', 'text': 'Are you kidding?', 'timestamp': '00:03:53'},
#  {'speaker': 'KIM', 'text': "That's crazy.", 'timestamp': '00:03:54'},
#  {'speaker': 'KIM',
#   'text': "That's way too much money, Mom.",
#   'timestamp': '00:03:55'},
#  {'speaker': 'KIM',
#   'text': "You have so many dresses, and it's just a plain black dress.",
#   'timestamp': '00:03:57'},
#  {'speaker': 'KIM', 'text': "It's nothing special.", 'timestamp': '00:04:00'},
#  {'speaker': 'KRIS',
#   'text': "I can't keep wearing the same dress over and over.",
#   'timestamp': '00:04:01'},
#  {'speaker': 'KRIS',
#   'text': 'You have to have, like, something new every time we go to an event.',
#   'timestamp': '00:04:03'},
#  {'speaker': 'KHLOE',
#   'text': 'Kris is such a hypocrite.',
#   'timestamp': '00:04:06'},
#  {'speaker': 'KHLOE',
#   'text': "Bruce is not allowed to spend any money on helicopters because it's wasteful, but yet my mom can go around and spend $4,000 on a dress that she's only going to wear once.",
#   'timestamp': '00:04:08'},
#  {'speaker': 'KRIS',
#   'text': 'Get out of my wallet, Khloe.',
#   'timestamp': '00:04:18'},
#  {'speaker': 'KHLOE', 'text': 'Credit card...', 'timestamp': '00:04:19'},
#  {'speaker': 'KRIS', 'text': 'Khloe, Khloe...', 'timestamp': '00:04:20'},
#  {'speaker': 'KHLOE',
#   'text': '...credit card, credit card...',
#   'timestamp': '00:04:21'},
#  {'speaker': 'KHLOE',
#   'text': "Ooh, Bruce Jenner's credit card.",
#   'timestamp': '00:04:24'},
#  {'speaker': 'KHLOE',
#   'text': 'No wonder he has no money.',
#   'timestamp': '00:04:26'},
#  {'speaker': 'KIM',
#   'text': 'Capitol One, Wells Fargo...',
#   'timestamp': '00:04:28'},
#  {'speaker': 'KRIS', 'text': 'Put my stuff away.', 'timestamp': '00:04:29'},
#  {'speaker': 'KRIS', 'text': 'That is not okay.', 'timestamp': '00:04:31'},
#  {'speaker': 'KRIS',
#   'text': "You don't go through somebody's wallet, it's rude and disrespectful.",
#   'timestamp': '00:04:32'},
#  {'speaker': 'KHLOE',
#   'text': "Oh, come on, she's too sensitive.",
#   'timestamp': '00:04:36'},
#  {'speaker': 'KHLOE', 'text': 'Come on, Kim.', 'timestamp': '00:04:37'},
#  {'speaker': 'ROBERT',
#   'text': 'To wives and mistresses.',
#   'timestamp': '00:04:47'},
#  {'speaker': 'SCOTT', 'text': 'To goomahs.', 'timestamp': '00:04:49'},
#  {'speaker': 'SCOTT', 'text': 'To you.', 'timestamp': '00:04:50'},
#  {'speaker': 'JJ',
#   'text': 'What were you saying about last night?',
#   'timestamp': '00:04:52'},
#  {'speaker': 'SCOTT',
#   'text': 'Do you know how many times he called Adrienne last night?',
#   'timestamp': '00:04:55'},
#  {'speaker': 'JJ', 'text': '80, I know.', 'timestamp': '00:04:58'},
#  {'speaker': 'ROBERT', 'text': 'Shut up.', 'timestamp': '00:04:59'},
#  {'speaker': 'SCOTT', 'text': '70 he told me.', 'timestamp': '00:05:00'},
#  {'speaker': 'JJ',
#   'text': "If she doesn't pick up after five calls...",
#   'timestamp': '00:05:01'},
#  {'speaker': 'JJ',
#   'text': 'I want to know where the other 65 came from.',
#   'timestamp': '00:05:02'},
#  {'speaker': 'SCOTT',
#   'text': 'What is going on with you and Adrienne?',
#   'timestamp': '00:05:04'},
#  {'speaker': 'SCOTT',
#   'text': 'Where are you with her right now?',
#   'timestamp': '00:05:06'},
#  {'speaker': 'ROBERT', 'text': 'To be honest...', 'timestamp': '00:05:08'},
#  {'speaker': 'SCOTT',
#   'text': 'Do you know what I mean?',
#   'timestamp': '00:05:08'},
#  {'speaker': 'JJ',
#   'text': 'I felt like post-wedding, you were really close, and then you screwed it up.',
#   'timestamp': '00:05:10'},
#  {'speaker': 'SCOTT',
#   'text': 'I felt like the wedding night he was good, until she woke up the next day and he called her 19 times to see when she woke up.',
#   'timestamp': '00:05:14'},
#  {'speaker': 'ROBERT', 'text': 'I deny...', 'timestamp': '00:05:20'},
#  {'speaker': 'SCOTT',
#   'text': 'Sent nine kinds of flowers.',
#   'timestamp': '00:05:21'},
#  {'speaker': 'ROBERT', 'text': "I didn't...", 'timestamp': '00:05:22'},
#  {'speaker': 'SCOTT',
#   'text': "He's going to send her a dog, by the way.",
#   'timestamp': '00:05:22'},
#  {'speaker': 'JJ',
#   'text': 'Did you send her flowers?',
#   'timestamp': '00:05:24'},
#  {'speaker': 'ROBERT', 'text': 'No, I did not.', 'timestamp': '00:05:25'},
#  {'speaker': 'ROBERT', 'text': 'Before the wedding.', 'timestamp': '00:05:26'},
#  {'speaker': 'ROBERT', 'text': "She liked 'em.", 'timestamp': '00:05:27'},
#  {'speaker': 'SCOTT', 'text': 'Bet she did, Focker.', 'timestamp': '00:05:27'},
#  {'speaker': 'SCOTT',
#   'text': 'What is she going to say, "Hey, by the way, I hated your flowers See you at the wedding."?',
#   'timestamp': '00:05:28'},
#  {'speaker': 'ROBERT',
#   'text': 'You know, JJ and Scott are constantly making fun of me, but little do they know, like Adrienne and I have a special relationship.',
#   'timestamp': '00:05:31'},
#  {'speaker': 'SCOTT',
#   'text': 'What do you think is going to happen at this point?',
#   'timestamp': '00:05:38'},
#  {'speaker': 'SCOTT',
#   'text': 'I mean, are you stalking her?',
#   'timestamp': '00:05:40'},
#  {'speaker': 'ROBERT', 'text': "No, I'm done.", 'timestamp': '00:05:41'},
#  {'speaker': 'SCOTT',
#   'text': "She's probably going to have a restraining order before you know it.",
#   'timestamp': '00:05:42'},
#  {'speaker': 'ROBERT',
#   'text': 'She understands how I am.',
#   'timestamp': '00:05:47'},
#  {'speaker': 'ROBERT',
#   'text': "She doesn't think I'm crazy.",
#   'timestamp': '00:05:49'},
#  {'speaker': 'KHLOE',
#   'text': "Robert, she definitely thinks you're crazy.",
#   'timestamp': '00:05:50'},
#  {'speaker': 'KHLOE',
#   'text': 'This is an intervention, okay?',
#   'timestamp': '00:05:52'},
#  {'speaker': 'KHLOE', 'text': "We're intervening.", 'timestamp': '00:05:54'},
#  {'speaker': 'KOURTNEY', 'text': "I'm done.", 'timestamp': '00:05:56'},
#  {'speaker': 'KOURTNEY',
#   'text': "If you don't start helping me out and getting on my team, this relationship is done.",
#   'timestamp': '00:05:58'},
#  {'speaker': 'KOURTNEY', 'text': 'Is this a joke?', 'timestamp': '00:08:39'},
#  {'speaker': 'KOURTNEY', 'text': 'Answer my phone.', 'timestamp': '00:08:45'},
#  {'speaker': 'KOURTNEY',
#   'text': 'When I call someone, like, answer.',
#   'timestamp': '00:08:46'},
#  {'speaker': 'KHLOE', 'text': 'Who are you calling?', 'timestamp': '00:08:48'},
#  {'speaker': 'KOURTNEY', 'text': 'Scott.', 'timestamp': '00:08:49'},
#  {'speaker': 'KOURTNEY',
#   'text': "I said I wanted to go to this-- to these classes, and like, he doesn't answer.",
#   'timestamp': '00:08:50'},
#  {'speaker': 'KHLOE', 'text': 'Class for what?', 'timestamp': '00:08:55'},
#  {'speaker': 'KOURTNEY',
#   'text': 'Like breast pumping.',
#   'timestamp': '00:08:56'},
#  {'speaker': 'KHLOE',
#   'text': "Maybe that's why he's not answering.",
#   'timestamp': '00:08:59'},
#  {'speaker': 'KOURTNEY', 'text': "It's still rude.", 'timestamp': '00:09:01'},
#  {'speaker': 'KOURTNEY',
#   'text': 'I said, "Let\'s go."',
#   'timestamp': '00:09:03'},
#  {'speaker': 'KOURTNEY', 'text': 'Call him again.', 'timestamp': '00:09:05'},
#  {'speaker': 'KOURTNEY',
#   'text': 'I just called like, three times.',
#   'timestamp': '00:09:07'},
#  {'speaker': 'KOURTNEY',
#   'text': "I don't want to be a stalker.",
#   'timestamp': '00:09:08'},
#  {'speaker': 'KOURTNEY', 'text': 'Answer my call.', 'timestamp': '00:09:10'},
#  {'speaker': 'KHLOE',
#   'text': "Kourtney, that's your baby daddy.",
#   'timestamp': '00:09:10'},
#  {'speaker': 'KHLOE', 'text': 'You can stalk.', 'timestamp': '00:09:12'},
#  {'speaker': 'KHLOE', 'text': 'Stalk that ass.', 'timestamp': '00:09:13'},
#  {'speaker': 'KOURTNEY',
#   'text': "I've called Scott over and over.",
#   'timestamp': '00:09:14'},
#  {'speaker': 'KOURTNEY',
#   'text': "He's totally avoiding my calls, and I'm really pissed off because he's totally flaking on me to go to this breast feeding class.",
#   'timestamp': '00:09:16'},
#  {'speaker': 'KOURTNEY',
#   'text': 'I mean, I refuse to go alone.',
#   'timestamp': '00:09:24'},
#  {'speaker': 'KHLOE',
#   'text': 'Honey, why would anyone want to pump their breast by themselves?',
#   'timestamp': '00:09:25'},
#  {'speaker': 'KHLOE',
#   'text': 'I could go with you and give you moral support.',
#   'timestamp': '00:09:30'},
#  {'speaker': 'KHLOE',
#   'text': "I mean, I'm not going to pump your breast, but I'll pump mine.",
#   'timestamp': '00:09:32'},
#  {'speaker': 'KOURTNEY', 'text': "I don't get it.", 'timestamp': '00:09:34'},
#  {'speaker': 'KOURTNEY',
#   'text': 'And I feel like when I go to these classes...',
#   'timestamp': '00:09:34'},
#  {'speaker': 'KHLOE', 'text': 'I wonder if I can.', 'timestamp': '00:09:36'},
#  {'speaker': 'KHLOE',
#   'text': 'Can I really be that supportive and pump mine, too?',
#   'timestamp': '00:09:37'},
#  {'speaker': 'KOURTNEY',
#   'text': "Bruce told me he's tasted breast milk.",
#   'timestamp': '00:09:39'},
#  {'speaker': 'KHLOE', 'text': "Bruce I'm sure has.", 'timestamp': '00:09:41'},
#  {'speaker': 'KOURTNEY', 'text': 'How sick.', 'timestamp': '00:09:43'},
#  {'speaker': 'KHLOE',
#   'text': 'Bruce is just very...',
#   'timestamp': '00:09:44'},
#  {'speaker': 'LILY', 'text': 'By accident?', 'timestamp': '00:09:45'},
#  {'speaker': 'KOURTNEY',
#   'text': 'Are you going to taste mine, just to see what it tastes like?',
#   'timestamp': '00:09:46'},
#  {'speaker': 'KHLOE',
#   'text': 'Drink your breast milk?',
#   'timestamp': '00:09:49'},
#  {'speaker': 'KOURTNEY', 'text': 'Not from my boob.', 'timestamp': '00:09:51'},
#  {'speaker': 'KHLOE',
#   'text': 'Obviously, you sick .',
#   'timestamp': '00:09:53'},
#  {'speaker': 'KOURTNEY',
#   'text': "If I'm... taste it.",
#   'timestamp': '00:09:55'},
#  {'speaker': 'KHLOE', 'text': "Yeah, I'll taste it.", 'timestamp': '00:09:56'},
#  {'speaker': 'KHLOE',
#   'text': "I'm not sucking on your  though.",
#   'timestamp': '00:09:57'},
#  {'speaker': 'KOURTNEY', 'text': "Let's hope.", 'timestamp': '00:10:00'},
#  {'speaker': 'BRUCE', 'text': 'What are you doing?', 'timestamp': '00:10:10'},
#  {'speaker': 'KYLIE',
#   'text': 'Rob told me to bring beers for them.',
#   'timestamp': '00:10:11'},
#  {'speaker': 'BRUCE',
#   'text': 'To bring beers for them?',
#   'timestamp': '00:10:14'},
#  {'speaker': 'BRUCE',
#   'text': 'What are you, their bartender?',
#   'timestamp': '00:10:16'},
#  {'speaker': 'KYLIE', 'text': 'Yeah.', 'timestamp': '00:10:17'},
#  {'speaker': 'BRUCE', 'text': 'Great.', 'timestamp': '00:10:19'},
#  {'speaker': 'BRUCE',
#   'text': "Okay, get them their beers and don't be drinking any of it.",
#   'timestamp': '00:10:19'},
#  {'speaker': 'KYLIE', 'text': 'Oh, I will.', 'timestamp': '00:10:22'},
#  {'speaker': 'BRUCE',
#   'text': 'Sometimes I get real disappointed with Scott.',
#   'timestamp': '00:10:24'},
#  {'speaker': 'BRUCE',
#   'text': "Here he's got a pregnant girlfriend, okay?",
#   'timestamp': '00:10:27'},
#  {'speaker': 'BRUCE',
#   'text': "Instead, he's over here with my little Kylie being a little barmaid, bringing beers out there so he can work on his tan.",
#   'timestamp': '00:10:29'},
#  {'speaker': 'BRUCE',
#   'text': 'It does not work for me.',
#   'timestamp': '00:10:35'},
#  {'speaker': 'SCOTT',
#   'text': 'Having a little brewski, Bruce?',
#   'timestamp': '00:10:37'},
#  {'speaker': 'BRUCE',
#   'text': "Yeah, I'm trying to keep up with you guys.",
#   'timestamp': '00:10:40'},
#  {'speaker': 'BRUCE',
#   'text': "Anyway, why aren't you with Kourtney?",
#   'timestamp': '00:10:43'},
#  {'speaker': 'SCOTT', 'text': 'What?', 'timestamp': '00:10:45'},
#  {'speaker': 'SCOTT',
#   'text': "I mean, I'm always with her.",
#   'timestamp': '00:10:46'},
#  {'speaker': 'ROBERT',
#   'text': 'The guy needs a little breather.',
#   'timestamp': '00:10:48'},
#  {'speaker': 'BRUCE', 'text': 'Oh?', 'timestamp': '00:10:51'},
#  {'speaker': 'SCOTT',
#   'text': "She's doing some class that doesn't involve me today anyway.",
#   'timestamp': '00:10:52'},
#  {'speaker': 'BRUCE',
#   'text': "She say she didn't want you to go?",
#   'timestamp': '00:10:55'},
#  {'speaker': 'SCOTT', 'text': 'Of course not.', 'timestamp': '00:10:57'},
#  {'speaker': 'SCOTT',
#   'text': 'She said she wanted me to go, but...',
#   'timestamp': '00:10:58'},
#  {'speaker': 'SCOTT', 'text': 'I know.', 'timestamp': '00:11:00'},
#  {'speaker': 'SCOTT', 'text': "I don't need to go.", 'timestamp': '00:11:01'},
#  {'speaker': 'BRUCE',
#   'text': 'Yeah, well, yes, you do, you need to go.',
#   'timestamp': '00:11:03'},
#  {'speaker': 'SCOTT',
#   'text': 'Look, Bruce, I know how to handle my lady, and you know how to handle yours.',
#   'timestamp': '00:11:06'},
#  {'speaker': 'SCOTT', 'text': "We'll be just fine.", 'timestamp': '00:11:10'},
#  {'speaker': 'BRUCE',
#   'text': 'You know how to handle Kourtney?',
#   'timestamp': '00:11:12'},
#  {'speaker': 'BRUCE',
#   'text': 'Nobody knows how to handle Kourtney.',
#   'timestamp': '00:11:14'},
#  {'speaker': 'SCOTT',
#   'text': 'I handled her well enough to get her pregnant.',
#   'timestamp': '00:11:17'},
#  {'speaker': 'BRUCE', 'text': 'Yeah. Good luck.', 'timestamp': '00:11:20'},
#  {'speaker': 'TEACHER', 'text': 'Hi. How are you?', 'timestamp': '00:11:28'},
#  {'speaker': 'TEACHER', 'text': 'Hi, come on in.', 'timestamp': '00:11:30'},
#  {'speaker': 'KHLOE',
#   'text': "You don't like your baby?",
#   'timestamp': '00:11:35'},
#  {'speaker': 'KOURTNEY', 'text': 'This one.', 'timestamp': '00:11:36'},
#  {'speaker': 'KHLOE',
#   'text': 'Here, you want this one?',
#   'timestamp': '00:11:37'},
#  {'speaker': 'KOURTNEY', 'text': 'Yes, thank you.', 'timestamp': '00:11:38'},
#  {'speaker': 'KOURTNEY', 'text': 'Okay.', 'timestamp': '00:11:41'},
#  {'speaker': 'KOURTNEY',
#   'text': 'I like that one better.',
#   'timestamp': '00:11:42'},
#  {'speaker': 'KHLOE', 'text': 'Like a girl.', 'timestamp': '00:11:45'},
#  {'speaker': 'KOURTNEY',
#   'text': "Ooh, look at that one's eyes.",
#   'timestamp': '00:11:45'},
#  {'speaker': 'KOURTNEY',
#   'text': 'Khloe, look at it.',
#   'timestamp': '00:11:47'},
#  {'speaker': 'TEACHER', 'text': 'So, hi, everyone.', 'timestamp': '00:11:48'},
#  {'speaker': 'TEACHER',
#   'text': "So today we're gonna take you through some of the, uh, basics that you guys need to know, how to take care of these little ones.",
#   'timestamp': '00:11:50'},
#  {'speaker': 'TEACHER',
#   'text': "And we're gonna just, um, talk about and learn about some of the things that you're gonna be doing every day.",
#   'timestamp': '00:11:56'},
#  {'speaker': 'TEACHER',
#   'text': 'Um, so I think hopefully it will be useful to you.',
#   'timestamp': '00:12:00'},
#  {'speaker': 'KOURTNEY',
#   'text': 'How many times a day does your baby eat?',
#   'timestamp': '00:12:04'},
#  {'speaker': 'TEACHER',
#   'text': 'Um, new babies that are breast-fed, eight to 12 times.',
#   'timestamp': '00:12:07'},
#  {'speaker': 'KOURTNEY', 'text': 'No.', 'timestamp': '00:12:11'},
#  {'speaker': 'TEACHER', 'text': 'Yeah.', 'timestamp': '00:12:12'},
#  {'speaker': 'KOURTNEY', 'text': 'A day?', 'timestamp': '00:12:12'},
#  {'speaker': 'TEACHER', 'text': 'Pretty often.', 'timestamp': '00:12:13'},
#  {'speaker': 'TEACHER',
#   'text': 'Uh-huh, in 24 hours.',
#   'timestamp': '00:12:14'},
#  {'speaker': 'KOURTNEY',
#   'text': "Going to these classes makes me more nervous because it just reminds me of all the information that I don't know.",
#   'timestamp': '00:12:15'},
#  {'speaker': 'TEACHER',
#   'text': "Put the front of the diaper underneath your baby's tush so you've got a clean surface.",
#   'timestamp': '00:12:23'},
#  {'speaker': 'KHLOE',
#   'text': 'Kourtney, his two legs like this.',
#   'timestamp': '00:12:27'},
#  {'speaker': 'KOURTNEY', 'text': 'Sorry.', 'timestamp': '00:12:30'},
#  {'speaker': 'TEACHER',
#   'text': 'And have that cloth diaper handy.',
#   'timestamp': '00:12:31'},
#  {'speaker': 'TEACHER',
#   'text': 'Everybody got that?',
#   'timestamp': '00:12:33'},
#  {'speaker': 'TEACHER', 'text': 'Perfect.', 'timestamp': '00:12:35'},
#  {'speaker': 'KHLOE', 'text': 'No, you wrap it...', 'timestamp': '00:12:36'},
#  {'speaker': 'KOURTNEY', 'text': 'Bingo.', 'timestamp': '00:12:37'},
#  {'speaker': 'KOURTNEY',
#   'text': "I don't know how to change a diaper.",
#   'timestamp': '00:12:38'},
#  {'speaker': 'KOURTNEY',
#   'text': "I don't know how to swaddle a baby.",
#   'timestamp': '00:12:40'},
#  {'speaker': 'KOURTNEY',
#   'text': "I don't know when you swaddle a baby.",
#   'timestamp': '00:12:43'},
#  {'speaker': 'KOURTNEY',
#   'text': "I don't know even how to hold the baby.",
#   'timestamp': '00:12:45'},
#  {'speaker': 'KOURTNEY',
#   'text': "Just thinking about all these tasks and things that I'm gonna need to know just makes me really nervous and anxious.",
#   'timestamp': '00:12:47'},
#  {'speaker': 'KOURTNEY', 'text': 'Did you do it?', 'timestamp': '00:12:56'},
#  {'speaker': 'TEACHER',
#   'text': "You guys, how'd you do?",
#   'timestamp': '00:12:57'},
#  {'speaker': 'TEACHER', 'text': 'It looks good.', 'timestamp': '00:12:59'},
#  {'speaker': 'KOURTNEY',
#   'text': "I don't think I did very well.",
#   'timestamp': '00:12:59'},
#  {'speaker': 'TEACHER', 'text': "Okay, let's see.", 'timestamp': '00:13:01'},
#  {'speaker': 'KHLOE',
#   'text': "Kourtney's just off right now.",
#   'timestamp': '00:13:02'},
#  {'speaker': 'KHLOE',
#   'text': "I think she's really getting stressed, and the pregnancy's finally starting to hit her and it's becoming more serious.",
#   'timestamp': '00:13:03'},
#  {'speaker': 'KHLOE',
#   'text': "And also, I think the fact that she's the only one without a dad here right now, I think that's really affecting her.",
#   'timestamp': '00:13:09'},
#  {'speaker': 'TEACHER',
#   'text': 'How are the dads back there feeling about all of this going on?',
#   'timestamp': '00:13:15'},
#  {'speaker': 'TEACHER',
#   'text': 'You guys plan to be pretty involved or...?',
#   'timestamp': '00:13:18'},
#  {'speaker': 'TEACHER',
#   'text': "Yeah, he's better than you are.",
#   'timestamp': '00:13:21'},
#  {'speaker': 'TEACHER',
#   'text': 'How about the rest of you?',
#   'timestamp': '00:13:22'},
#  {'speaker': 'TEACHER',
#   'text': 'Dads involved or...?',
#   'timestamp': '00:13:23'},
#  {'speaker': 'KHLOE', 'text': "I'm the dad today.", 'timestamp': '00:13:25'},
#  {'speaker': 'TEACHER', 'text': 'Got it.', 'timestamp': '00:13:26'},
#  {'speaker': 'TEACHER', 'text': 'Good.', 'timestamp': '00:13:27'},
#  {'speaker': 'TEACHER',
#   'text': "You're gonna be busy.",
#   'timestamp': '00:13:27'},
#  {'speaker': 'KHLOE', 'text': 'Mm.', 'timestamp': '00:13:28'},
#  {'speaker': 'KHLOE',
#   'text': "I will still be the dad, even when he is around, I'm sure.",
#   'timestamp': '00:13:29'},
#  {'speaker': 'SCOTT', 'text': 'Hello.', 'timestamp': '00:13:39'},
#  {'speaker': 'SCOTT', 'text': 'Okay.', 'timestamp': '00:13:45'},
#  {'speaker': 'SCOTT', 'text': 'What are you up to?', 'timestamp': '00:13:46'},
#  {'speaker': 'SCOTT',
#   'text': 'All right, good talking to you.',
#   'timestamp': '00:13:50'},
#  {'speaker': 'KOURTNEY',
#   'text': "I'm sick and tired of Scott not putting in an effort with the baby and I.",
#   'timestamp': '00:13:51'},
#  {'speaker': 'KOURTNEY',
#   'text': 'And him not coming to that class was the last straw.',
#   'timestamp': '00:13:56'},
#  {'speaker': 'SCOTT',
#   'text': 'You have a bad attitude.',
#   'timestamp': '00:13:59'},
#  {'speaker': 'KOURTNEY',
#   'text': "Yeah, 'cause you ditched me in my breast-feeding class today.",
#   'timestamp': '00:14:01'},
#  {'speaker': 'SCOTT',
#   'text': "It's a woman's breast-feeding class.",
#   'timestamp': '00:14:05'},
#  {'speaker': 'KOURTNEY',
#   'text': 'We learned about other things.',
#   'timestamp': '00:14:08'},
#  {'speaker': 'KOURTNEY',
#   'text': "It wasn't just about breast-feeding!",
#   'timestamp': '00:14:10'},
#  {'speaker': 'KOURTNEY',
#   'text': "You just don't get it.",
#   'timestamp': '00:14:12'},
#  {'speaker': 'KOURTNEY',
#   'text': 'What are you bringing to the table?',
#   'timestamp': '00:14:13'},
#  {'speaker': 'KOURTNEY', 'text': 'Nothing.', 'timestamp': '00:14:15'},
#  {'speaker': 'SCOTT', 'text': 'Everything.', 'timestamp': '00:14:16'},
#  {'speaker': 'KOURTNEY', 'text': 'Nothing!', 'timestamp': '00:14:16'},
#  {'speaker': 'KOURTNEY',
#   'text': "You're not helping with any  thing.",
#   'timestamp': '00:14:17'},
#  {'speaker': 'KOURTNEY', 'text': "I'm done.", 'timestamp': '00:14:20'},
#  {'speaker': 'KOURTNEY',
#   'text': 'Like, I am so  done with you.',
#   'timestamp': '00:14:21'},
#  {'speaker': 'SCOTT', 'text': 'Oh, relax.', 'timestamp': '00:14:23'},
#  {'speaker': 'SCOTT',
#   'text': "You-you don't mean that.",
#   'timestamp': '00:14:24'},
#  {'speaker': 'KOURTNEY', 'text': 'Relax?', 'timestamp': '00:14:25'},
#  {'speaker': 'SCOTT', 'text': 'No, okay...', 'timestamp': '00:14:25'},
#  {'speaker': 'KOURTNEY', 'text': 'Test me!', 'timestamp': '00:14:26'},
#  {'speaker': 'KOURTNEY', 'text': 'test me and see.', 'timestamp': '00:14:27'},
#  {'speaker': 'SCOTT', 'text': 'Test you?', 'timestamp': '00:14:28'},
#  {'speaker': 'KOURTNEY', 'text': 'Yeah!', 'timestamp': '00:14:29'},
#  {'speaker': 'KOURTNEY',
#   'text': "If you don't start helping me out and getting on my team, this relationship is done.",
#   'timestamp': '00:14:29'},
#  {'speaker': 'KRIS', 'text': "Where's my dress?", 'timestamp': '00:14:36'},
#  {'speaker': 'BRUCE',
#   'text': 'Bitch, I want my damn ATM card!',
#   'timestamp': '00:14:38'},
#  {'speaker': 'KIM',
#   'text': "So what's, like, your plan?",
#   'timestamp': '00:14:41'},
#  {'speaker': 'KIM',
#   'text': 'Like, where are you gonna stay?',
#   'timestamp': '00:14:44'},
#  {'speaker': 'ROBERT',
#   'text': 'When I get tre, m just gonna go get a hotel room and, uh...',
#   'timestamp': '00:14:45'},
#  {'speaker': 'KIM',
#   'text': "I'm just afraid if you go to New York, you'll come back hurt.",
#   'timestamp': '00:14:48'},
#  {'speaker': 'KIM',
#   'text': "As much as I don't agree with Rob going to New York, he's my little brother.",
#   'timestamp': '00:14:52'},
#  {'speaker': 'KIM',
#   'text': "I'm gonna support him no matter what.",
#   'timestamp': '00:14:57'},
#  {'speaker': 'ROBERT', 'text': 'Hello?', 'timestamp': '00:17:39'},
#  {'speaker': 'KIM',
#   'text': "So I call Rob to see what's going on with Adrienne.",
#   'timestamp': '00:17:41'},
#  {'speaker': 'ROBERT',
#   'text': 'I freaked out last night and I called her, like, 60 times, literally, like crazy.',
#   'timestamp': '00:17:43'},
#  {'speaker': 'ROBERT',
#   'text': 'Like, more than that.',
#   'timestamp': '00:17:48'},
#  {'speaker': 'ROBERT',
#   'text': 'Like, from the house and from my cell.',
#   'timestamp': '00:17:49'},
#  {'speaker': 'KIM', 'text': "Rob, you're crazy.", 'timestamp': '00:17:52'},
#  {'speaker': 'ROBERT',
#   'text': "I think if I show her that I'm serious about wanting her back, I think she'll come back to me.",
#   'timestamp': '00:17:54'},
#  {'speaker': 'ROBERT',
#   'text': "I don't want to be with anybody but her.",
#   'timestamp': '00:17:59'},
#  {'speaker': 'ROBERT',
#   'text': "I don't want to even date.",
#   'timestamp': '00:18:01'},
#  {'speaker': 'ROBERT',
#   'text': "And I can't just be lonely and single anymore.",
#   'timestamp': '00:18:02'},
#  {'speaker': 'ROBERT',
#   'text': 'Literally, every single day, I send her an e-mail or a text.',
#   'timestamp': '00:18:05'},
#  {'speaker': 'ROBERT',
#   'text': "And I'm not talking about just one.",
#   'timestamp': '00:18:09'},
#  {'speaker': 'ROBERT',
#   'text': 'Like, "Oh, this just reminded me of you." "I\'m so sorry, like, that I treated you that way."',
#   'timestamp': '00:18:10'},
#  {'speaker': 'ROBERT',
#   'text': 'I think that at some point, you just need to stop calling her.',
#   'timestamp': '00:18:21'},
#  {'speaker': 'ROBERT',
#   'text': 'And I think this is now, like, the turning point.',
#   'timestamp': '00:18:24'},
#  {'speaker': 'ROBERT',
#   'text': 'You have to let it go.',
#   'timestamp': '00:18:27'},
#  {'speaker': 'ROBERT',
#   'text': "All right, I'm gonna shower.",
#   'timestamp': '00:18:29'},
#  {'speaker': 'KIM', 'text': 'Bye.', 'timestamp': '00:18:30'},
#  {'speaker': 'SCOTT', 'text': 'Hey, Bruce.', 'timestamp': '00:18:31'},
#  {'speaker': 'BRUCE', 'text': 'Scotty.', 'timestamp': '00:18:43'},
#  {'speaker': 'SCOTT', 'text': 'Rob here?', 'timestamp': '00:18:44'},
#  {'speaker': 'BRUCE', 'text': 'No, he left.', 'timestamp': '00:18:45'},
#  {'speaker': 'SCOTT', 'text': 'What?', 'timestamp': '00:18:46'},
#  {'speaker': 'SCOTT',
#   'text': 'He just told me to come here.',
#   'timestamp': '00:18:47'},
#  {'speaker': 'BRUCE', 'text': 'Did he really?', 'timestamp': '00:18:49'},
#  {'speaker': 'SCOTT',
#   'text': "I figure I'll talk to you then, Bruce, if Rob ain't here.",
#   'timestamp': '00:18:49'},
#  {'speaker': 'SCOTT',
#   'text': "I need somebody to speak to, because, you know, it's all women everywhere.",
#   'timestamp': '00:18:53'},
#  {'speaker': 'BRUCE', 'text': 'Yeah.', 'timestamp': '00:18:56'},
#  {'speaker': 'SCOTT',
#   'text': "There's nothing but...",
#   'timestamp': '00:18:57'},
#  {'speaker': 'BRUCE',
#   'text': 'And you got a pregnant one.',
#   'timestamp': '00:18:58'},
#  {'speaker': 'SCOTT',
#   'text': "It's not simple, I've come to realize.",
#   'timestamp': '00:19:00'},
#  {'speaker': 'BRUCE',
#   'text': "You're just realizing that now?",
#   'timestamp': '00:19:02'},
#  {'speaker': 'SCOTT',
#   'text': 'She, I guess, asked me to go to some class that I thought I had no part in.',
#   'timestamp': '00:19:04'},
#  {'speaker': 'SCOTT', 'text': 'Breast-feeding?', 'timestamp': '00:19:08'},
#  {'speaker': 'SCOTT',
#   'text': "I thought that's just her.",
#   'timestamp': '00:19:09'},
#  {'speaker': 'SCOTT',
#   'text': 'What-what do I bring to the table in breast-feeding?',
#   'timestamp': '00:19:11'},
#  {'speaker': 'BRUCE', 'text': 'Support.', 'timestamp': '00:19:13'},
#  {'speaker': 'SCOTT',
#   'text': "I mean, I want to be there for her and be sensitive, I've just never been this person before.",
#   'timestamp': '00:19:14'},
#  {'speaker': 'BRUCE',
#   'text': 'Scott has really lived a very easy life.',
#   'timestamp': '00:19:19'},
#  {'speaker': 'BRUCE',
#   'text': "He's been really very selfish and just kind of dealing with Scott.",
#   'timestamp': '00:19:22'},
#  {'speaker': 'BRUCE',
#   'text': "It's time to give a little bit of advice about being a father.",
#   'timestamp': '00:19:25'},
#  {'speaker': 'BRUCE',
#   'text': "You just got to realize that it's just not about you anymore.",
#   'timestamp': '00:19:28'},
#  {'speaker': 'SCOTT', 'text': 'Yeah.', 'timestamp': '00:19:32'},
#  {'speaker': 'BRUCE',
#   'text': "It's not about Kourtney anymore.",
#   'timestamp': '00:19:32'},
#  {'speaker': 'BRUCE',
#   'text': "It's about this family structure.",
#   'timestamp': '00:19:34'},
#  {'speaker': 'BRUCE', 'text': "It's easier now.", 'timestamp': '00:19:36'},
#  {'speaker': 'BRUCE',
#   'text': 'Because when little guy comes...',
#   'timestamp': '00:19:37'},
#  {'speaker': 'SCOTT',
#   'text': "It's a whole 'nother level.",
#   'timestamp': '00:19:40'},
#  {'speaker': 'BRUCE',
#   'text': "It's 24 hours a day, seven days a week, 365 days out of the year for the next 20 years of your life.",
#   'timestamp': '00:19:41'},
#  {'speaker': 'SCOTT',
#   'text': "I'm getting to realize that now.",
#   'timestamp': '00:19:47'},
#  {'speaker': 'SCOTT',
#   'text': "Being an only child, I never really did care too much about other people's needs.",
#   'timestamp': '00:19:49'},
#  {'speaker': 'SCOTT',
#   'text': "But I realize, I'm not the most important person anymore, and I can't be selfish.",
#   'timestamp': '00:19:54'},
#  {'speaker': 'SCOTT',
#   'text': 'I need to think about my family.',
#   'timestamp': '00:19:58'},
#  {'speaker': 'BRUCE',
#   'text': 'All you can do right now is just dote on her, take care of her and just realize that this stage of pregnancy, you just got to get through it.',
#   'timestamp': '00:19:59'},
#  {'speaker': 'KOURTNEY',
#   'text': 'They came with me to look at the...',
#   'timestamp': '00:20:16'},
#  {'speaker': 'KHLOE', 'text': 'Yeah.', 'timestamp': '00:20:18'},
#  {'speaker': 'KHLOE', 'text': 'Kathy comes with us.', 'timestamp': '00:20:18'},
#  {'speaker': 'KIM', 'text': 'Yummy.', 'timestamp': '00:20:19'},
#  {'speaker': 'KHLOE', 'text': 'Hey, Rob.', 'timestamp': '00:20:21'},
#  {'speaker': 'KHLOE',
#   'text': "Kourt, Kim and I decide that it's time to intervene on Rob with this whole Adrienne situation.",
#   'timestamp': '00:20:22'},
#  {'speaker': 'KHLOE',
#   'text': "Thank God you're here, because honestly you have a major problem.",
#   'timestamp': '00:20:28'},
#  {'speaker': 'ROBERT', 'text': 'What did I do?', 'timestamp': '00:20:32'},
#  {'speaker': 'KHLOE',
#   'text': 'Uh, you are obsessed with Adrienne.',
#   'timestamp': '00:20:33'},
#  {'speaker': 'ROBERT',
#   'text': 'She understands how I am.',
#   'timestamp': '00:20:40'},
#  {'speaker': 'ROBERT',
#   'text': "She doesn't think I'm crazy.",
#   'timestamp': '00:20:42'},
#  {'speaker': 'KHLOE',
#   'text': "Um, Robert, she definitely thinks you're crazy.",
#   'timestamp': '00:20:43'},
#  {'speaker': 'KOURTNEY',
#   'text': "Who wouldn't think someone's crazy if they call them that many times?",
#   'timestamp': '00:20:46'},
#  {'speaker': 'KHLOE',
#   'text': 'This is an intervention, okay?',
#   'timestamp': '00:20:49'},
#  {'speaker': 'KHLOE', 'text': "We're intervening.", 'timestamp': '00:20:51'},
#  {'speaker': 'KOURTNEY',
#   'text': "If Rob and Adrienne are meant to be together, they'll be.",
#   'timestamp': '00:20:52'},
#  {'speaker': 'KOURTNEY',
#   'text': "You don't need to try this hard.",
#   'timestamp': '00:20:56'},
#  {'speaker': 'KOURTNEY', 'text': "I'm over it now.", 'timestamp': '00:20:57'},
#  {'speaker': 'KOURTNEY',
#   'text': 'Like, at first, I was like, "Oh, cute, Rob and Adrienne." Like, I\'m over it, okay?',
#   'timestamp': '00:20:58'},
#  {'speaker': 'KIM',
#   'text': 'She knows that you love her.',
#   'timestamp': '00:21:02'},
#  {'speaker': 'KIM', 'text': 'What else can you do?', 'timestamp': '00:21:03'},
#  {'speaker': 'KIM',
#   'text': "There's nothing else you can do.",
#   'timestamp': '00:21:04'},
#  {'speaker': 'ROBERT',
#   'text': "The love that Adrienne and I had doesn't just go away overnight.",
#   'timestamp': '00:21:06'},
#  {'speaker': 'ROBERT',
#   'text': "It's just so frustrating that my own family doesn't even understand their own brother.",
#   'timestamp': '00:21:10'},
#  {'speaker': 'ROBERT',
#   'text': "I don't feel content and, like, at peace.",
#   'timestamp': '00:21:14'},
#  {'speaker': 'ROBERT',
#   'text': "I can't just drop everything and be cold turkey not talk to her anymore.",
#   'timestamp': '00:21:17'},
#  {'speaker': 'KHLOE',
#   'text': "Well, that's not gonna happen.",
#   'timestamp': '00:21:20'},
#  {'speaker': 'KHLOE',
#   'text': 'She went back to New York.',
#   'timestamp': '00:21:22'},
#  {'speaker': 'KIM', 'text': "She's in New York.", 'timestamp': '00:21:23'},
#  {'speaker': 'ROBERT',
#   'text': "Then if I have to go to New York, I'll go to New York.",
#   'timestamp': '00:21:23'},
#  {'speaker': 'ROBERT',
#   'text': 'If I look like an idiot-- How much more stupid can I look?',
#   'timestamp': '00:21:26'},
#  {'speaker': 'KHLOE',
#   'text': "You're just gonna go to her house?",
#   'timestamp': '00:21:28'},
#  {'speaker': 'ROBERT',
#   'text': "I'm gonna go try and make things right.",
#   'timestamp': '00:21:30'},
#  {'speaker': 'KHLOE',
#   'text': 'You know, honestly, maybe you need to go to New York to open up your eyes that you guys are not meant to be.',
#   'timestamp': '00:21:32'},
#  {'speaker': 'ROBERT',
#   'text': "Well, I don't agree with that.",
#   'timestamp': '00:21:37'},
#  {'speaker': 'KHLOE',
#   'text': 'Enjoy Adrienne in New York, you freak of the week.',
#   'timestamp': '00:21:39'},
#  {'speaker': 'KIM',
#   'text': 'We should go and get her dress from the dry cleaners and hold it captive until she gives back the ATM card.',
#   'timestamp': '00:21:46'},
#  {'speaker': 'ROBERT',
#   'text': "I've decided to fly back to New York to see Adrienne face-to-face.",
#   'timestamp': '00:21:53'},
#  {'speaker': 'KRIS',
#   'text': "Does she know you're coming?",
#   'timestamp': '00:21:57'},
#  {'speaker': 'ROBERT', 'text': "No, she doesn't.", 'timestamp': '00:21:58'},
#  {'speaker': 'BRUCE',
#   'text': "Where'd these cookies come from?",
#   'timestamp': '00:24:46'},
#  {'speaker': 'KHLOE',
#   'text': "They're Armenian cookies.",
#   'timestamp': '00:24:48'},
#  {'speaker': 'BRUCE',
#   'text': "What's the difference between, like, an American cookie and an Armenian cookie?",
#   'timestamp': '00:24:50'},
#  {'speaker': 'KHLOE',
#   'text': 'An Armenian made them.',
#   'timestamp': '00:24:54'},
#  {'speaker': 'BRUCE',
#   'text': 'Oh, that makes them Armenian cookies?',
#   'timestamp': '00:24:56'},
#  {'speaker': 'KIM',
#   'text': 'Those pants-- I mean, are you a doctor?',
#   'timestamp': '00:24:58'},
#  {'speaker': 'BRUCE', 'text': 'Yeah.', 'timestamp': '00:25:00'},
#  {'speaker': 'KHLOE',
#   'text': 'I mean, do you have a washing machine?',
#   'timestamp': '00:25:01'},
#  {'speaker': 'KHLOE', 'text': "They're filthy.", 'timestamp': '00:25:02'},
#  {'speaker': 'BRUCE',
#   'text': "They are, but I've been working all day, moving stuff for your mother.",
#   'timestamp': '00:25:03'},
#  {'speaker': 'KHLOE',
#   'text': "Don't you have any, like, balls?",
#   'timestamp': '00:25:07'},
#  {'speaker': 'BRUCE', 'text': 'No, not with her.', 'timestamp': '00:25:09'},
#  {'speaker': 'KHLOE', 'text': 'Apparently not.', 'timestamp': '00:25:10'},
#  {'speaker': 'KHLOE',
#   'text': "They're in the blender.",
#   'timestamp': '00:25:11'},
#  {'speaker': 'KIM', 'text': 'Balls in a blender.', 'timestamp': '00:25:11'},
#  {'speaker': 'KHLOE', 'text': 'Balls in a blender.', 'timestamp': '00:25:12'},
#  {'speaker': 'KHLOE',
#   'text': 'Kris already has your balls in a blender.',
#   'timestamp': '00:25:14'},
#  {'speaker': 'BRUCE', 'text': 'I know.', 'timestamp': '00:25:16'},
#  {'speaker': 'BRUCE',
#   'text': 'Well, what are you gonna do?',
#   'timestamp': '00:25:17'},
#  {'speaker': 'BRUCE',
#   'text': "I'm...  I'm scared of her!",
#   'timestamp': '00:25:18'},
#  {'speaker': 'KHLOE',
#   'text': "Honey, she's the one that walked in with a $5,000 all-black basic dress.",
#   'timestamp': '00:25:20'},
#  {'speaker': 'KHLOE', 'text': 'Like, hello.', 'timestamp': '00:25:25'},
#  {'speaker': 'BRUCE', 'text': 'Really?', 'timestamp': '00:25:26'},
#  {'speaker': 'KHLOE',
#   'text': 'Yeah, $5,000 for one black gown.',
#   'timestamp': '00:25:27'},
#  {'speaker': 'KHLOE',
#   'text': "It wasn't even special.",
#   'timestamp': '00:25:30'},
#  {'speaker': 'BRUCE',
#   'text': 'Thousands of dollars she paid, for a dress!',
#   'timestamp': '00:25:32'},
#  {'speaker': 'BRUCE', 'text': 'Are you kidding me?!', 'timestamp': '00:25:35'},
#  {'speaker': 'KIM',
#   'text': "We've got to get her back.",
#   'timestamp': '00:25:37'},
#  {'speaker': 'KIM',
#   'text': "I don't know how, but...",
#   'timestamp': '00:25:38'},
#  {'speaker': 'BRUCE',
#   'text': 'Maybe I should trade in the dress or something, huh?',
#   'timestamp': '00:25:42'},
#  {'speaker': 'KIM ',
#   'text': 'Wait, I have the best idea!',
#   'timestamp': '00:25:44'},
#  {'speaker': 'KHLOE & BRUCE', 'text': 'What?', 'timestamp': '00:25:47'},
#  {'speaker': 'KIM',
#   'text': 'We should go and get her dress from the dry cleaners and hold it captive until she gives back the ATM card.',
#   'timestamp': '00:25:47'},
#  {'speaker': 'KIM',
#   'text': 'I really want to help Bruce get his financial freedom back.',
#   'timestamp': '00:25:54'},
#  {'speaker': 'KIM', 'text': "He's worked so hard.", 'timestamp': '00:25:58'},
#  {'speaker': 'KIM',
#   'text': "There's no way that my mom should have control over the money.",
#   'timestamp': '00:25:59'},
#  {'speaker': 'BRUCE',
#   'text': 'So we get her dress from the cleaners, and we hold her hostage.',
#   'timestamp': '00:26:03'},
#  {'speaker': 'BRUCE', 'text': "I like it. I'm in.", 'timestamp': '00:26:07'},
#  {'speaker': 'SCOTT',
#   'text': "I'm gonna show Kourtney that I'm gonna be there for whatever she needs, whenever she needs it.",
#   'timestamp': '00:26:23'},
#  {'speaker': 'KOURTNEY', 'text': 'Hey.', 'timestamp': '00:26:40'},
#  {'speaker': 'SCOTT', 'text': 'Hello, hello.', 'timestamp': '00:26:41'},
#  {'speaker': 'KOURTNEY',
#   'text': 'What are you doing?',
#   'timestamp': '00:26:43'},
#  {'speaker': 'SCOTT',
#   'text': 'Getting this room put together.',
#   'timestamp': '00:26:44'},
#  {'speaker': 'KOURTNEY',
#   'text': "Oh, that's cute, with the animals there on the blanket.",
#   'timestamp': '00:26:46'},
#  {'speaker': 'SCOTT',
#   'text': 'What about the whole crib is all done?',
#   'timestamp': '00:26:49'},
#  {'speaker': 'KOURTNEY', 'text': 'Oh, no way.', 'timestamp': '00:26:51'},
#  {'speaker': 'SCOTT',
#   'text': 'I never in a million years pictured myself putting a crib together.',
#   'timestamp': '00:26:52'},
#  {'speaker': 'SCOTT',
#   'text': "I know that I'm doing it for my son, and I'm taking pride in it.",
#   'timestamp': '00:26:57'},
#  {'speaker': 'KOURTNEY',
#   'text': "It's so cute that you put those animals out here like that.",
#   'timestamp': '00:27:01'},
#  {'speaker': 'SCOTT',
#   'text': 'Just wanted you to be happy.',
#   'timestamp': '00:27:04'},
#  {'speaker': 'KOURTNEY', 'text': 'Thank you.', 'timestamp': '00:27:06'},
#  {'speaker': 'KOURTNEY',
#   'text': 'It makes me happy.',
#   'timestamp': '00:27:07'},
#  {'speaker': 'KHLOE',
#   'text': 'Our mission is to teach Kris a lesson and give Bruce his balls back for life.',
#   'timestamp': '00:27:21'},
#  {'speaker': 'KHLOE', 'text': "So, we're here.", 'timestamp': '00:27:26'},
#  {'speaker': 'KIM',
#   'text': 'Hi. We are picking up a dress under "Kris Jenner."',
#   'timestamp': '00:27:33'},
#  {'speaker': 'KIM',
#   'text': "We're just gonna take this dress.",
#   'timestamp': '00:27:37'},
#  {'speaker': 'KHLOE', 'text': 'Thank you.', 'timestamp': '00:27:39'},
#  {'speaker': 'KIM',
#   'text': 'You can charge it to her.',
#   'timestamp': '00:27:39'},
#  {'speaker': 'KHLOE',
#   'text': 'Yeah, charge it to her account. Bye.',
#   'timestamp': '00:27:41'},
#  {'speaker': 'KIM', 'text': 'Bye-bye.', 'timestamp': '00:27:43'},
#  {'speaker': 'KHLOE', 'text': 'Bruce, got it.', 'timestamp': '00:27:44'},
#  {'speaker': 'KHLOE', 'text': 'Come on.', 'timestamp': '00:27:45'},
#  {'speaker': 'KIM', 'text': 'Mission accomplished.', 'timestamp': '00:27:46'},
#  {'speaker': 'BRUCE', 'text': 'Right.', 'timestamp': '00:27:47'},
#  {'speaker': 'BRUCE',
#   'text': 'Should we wait here, or what?',
#   'timestamp': '00:27:48'},
#  {'speaker': 'KHLOE',
#   'text': "Yeah, we're gonna wait here.",
#   'timestamp': '00:27:50'},
#  {'speaker': 'KHLOE',
#   'text': "She said she's on her way.",
#   'timestamp': '00:27:52'},
#  {'speaker': 'BRUCE',
#   'text': "I feel like it's, like, we're the cops.",
#   'timestamp': '00:27:53'},
#  {'speaker': 'BRUCE', 'text': "We're on stakeout.", 'timestamp': '00:27:55'},
#  {'speaker': 'BRUCE', 'text': 'This is wonderful.', 'timestamp': '00:27:56'},
#  {'speaker': 'KHLOE', 'text': 'This is a stakeout.', 'timestamp': '00:27:57'},
#  {'speaker': 'BRUCE',
#   'text': 'This is the stakeout?',
#   'timestamp': '00:27:58'},
#  {'speaker': 'KHLOE',
#   'text': "So, now that we're playing a waiting game...",
#   'timestamp': '00:28:01'},
#  {'speaker': 'BRUCE',
#   'text': "All right, I can't see.",
#   'timestamp': '00:28:03'},
#  {'speaker': 'BRUCE',
#   'text': "I'm gonna move up to the front seat.",
#   'timestamp': '00:28:05'},
#  {'speaker': 'KHLOE', 'text': 'Oh, sorry.', 'timestamp': '00:28:08'},
#  {'speaker': 'BRUCE',
#   'text': 'All right, where is she?',
#   'timestamp': '00:28:13'},
#  {'speaker': 'BRUCE',
#   'text': 'And I think you should make...',
#   'timestamp': '00:28:15'},
#  {'speaker': 'BRUCE',
#   'text': 'Oh, you got the phone call already?',
#   'timestamp': '00:28:16'},
#  {'speaker': 'KHLOE', 'text': 'Yeah.', 'timestamp': '00:28:18'},
#  {'speaker': 'BRUCE', 'text': 'Okay.', 'timestamp': '00:28:19'},
#  {'speaker': 'KHLOE', 'text': 'Come on, Kris.', 'timestamp': '00:28:20'},
#  {'speaker': 'BRUCE', 'text': 'Come on, Kris.', 'timestamp': '00:28:22'},
#  {'speaker': 'KHLOE',
#   'text': "Here we are at a stakeout, and literally it's been an hour, Kris is still not here, my ass is numb-- I mean, being a spy is really hard.",
#   'timestamp': '00:28:25'},
#  {'speaker': 'BRUCE',
#   'text': "There... she's parking.",
#   'timestamp': '00:28:37'},
#  {'speaker': 'KHLOE', 'text': 'Oh... yeah.', 'timestamp': '00:28:39'},
#  {'speaker': 'KHLOE',
#   'text': "You don't need to show 'em that.",
#   'timestamp': '00:28:41'},
#  {'speaker': 'BRUCE', 'text': 'All right, call her.', 'timestamp': '00:28:52'},
#  {'speaker': 'BRUCE', 'text': 'Now.', 'timestamp': '00:28:53'},
#  {'speaker': 'KRIS ', 'text': 'Hello?', 'timestamp': '00:28:55'},
#  {'speaker': 'KHLOE', 'text': 'Kris Jenner...', 'timestamp': '00:29:02'},
# ...
#   'timestamp': '00:38:49'},
#  {'speaker': 'TEACHER',
#   'text': 'So I want you to take a deep breath through your nose.',
#   'timestamp': '00:38:57'},
#  {'speaker': 'TEACHER',
#   'text': 'Open your mouth and relax it.',
#   'timestamp': '00:39:03'},
#  {'speaker': 'KOURTNEY',
#   'text': "I believe that everything's going to be okay.",
#   'timestamp': '00:39:14'},
#  {'speaker': 'KOURTNEY',
#   'text': "We're both totally on the same page now, and just moving forward in the right direction.",
#   'timestamp': '00:39:16'},
#  {'speaker': 'KIM',
#   'text': "So, what's, like, your plan?",
#   'timestamp': '00:39:41'},
#  {'speaker': 'KIM',
#   'text': 'Like, where are you going to stay?',
#   'timestamp': '00:39:44'},
#  {'speaker': 'ROBERT',
#   'text': 'When I get there, I\'m just going to go get a hotel room and, uh, I\'ll probably hit her up when I\'m out there, and just let her know, like, "Look, I\'m out here.',
#   'timestamp': '00:39:46'},
#  {'speaker': 'ROBERT',
#   'text': 'I came out here to see you, and like, I\'m being for real."',
#   'timestamp': '00:39:54'},
#  {'speaker': 'ROBERT',
#   'text': "As much as I don't agree with Rob going to New York, I really get what Rob is going through because I used to go and fly to see Reggie when we were broken up.",
#   'timestamp': '00:40:01'},
#  {'speaker': 'ROBERT',
#   'text': "He's my little brother.",
#   'timestamp': '00:40:10'},
#  {'speaker': 'ROBERT',
#   'text': "I'm going to support him no matter what.",
#   'timestamp': '00:40:11'},
#  {'speaker': 'KIM', 'text': 'Hey, okay.', 'timestamp': '00:40:13'},
#  {'speaker': 'KIM',
#   'text': 'I am just taking Rob to the airport.',
#   'timestamp': '00:40:18'},
#  {'speaker': 'KIM',
#   'text': "I'm going to call you as soon as I'm done.",
#   'timestamp': '00:40:21'},
#  {'speaker': 'KIM', 'text': 'Bye.', 'timestamp': '00:40:23'},
#  {'speaker': 'ROBERT',
#   'text': 'I just got this email from Adrienne.',
#   'timestamp': '00:40:25'},
#  {'speaker': 'KIM', 'text': 'What?', 'timestamp': '00:40:27'},
#  {'speaker': 'KIM', 'text': 'What does it say?', 'timestamp': '00:40:28'},
#  {'speaker': 'ROBERT', 'text': 'Wait, pull over.', 'timestamp': '00:40:29'},
#  {'speaker': 'ROBERT',
#   'text': 'All of a sudden, I get an email.',
#   'timestamp': '00:40:30'},
#  {'speaker': 'KIM', 'text': "What's going on?", 'timestamp': '00:40:33'},
#  {'speaker': 'KIM',
#   'text': 'Why are you making me pull over?',
#   'timestamp': '00:40:34'},
#  {'speaker': 'ROBERT',
#   'text': "Because I just got an email that's from her.[ Female Announcer ] We were learned regenerist beat the $100 cream.",
#   'timestamp': '00:40:35'},
#  {'speaker': 'ROBERT',
#   'text': 'Floored when we whipped the $350 cream.',
#   'timestamp': '00:40:47'},
#  {'speaker': 'ROBERT',
#   'text': 'And finally, flabbergasted when we creamed the $700 cream!',
#   'timestamp': '00:40:50'},
#  {'speaker': 'ROBERT',
#   'text': "For under $30 olay regenerist micro-sculpting cream, according to a european independent study, hydrates better and longer than 32 of the world's most expensive creams.",
#   'timestamp': '00:40:55'},
#  {'speaker': 'ROBERT',
#   'text': 'Fantastic. phenomenal.',
#   'timestamp': '00:41:05'},
#  {'speaker': 'ROBERT', 'text': 'Olay regenerist.', 'timestamp': '00:41:08'},
#  {'speaker': 'ROBERT',
#   'text': "Love the skin you're in.",
#   'timestamp': '00:41:09'},
#  {'speaker': 'ROBERT',
#   'text': 'For hundreds and hundreds less.',
#   'timestamp': '00:41:10'},
#  {'speaker': 'ROBERT',
#   'text': 'I just got this email from Adrienne.',
#   'timestamp': '00:43:17'},
#  {'speaker': 'KIM', 'text': 'What?', 'timestamp': '00:43:19'},
#  {'speaker': 'KIM', 'text': 'What does it say?', 'timestamp': '00:43:20'},
#  {'speaker': 'ROBERT', 'text': 'Wait, pull over.', 'timestamp': '00:43:21'},
#  {'speaker': 'KIM', 'text': "What's going on?", 'timestamp': '00:43:22'},
#  {'speaker': 'KIM',
#   'text': 'Why are you making me pull over?',
#   'timestamp': '00:43:23'},
#  {'speaker': 'ROBERT',
#   'text': "Because I just got an email that's from her.",
#   'timestamp': '00:43:24'},
#  {'speaker': 'ROBERT',
#   'text': '"Don\'t take this email the wrong way, but this is from the new man in her life."',
#   'timestamp': '00:43:28'},
#  {'speaker': 'ROBERT', 'text': 'Yeah.', 'timestamp': '00:43:33'},
#  {'speaker': 'ROBERT',
#   'text': '"We\'re trying to start off on the right note and you\'re really not making it easy.',
#   'timestamp': '00:43:34'},
#  {'speaker': 'ROBERT',
#   'text': "Her Blackberry goes off every minute and it's you almost every time.",
#   'timestamp': '00:43:38'},
#  {'speaker': 'ROBERT',
#   'text': "I can't imagine what you guys really have to discuss after all this time.",
#   'timestamp': '00:43:43'},
#  {'speaker': 'ROBERT',
#   'text': "It's honestly annoying and unhealthy for our relationship.",
#   'timestamp': '00:43:47'},
#  {'speaker': 'ROBERT',
#   'text': "I respect what you guys had in the past, but according to her, it's clearly over.",
#   'timestamp': '00:43:49'},
#  {'speaker': 'ROBERT', 'text': 'Thanks, Dogs1."', 'timestamp': '00:43:55'},
#  {'speaker': 'ROBERT', 'text': "I'm turning around.", 'timestamp': '00:44:02'},
#  {'speaker': 'ROBERT',
#   'text': "Like, you're not even going to New York.",
#   'timestamp': '00:44:03'},
#  {'speaker': 'ROBERT', 'text': "I'm sorry.", 'timestamp': '00:44:05'},
#  {'speaker': 'ROBERT', 'text': 'You just...', 'timestamp': '00:44:06'},
#  {'speaker': 'KIM',
#   'text': 'On our way to the airport, on our way to the airport, you get an email from him, like, "Sorry." But this isn\'t the biggest sign?',
#   'timestamp': '00:44:07'},
#  {'speaker': 'ROBERT',
#   'text': "I've done every single thing.",
#   'timestamp': '00:44:14'},
#  {'speaker': 'ROBERT',
#   'text': "I've made myself look like an idiot.",
#   'timestamp': '00:44:17'},
#  {'speaker': 'ROBERT',
#   'text': 'I made myself, you know...',
#   'timestamp': '00:44:19'},
#  {'speaker': 'KIM',
#   'text': "And that's what you do for someone that you love.",
#   'timestamp': '00:44:21'},
#  {'speaker': 'KIM',
#   'text': "You do it and if you've tried everything you can, and they're not, you know, giving you back what you need in return...",
#   'timestamp': '00:44:23'},
#  {'speaker': 'ROBERT', 'text': 'And it sucks.', 'timestamp': '00:44:30'},
#  {'speaker': 'KIM',
#   'text': "After you've tried everything, then now you know you have to move on.",
#   'timestamp': '00:44:31'},
#  {'speaker': 'KIM',
#   'text': 'And this was the biggest sign ever.',
#   'timestamp': '00:44:34'},
#  {'speaker': 'ROBERT',
#   'text': "As hard as it is to let go of the love of my life, I needed to learn that cheating isn't acceptable.",
#   'timestamp': '00:44:36'},
#  {'speaker': 'ROBERT',
#   'text': "I'll never, ever do this to my wife, to my future girlfriend.",
#   'timestamp': '00:44:42'},
#  {'speaker': 'ROBERT',
#   'text': "It sucks so much and I'm, like, in so much pain, but I have to move on and it just... sucks.",
#   'timestamp': '00:44:45'},
#  {'speaker': 'ROBERT', 'text': 'I just...', 'timestamp': '00:44:53'},
#  {'speaker': 'ROBERT', 'text': "I'm, like...", 'timestamp': '00:44:54'},
#  {'speaker': 'ROBERT',
#   'text': "I just can't believe that, like, I loved her so much.",
#   'timestamp': '00:44:57'},
#  {'speaker': 'BRUCE',
#   'text': "All right, we're here.",
#   'timestamp': '00:45:19'},
#  {'speaker': 'KRIS',
#   'text': 'Okay, show me your fabulous toy store, honey.',
#   'timestamp': '00:45:34'},
#  {'speaker': 'BRUCE', 'text': 'Come on.', 'timestamp': '00:45:39'},
#  {'speaker': 'KRIS', 'text': 'I feel really bad.', 'timestamp': '00:45:40'},
#  {'speaker': 'KRIS',
#   'text': "I really didn't look at the big picture of Bruce's spending, so I have the perfect way to make this whole thing up to Bruce.",
#   'timestamp': '00:45:41'},
#  {'speaker': 'BRUCE',
#   'text': "I'm very excited about this.",
#   'timestamp': '00:45:49'},
#  {'speaker': 'BRUCE',
#   'text': "Don't dampen my enthusiasm.",
#   'timestamp': '00:45:51'},
#  {'speaker': 'BRUCE',
#   'text': "It's like a good pair of Manolo Blahniks.",
#   'timestamp': '00:45:52'},
#  {'speaker': 'KRIS', 'text': 'Knock yourself out.', 'timestamp': '00:45:55'},
#  {'speaker': 'BRUCE',
#   'text': 'Think of it that way.',
#   'timestamp': '00:45:56'},
#  {'speaker': 'BRUCE',
#   'text': 'We need that in the house.',
#   'timestamp': '00:45:58'},
#  {'speaker': 'BRUCE',
#   'text': 'The kids would like that.',
#   'timestamp': '00:45:59'},
#  {'speaker': 'KRIS',
#   'text': "No, we don't need that in the house.",
#   'timestamp': '00:46:00'},
#  {'speaker': 'KRIS',
#   'text': 'Okay, show me what the 700 looks like.',
#   'timestamp': '00:46:02'},
#  {'speaker': 'BRUCE',
#   'text': 'Well, there it is, honey.',
#   'timestamp': '00:46:04'},
#  {'speaker': 'KRIS', 'text': "It's beautiful.", 'timestamp': '00:46:06'},
#  {'speaker': 'BRUCE',
#   'text': "And you're buying it for me.",
#   'timestamp': '00:46:07'},
#  {'speaker': 'KRIS', 'text': 'Okay, great.', 'timestamp': '00:46:09'},
#  {'speaker': 'KRIS', 'text': "I'm happy to do that.", 'timestamp': '00:46:09'},
#  {'speaker': 'KRIS',
#   'text': 'All right, so how much is this helicopter?',
#   'timestamp': '00:46:10'},
#  {'speaker': 'CLERK', 'text': 'Close to $3,000.', 'timestamp': '00:46:13'},
#  {'speaker': 'CLERK', 'text': 'Mm-hmm.', 'timestamp': '00:46:16'},
#  {'speaker': 'CLERK', 'text': 'Yeah.', 'timestamp': '00:46:18'},
#  {'speaker': 'KRIS',
#   'text': 'For this-- For this toy?',
#   'timestamp': '00:46:19'},
#  {'speaker': 'BRUCE',
#   'text': "Well, it's not a toy, honey, this is a very sophisticated piece of equipment.",
#   'timestamp': '00:46:21'},
#  {'speaker': 'BRUCE',
#   'text': 'I mean, this is like what the pros use.',
#   'timestamp': '00:46:25'},
#  {'speaker': 'KRIS', 'text': 'There you go, honey.', 'timestamp': '00:46:27'},
#  {'speaker': 'BRUCE', 'text': 'Throw it down.', 'timestamp': '00:46:28'},
#  {'speaker': 'KRIS', 'text': 'Have a good time.', 'timestamp': '00:46:29'},
#  {'speaker': 'BRUCE', 'text': 'Thanks.', 'timestamp': '00:46:30'},
#  {'speaker': 'KRIS',
#   'text': 'You work really hard and you deserve to have what you want and to have fun in life and this is your hobby, so go for it.',
#   'timestamp': '00:46:31'},
#  {'speaker': 'KRIS', 'text': "I think it's cool.", 'timestamp': '00:46:38'},
#  {'speaker': 'BRUCE', 'text': 'All right.', 'timestamp': '00:46:39'},
#  {'speaker': 'BRUCE', 'text': 'Okay.', 'timestamp': '00:46:40'},
#  {'speaker': 'BRUCE',
#   'text': 'I have no problem with that.',
#   'timestamp': '00:46:41'},
#  {'speaker': 'BRUCE',
#   'text': "I guarantee, no matter what I spend here, it's a lot less than what you do.",
#   'timestamp': '00:46:43'},
#  {'speaker': 'KRIS',
#   'text': "Honey, I think it's good you put your foot down.",
#   'timestamp': '00:46:48'},
#  {'speaker': 'KRIS',
#   'text': 'I think actually, you getting mad at me was actually kind of sexy.',
#   'timestamp': '00:46:51'},
#  {'speaker': 'BRUCE', 'text': 'Really?', 'timestamp': '00:46:54'},
#  {'speaker': 'KRIS', 'text': 'Yeah.', 'timestamp': '00:46:54'},
#  {'speaker': 'BRUCE',
#   'text': 'I got to try that more often.',
#   'timestamp': '00:46:55'},
#  {'speaker': 'KRIS',
#   'text': 'I know, you ought to try that more often.',
#   'timestamp': '00:46:56'},
#  {'speaker': 'KRIS',
#   'text': "Get your toy and let's go.",
#   'timestamp': '00:46:58'},
#  {'speaker': 'BRUCE', 'text': 'Okay, thank you.', 'timestamp': '00:47:00'},
#  {'speaker': 'BRUCE', 'text': 'Thank you, honey.', 'timestamp': '00:47:01'},
#  {'speaker': 'KRIS', 'text': "Let's go, baby.", 'timestamp': '00:47:01'},
#  {'speaker': 'BRUCE',
#   'text': "You're so sweet, honey.",
#   'timestamp': '00:47:02'},
#  {'speaker': 'KRIS', 'text': 'I know.', 'timestamp': '00:47:04'},
#  {'speaker': 'KRIS', 'text': 'So are you.', 'timestamp': '00:47:04'},
#  {'speaker': 'BRUCE', 'text': 'See you guys later.', 'timestamp': '00:47:05'},
#  {'speaker': 'BRUCE',
#   'text': "I promise I won't crash it.",
#   'timestamp': '00:47:06'},
#  {'speaker': 'KRIS', 'text': 'Bye, everybody.', 'timestamp': '00:47:07'},
#  {'speaker': 'KRIS', 'text': 'Thank you!', 'timestamp': '00:47:09'},
#  {'speaker': 'KHLOE',
#   'text': 'So, are we not going to the movies?',
#   'timestamp': '00:47:13'},
#  {'speaker': 'KHLOE',
#   'text': "'Cause no one's doing anything.",
#   'timestamp': '00:47:15'},
#  {'speaker': 'KHLOE', 'text': "I don't get it.", 'timestamp': '00:47:16'},
#  {'speaker': 'ROBERT',
#   'text': "I'm actually trying to save this movie for this date that I have.",
#   'timestamp': '00:47:17'},
#  {'speaker': 'KHLOE', 'text': 'Yeah, right.', 'timestamp': '00:47:21'},
#  {'speaker': 'KHLOE', 'text': 'Well, what?', 'timestamp': '00:47:22'},
#  {'speaker': 'KHLOE',
#   'text': 'When did you meet her?',
#   'timestamp': '00:47:23'},
#  {'speaker': 'KHLOE', 'text': "I'm so proud of you.", 'timestamp': '00:47:24'},
#  {'speaker': 'ROBERT',
#   'text': 'Look, she gave this to me at Katsuya.',
#   'timestamp': '00:47:25'},
#  {'speaker': 'ROBERT', 'text': 'An Armenian girl.', 'timestamp': '00:47:28'},
#  {'speaker': 'KHLOE',
#   'text': '"Call me. Violet." With a happy face.',
#   'timestamp': '00:47:31'},
#  {'speaker': 'KHLOE',
#   'text': 'So, by going on this movie date, does that mean you are over Adrienne?',
#   'timestamp': '00:47:33'},
#  {'speaker': 'ROBERT',
#   'text': "I mean, it's my way of getting over her.",
#   'timestamp': '00:47:37'},
#  {'speaker': 'KHLOE', 'text': 'I told you.', 'timestamp': '00:47:41'},
#  {'speaker': 'KHLOE',
#   'text': "Cutting yourself off from the outside world and, like, waiting for Adrienne, that's never going to do anything for you.",
#   'timestamp': '00:47:42'},
#  {'speaker': 'KHLOE', 'text': 'So, wait.', 'timestamp': '00:47:47'},
#  {'speaker': 'KHLOE',
#   'text': 'So that means no movie for us.',
#   'timestamp': '00:47:47'},
#  {'speaker': 'ROBERT', 'text': "No, it isn't.", 'timestamp': '00:47:49'},
#  {'speaker': 'KHLOE', 'text': "You're saving it?", 'timestamp': '00:47:50'},
#  {'speaker': 'SCOTT',
#   'text': 'We could still go, Khlo.',
#   'timestamp': '00:47:51'},
#  {'speaker': 'KYLIE', 'text': 'Can I come?', 'timestamp': '00:47:53'},
#  {'speaker': 'KHLOE', 'text': "We'll all just go.", 'timestamp': '00:47:54'},
#  {'speaker': 'ROBERT', 'text': 'Yeah.', 'timestamp': '00:47:55'},
#  {'speaker': 'KHLOE',
#   'text': "Well, Rob, I'm so happy you're moving on.",
#   'timestamp': '00:47:56'},
#  {'speaker': 'ROBERT',
#   'text': "There's more love out there.",
#   'timestamp': '00:47:59'},
#  {'speaker': 'KHLOE',
#   'text': 'There is and it begins with us.',
#   'timestamp': '00:48:01'},
#  {'speaker': 'ROBERT', 'text': 'With Kylie.', 'timestamp': '00:48:03'},
#  {'speaker': 'KHLOE',
#   'text': "Kylie, don't go to him.",
#   'timestamp': '00:48:05'},
#  {'speaker': 'KHLOE',
#   'text': 'Kylie, pick or choose, now.',
#   'timestamp': '00:48:07'},
#  {'speaker': 'KYLIE', 'text': "You're mean to me.", 'timestamp': '00:48:08'},
#  {'speaker': 'KHLOE', 'text': "I'm mean?", 'timestamp': '00:48:09'},
#  {'speaker': 'KYLIE', 'text': 'Robert would never--', 'timestamp': '00:48:10'},
#  {'speaker': 'ROBERT',
#   'text': 'All right, all right, all right.',
#   'timestamp': '00:48:10'},
#  {'speaker': 'KHLOE', 'text': "You're dead, Kylie.", 'timestamp': '00:48:13'},
#  {'speaker': 'KRIS',
#   'text': 'Next onKeeping Up With the Kardashians:',
#   'timestamp': '00:48:18'},
#  {'speaker': 'KIM',
#   'text': 'I found the dog walking around in Calabasas.',
#   'timestamp': '00:48:18'},
#  {'speaker': 'WOMAN',
#   'text': 'She has a condition called pyometra.',
#   'timestamp': '00:48:21'},
#  {'speaker': 'KIM', 'text': "I can't watch that.", 'timestamp': '00:48:23'},
#  {'speaker': 'ROBERT', 'text': 'Just do it, bro.', 'timestamp': '00:48:25'},
#  {'speaker': 'BRUCE',
#   'text': 'Rob moving back in-- not a good thing.',
#   'timestamp': '00:48:27'},
#  {'speaker': 'BRUCE',
#   'text': 'Hey, what the hell are you guys doing?!',
#   'timestamp': '00:48:30'},
#  {'speaker': 'BRUCE',
#   'text': "I'm sick and tired of you babying this little kid.",
#   'timestamp': '00:48:32'},
#  {'speaker': 'KRIS', 'text': "I don't baby him.", 'timestamp': '00:48:33'},
#  {'speaker': 'BRUCE', 'text': "He's 22 years old!", 'timestamp': '00:48:34'},
#  {'speaker': 'BRUCE',
#   'text': 'Bill is getting his pilot license.',
#   'timestamp': '00:48:39'},
#  {'speaker': 'BRUCE',
#   'text': 'I have to get rid of my fear of flying.',
#   'timestamp': '00:48:41'}]

# %%
reply_matrix = create_reply_matrix(deduped_transcripts, good_speakers, n_good_speakers)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_reply_matrix` returns the correct output."""
assert type(reply_matrix) == np.ndarray
assert reply_matrix.shape == (8, 8)
assert reply_matrix[1][1] == 0
assert sum(reply_matrix[2]) > 2500
assert sum(reply_matrix[6]) < 950

# %%
plt.figure(figsize=(5, 5))
plt.imshow(reply_matrix, interpolation='none', cmap=plt.cm.Blues)
plt.colorbar()

plt.xticks(range(n_good_speakers), good_speakers, rotation=90)
plt.yticks(range(n_good_speakers), good_speakers)
plt.show()

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='green'> Question 4b (free response): Communication between characters </font> <a class="anchor" id="4b"></a>
#
# In the cell below, use Markdown to describe anything that you notice about the heatmap generated from ``reply_matrix``. What do you notice about the communication between certain characters?

# %% [markdown]
# **Solution**: YOUR ANSWER GOES HERE

# %% [markdown]
# - - -
# <p style="text-align:left;"> assignment-2 [PART 1] ends here <span style="float:right;font-size:11px;"> [[contents](#contents)] </span></p>
# - - -

# %% [markdown]
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### [PART 2] Interaction strength and social interaction patterns <a class="anchor" id="part2"></a>
# > <font color='red'>due 02/15 11:59pm</font>
#
# <u>Note</u>: Please ensure to have run [all the cells above](#part1) before proceeding further.

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Character-pair specific reply diction <a class="anchor" id="5"></a>
#
# #### <font color='blue'> Question 5a (code completion): Words used most specifically by pairs of characters </font> <a class="anchor" id="5a"></a>
#
# For this analysis, we will take only the pairs of characters that exchanged at least `min_exchange_messages` number of messages (e.g., 350 messages) between them (*good pairs*), in either direction. For example (in case of 350 messages), Speaker A and Speaker B are a *good pair* if A replies to B 175 times and B replies to A 175 times.
#
# We will represent these *good pairs* as tuple pairs of character names (ordered alphabetically) and build a matrix where the rows correspond to the pairs, and the columns to the *good type* words.
#
# You will begin by satisfying the specification in the cell below and determining the good pairs. The return type of the function will be a list of tuples in the following format:
# ```json
# [(CHARACTER_NAME_A, CHARACTER_NAME_B),
#  (CHARACTER_NAME_A, CHARACTER_NAME_C),
#  ...
# ]
# ```
#
# **Note: We will be numerically sorting the good pairs later.**
#
# Hint: You are to only look at the interaction between the pairs, not all words each person says. As such you should be only relying on the `reply_matrix`.

# %%
def create_good_pairs(input_reply_matrix,
                      input_good_speakers,
                      input_n_speakers,
                      min_exchange_messages=350):
    """Create "good pairs" based on the number of messages exchanged.
    
    Returns a tuple list of good pairs in the following format:
    ```[(CHARACTER_NAME_A, CHARACTER_NAME_B), (CHARACTER_NAME_A, CHARACTER_NAME_C), ...]```.
    
    Note: Good pairs are bi-directional and should be included only once. That is, if (A, B) is in 
    the list, (B, A) should not be. Names should be ordered alphbetically within each tuple. Also,
    sorting the good pairs need not be handled in this function.
    
    Parameters
    ----------
    input_reply_matrix : np.ndarray
        The reply matrix of shape (`input_n_speakers`, `input_n_speakers`) such that an entry (i, j)
        indicates the number of times speaker `j` replied to speaker `i`.
    input_good_speakers : list
        A list of chosen "good" speakers.
    input_n_speakers : int
        The number of input speakers to be chosen in constructing the good pairs (essentially, the
        number of good speakers).
    min_exchange_messages : int
        The minimum number of messages to be exchanged between a character pair for them to be 
        considered a "good pair" (defaults to 350).
    
    Returns
    -------
    list
        A list of tuples of good pairs, based on the number of messages exchanged.
    """
    # YOUR CODE GOES HERE
    raise NotImplementedError()

# %%
good_pairs = create_good_pairs(reply_matrix, good_speakers, n_good_speakers)
good_pairs.sort()

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_good_pairs` returns the correct output."""
assert type(good_pairs) == list
assert len(good_pairs) < 15 and len(good_pairs) > 10
assert good_pairs[0] == tuple(sorted(good_pairs[0]))
assert (reply_matrix[tuple([good_speakers.index(s) for s in good_pairs[0]])] +
        reply_matrix[tuple([good_speakers.index(s) for s in good_pairs[0]][::-1])]) >= 350

# %%
# To help you for the next couple of functions. We recommend you use the following variables
# as well as the good_type_reverse_index variable defined before
n_good_pairs = len(good_pairs)
good_pairs_reverse_index = {t: i for i, t in enumerate(good_pairs)}


# We have attached a tokenize method that you should use below:
def tokenize(text):
    """Returns a list of words that make up the text.    
    
    Parameters
    ----------
    text : str
        The input text string
    
    Returns
    -------
    list
        A list of tokens corresponding to the input string.
    """
    return [x for x in re.findall(r"[a-z]+", text.lower())]

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 5b (code completion): Building character-pair word occurrence matrix </font> <a class="anchor" id="5b"></a>
#
# As we continue the analysis we hope to build a character-pair word occurrence matrix. This matrix has rows that correspond to *good pairs* and columns that correspond to *good type* words.
#
# Note that here, like in [Question 3a](#3a), we consider B to be replying to A **only when speaker A gets a reply from speaker B in the next utterance**. Do not merge consecutive lines by the same speaker as the same speech/reply. For instance, in the example:
# ```json
# Line 1: {speaker: A, text: ...}
# Line 2: {speaker: A, text: ...}
# Line 3: {speaker: B, text: ...}
# Line 4: {speaker: B, text: ...}
# Line 5: {speaker: A, text: ...}
# ```
# If (A, B) is a *good pair*, then
# * Line 3 should be included in (A, B)'s reply diction.
# * Line 5 should be included in (A, B)'s reply diction.
#
# As such, in the cell below, fulfill the specification to build this (`input_n_good_pairs`, `input_n_good_types`) matrix:

# %%
def create_pair_words_mat(input_tokenize_method, input_deduped_transcripts, input_good_speakers,
                          input_n_speakers, input_n_good_types, input_n_good_pairs):
    """Create character-pair word occurrence matrix.
    
    Returns a np.ndarray of shape (`input_n_good_pairs`, `input_n_good_types`) such that the entry
    (i, j) indicates how many times pair `i` has replied good type word `j`.
    
    Hint: Use the global variables `good_pairs_reverse_index` and `good_types_reverse_index`.
    
    Parameters
    ----------
    input_tokenize_method : function
        A method that tokenizes the input text into tokens.
    input_deduped_transcripts : list
        The list of input deduped transcripts, loaded from assignment 1.
    input_good_speakers : list
        A list of chosen "good" speakers.
    input_n_speakers : int
        The number of input speakers to be chosen in constructing the matrix (essentially, the 
        number of good speakers).
    input_n_good_types : int
        The number of input good type words.
    input_n_good_pairs : int
        The number of input good character pairs.
    
    Returns
    -------
    np.ndarray
        An array of shape (`input_n_good_pairs`, `input_n_good_pairs`) such that the entry (i, j) 
        indicates how many times pair `i` has replied good type word `j`.
    """
    # YOUR CODE GOES HERE
    raise NotImplementedError()

# %%
pair_words_mat = create_pair_words_mat(tokenize, deduped_transcripts, good_speakers,
                                       n_good_speakers, n_good_types, n_good_pairs)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_pair_words_mat` returns the correct output."""
assert type(pair_words_mat) == np.ndarray
assert pair_words_mat.shape == (n_good_pairs, n_good_types)
assert sum(pair_words_mat[5]) > 2000
assert sum(pair_words_mat[:, 8]) == 0

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 5c (code completion): Weighting the character-pair word occurrences </font> <a class="anchor" id="5c"></a>
#
# We will finish this analysis by reweighting the character-pair word occurrences such that each entry corresponds to the ratio between how often a given pair says a word and how often all of the *good pairs* said that word. This can be done quite simply with numpy primitives.
#
# In order to de-emphasize the ratios of rare words (i.e. words in rare contexts are more likely to occur for only a single pair), we will apply additive smoothing also known as Laplace smoothing. This means that we will add one to each character-pair word occurrence before reweighting. So, for a given word $w$, pair $p$, and character-pair word occurrence $\text{count}(p, w)$, the weighted occurrence $W(p, w)$ is
#
# $$ W(p, w) = \frac{\text{count}(p, w) + 1}{\displaystyle\sum_{\pi\,\in\,\text{good pairs}} \big(\text{count}(\pi, w) + 1\big)} $$
#
# Below are a few examples of how some ratios will change assuming there are 10 good pairs.
#
# $$
# \begin{align*}
# \frac{2}{2} = 1.0 \rightarrow \frac{3}{2 + 10} = 0.25;\,\,\, \frac{50}{50} = 1.0 \rightarrow \frac{51}{50 + 10} = 0.85;\,\,\, \frac{9}{10} = 0.9 \rightarrow \frac{10}{10 + 10} = 0.5
# \end{align*}
# $$
#
#
# In the cell below, complete the specification and return the weighted words by each pair:

# %%
def create_weighted_words(input_pair_words_mat):
    """Create weighted character-pair word occurrence matrix.
    
    Returns a np.ndarray with the same shape as `input_pair_words_mat`, such that entry (i, j) 
    indicates a weighted score showing how often a given pair replied a word.
    
    Note: Words may not be said by any pair.
    Hint: Use numpy primitives to optimize this function.
    
    Parameters
    ----------
    input_pair_words_mat : np.ndarray
        The character-pair word occurrence matrix with an entry (i, j) indicating how many times 
        pair `i` has replied good type word `j`.
    
    Returns
    -------
    np.ndarray
        A weighted character-pair word occurrence matrix such that entry (i, j) indicates a weighted
        score showing how often a given pair replied a word.
    """
    # YOUR CODE GOES HERE
    raise NotImplementedError()

# %%
weighted_words = create_weighted_words(pair_words_mat)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_weighted_words` returns the correct output."""
assert type(weighted_words) == np.ndarray
assert weighted_words.shape == (n_good_pairs, n_good_types)
assert_almost_equal(weighted_words[-1, 1], 1 / 9)
assert_almost_equal(round(sum(weighted_words[:, 0]), 5), 1)
assert_almost_equal(round(sum(weighted_words[:, 2]), 5), 1)
assert sum(weighted_words[5]) > 100

# %% [markdown]
# Now, we can display the top 10 words between good pairs:

# %%
for i, j in good_pairs:
    print("{}, {}".format(i, j))
    words = weighted_words[good_pairs_reverse_index[i, j]]
    ranked = sorted(enumerate(words), key=lambda x: x[1], reverse=True)
    for index, score in ranked[:10]:
        print("{:.2f} {}".format(score, good_types[index]))
    print()

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='green'> Question 5d (free response): Analyzing character-pair specific diction </font> <a class="anchor" id="5d"></a>
#
# Now we have some sensible results to understand the specific diction between character pairs. In the cell below, please use Markdown to note any interesting observations/analysis you can take-away from the results above.

# %% [markdown]
# **Solution**: YOUR ANSWER GOES HERE

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Strength of interactions between speaker pairs <a class="anchor" id="6"></a>
#
# #### <font color='blue'> Question 6a (code completion): Pair interaction strength </font> <a class="anchor" id="6a"></a>
#
# In this question we will look at the strength of interactions between *all good speaker pairs* and how that relates to the similarity in their speech. We define interaction strength as the number of interactions between characters.
#
# To do this, we will start by making some modifications to our `reply_matrix`.
# We want an `interaction_matrix` which includes the number of interactions between a pair of characters in total, not just the number of times a character has spoke to another character. Put another way, we want the matrix to be bi-directional and symmetric. To use our example:
# ```json
# Line 1: {speaker: A, text: ...}
# Line 2: {speaker: A, text: ...}
# Line 3: {speaker: B, text: ...}
# Line 4: {speaker: B, text: ...}
# ```
# Line 3 should be considered an interaction between pair (Character A, Character B) as well as pair (Character B, Character A) in the `interaction_matrix`.

# %%
def create_interaction_mat(input_reply_matrix, input_n_speakers):
    """Create an interaction matrix.
    
    Returns a np.ndarray of shape (`input_n_speakers`, `input_n_speakers`), such that the entry
    (i, j) indicates the combined number of times speaker `j` started a conversation with speaker
    `i` and vice versa.
    
    Parameters
    ----------
    input_reply_matrix : np.ndarray
        The reply matrix of shape (`input_n_speakers`, `input_n_speakers`) such that an entry (i, j)
        indicates the number of times speaker `j` replied to speaker `i`.
    input_n_speakers : int
        The number of input speakers to be chosen in constructing the reply matrix.
    
    Returns
    -------
    np.ndarray
        An interaction matrix, such that the entry (i, j) indicates the combined number of times 
        speaker `j` started a conversation with speaker `i` and vice versa.
    """
    # YOUR CODE GOES HERE
    raise NotImplementedError()

# %%
interaction_matrix = create_interaction_mat(reply_matrix, n_good_speakers)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_exchange_mat` returns the correct output."""
assert type(interaction_matrix) == np.ndarray
assert interaction_matrix.shape == (8, 8)
assert sum(interaction_matrix[0]) > 3000 and sum(interaction_matrix[0]) < 3200
assert sum(interaction_matrix[:, 0]) > 3000 and sum(interaction_matrix[:, 0]) < 3200

# %% [markdown]
# Now let's take a look at how pair interaction strength compares with pair speech similarity. We first do this by looking at  trends for a specific character.

# %%
def character_interaction_similarity_plot(input_interaction_matrix, input_similarity_matrix,
                                          input_character):
    """Plot the interaction-similarity relation for an `input_character`.
    
    x-axis: lists `good_speakers` in the order of high to low interaction with `input_character`.
    y-axis: generalized Jaccard similarity between each `good_speaker` and `input_character` pair.
    
    Parameters
    ----------
    input_interaction_matrix : np.ndarray
        An interaction matrix of shape (`input_n_good_pairs`, `input_n_good_pairs`), such that the
        entry (i, j) indicates the combined number of times speaker `j` started a conversation with
        speaker `i` and vice versa.
    input_similarity_matrix : np.ndarray
        The similarity matrix of (`input_n_speakers`, `input_n_speakers`), with the entry (i, j)
        indicating the generalized Jaccard similarity between the speakers `i` and `j`.
    input_character : str
        The chosen character for whom the interaction-similarity plot is to be drawn.
    """
    n = good_speakers.index(input_character)
    interaction_order = [
        idx
        for idx, sim in sorted(enumerate(interaction_matrix[n]), reverse=True, key=lambda x: x[1])
    ]
    similarity = [g_j_sim_matrix[n][i] for i in interaction_order]
    index = np.arange(n_good_speakers)

    plt.bar(index, similarity, color='tab:blue')

    plt.title(good_speakers[n])
    plt.xlabel('Interaction strength (high to low)')
    plt.ylabel('Similarity')
    plt.xticks(index, [good_speakers[i] for i in interaction_order])

    plt.show()

# %%
plt.figure(figsize=(10, 4))
character_interaction_similarity_plot(interaction_matrix, g_j_sim_matrix, "KIM")

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='green'> Question 6b (free response): Pair interaction strength and similarity </font> <a class="anchor" id="6b"></a>
#
# In the cell below, use Markdown to describe anything that you notice about how interaction strength compares to similarity for **Kim**.

# %% [markdown]
# **Solution**: YOUR ANSWER GOES HERE

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 6c (code completion): Analyzing pair interaction strength and similarity </font> <a class="anchor" id="6c"></a>
#
# To complete your analysis print a bar graph that generalizes the relationship between pair interaction strength and similarity. For simplicity, we rate each pair's interaction strength "high", "medium", and "low" depending on how many interactions were exchanged between the pair:
# * High interaction strength: more than 500 interactions,
# * Medium interaction strength: 150 interactions to 500 interactions (inclusive),
# * Low interaction strength: less than 150 interactions.
#
# In this analysis, categorize each pair into high, medium, or low interaction strength, and plot the average similarity of each category. That is, plot three bars on the x-axis (one for each category) against average similarity (for each category) on the y-axis.
#
# Note: Pairs of good speakers are bidirectional in this analysis and should be included only once. That is, if you've included (BRUCE, KRIS), you shouldn't include (KRIS, BRUCE). Also, do not include pairs between the same person (e.g. (KIM, KIM))
#
# Hint: Use `interaction_matrix` and `g_j_sim_matrix`.

# %%
# YOUR CODE GOES HERE
raise NotImplementedError()

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='green'> Question 6d (free response): Connecting pair interaction strength and similarity </font> <a class="anchor" id="6d"></a>
#
# These are some interesting connections between interaction strength and speech similarity. In the cell below, please use Markdown to note any interesting observations/analysis you can take-away from the results above.

# %% [markdown]
# **Solution**: YOUR ANSWER GOES HERE

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Speaker characteristics and social interaction <a class="anchor" id="7"></a>
#
# #### <font color='blue'> Question 7a (code completion): Age-group and social interaction </font> <a class="anchor" id="7a"></a>
#
# Often we might want to examine how interactions differ depending on the characteristics of the people involved. In this case, we are interested in the extent to which people interact differently depending on the ages of the people they are talking to.
#
# For example, do people from one age group talk differently to people of other age groups than to people of their own?
#
# For simplicity, we will divide the characters into two age groups and name them P for Parent and C for Child. We provide an age group dictionary below. You are welcome to **additionally** explore on your own other speaker characteristics.  If you find something interesting fill out the [optional free response cell below (7d)](#7d).
#
# We will start by building a matrix with rows corresponding to age group combinations and columns corresponding to good type words. Age group combination (P, C) means that a person from group C is replying to a person from group P. In this analysis, we will consider all interactions, not just the good pairs.
#
# In the cell below, complete the specification by returning the desired numpy array. (Hint: You can reuse your helper functions from above or the logic in the your previous methods.)
#
# **Note**: Only consider the `good_types` in replies.

# %%
# Here we provide you with the age groups for each character
# and age group combinations of interactions that you will be working with
age_group = {
    u'BRUCE': u'P',
    u'JONATHAN': u'C',
    u'KHLOE': u'C',
    u'KIM': u'C',
    u'KOURTNEY': u'C',
    u'KRIS': u'P',
    u'ROBERT': u'C',
    u'SCOTT': u'C'
}
age_group_index = {'P': 0, 'C': 1}
age_group_mat_index = {('P', 'P'): 0, ('P', 'C'): 1, ('C', 'P'): 2, ('C', 'C'): 3}

# %%
def create_age_words_mat(input_tokenize_method, input_deduped_transcripts, input_good_speakers,
                         input_n_good_types):
    """Create age-group interactions matrix.
    
    Returns a np.ndarray of shape (4, `input_n_good_types`) such that the entry (i, j) indicates the
    number of times age group pair `i` says word `j`.
    
    Hint: You should use the global variables: `good_types_reverse_index`, `age_group`, 
    `age_group_index`, and `age_group_mat_index`.
    
    Parameters
    ----------
    input_tokenize_method : function
        A method that tokenizes the input text into tokens.
    input_deduped_transcripts : list
        The list of input deduped transcripts, loaded from assignment 1.
    input_good_speakers : list
        A list of chosen "good" speakers.
    input_n_good_types : int
        The number of input good type words.
    
    Returns
    -------
    np.ndarray
        An array of age-group interactions, such that the entry (i, j) indicates the number of times
        age group pair `i` says word `j`.
    """
    # YOUR CODE GOES HERE
    raise NotImplementedError()

# %%
age_words_mat = create_age_words_mat(tokenize, deduped_transcripts, good_speakers, n_good_types)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_age_words_mat` returns the correct output."""
assert type(age_words_mat) == np.ndarray
assert age_words_mat.shape == (4, 4517)
assert sum(age_words_mat[1]) > 15000

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 7b (code completion): Weighting age-group interactions matrix </font> <a class="anchor" id="7b"></a>
#
# As we finish this portion of the analysis, we end by scoring the words by the ratio between how often a given age group combination said it and how often all of the combinations said it. This can be done quite simply with numpy primitives. As in [Question 5c](#5c), we will use additive smoothing to de-emphasize ratios of less frequent words.
#
# In the cell below, complete the specification and return the weighted words by each age group pair:
#
# Hint: You can reuse your helper functions from above or the logic in the your previous methods.

# %%
def create_age_weighted_words(input_age_words_mat):
    """Create weighted age-group interactions matrix.
    
    Returns a np.ndarray with the same shape as `input_age_words_mat`, such that entry (i, j) 
    indicates a weighted score showing how often a given age-group pair `i` uttered a good type
    word `j`.
    
    Note: Words may not be said by any pair.
    Hint: Use numpy primitives to optimize this function.
    
    Parameters
    ----------
    input_age_words_mat : np.ndarray
        The age-group interactions matrix with an entry (i, j) indicating how many times age-group 
        pair `i` has uttered good type word `j`.
    
    Returns
    -------
    np.ndarray
        A weighted age-group interactions matrix with an entry (i, j) indicating how many times age
        group pair `i` has uttered good type word `j`.
    """
    # YOUR CODE GOES HERE
    raise NotImplementedError()

# %%
age_weighted_words = create_age_weighted_words(age_words_mat)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `create_gender_weighted_words` returns the correct output."""
assert type(age_weighted_words) == np.ndarray
assert age_weighted_words.shape == (4, 4517)
assert_almost_equal(round(sum(age_weighted_words[:, 0]), 5), 1)
assert_almost_equal(age_weighted_words[0, 1], 0.1)

# %%
for i, j in age_group_mat_index.keys():
    print(i, j)
    words = age_weighted_words[age_group_mat_index[(i, j)]]
    ranked = sorted(enumerate(words), key=lambda x: x[1], reverse=True)
    for index, score in ranked[:10]:
        print('{:.2f} {}'.format(score, good_types[index]))
    print()

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='green'> Question 7c (free response): Analyzing age-group and social interaction </font> <a class="anchor" id="7c"></a>
#
# These are some interesting results in regards to uncovering age group and the social interaction between age group pairs. In the cell below, please use Markdown to note any interesting observations/analysis you can take-away from the results above.

# %% [markdown]
# **Solution**: YOUR ANSWER GOES HERE

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> [optional] Question 7d (code completion): Other characteristics and social interaction </font> <a class="anchor" id="7d"></a>
#
# We might want to examine how interactions differ depending on other characteristics of the people involved. You are welcome to **additionally** explore on your own other characteristics of the people. If you find something interesting fill out the optional free response cell below.<br>
#
# While no extra points will be awarded for this task, it may help you with your extra-credit assignment.

# %%
# YOUR CODE GOES HERE

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Priming: Word choice influenced by the person being spoken to <a class="anchor" id="8"></a>
#
# <a href=https://en.wikipedia.org/wiki/Priming_(psychology)>Priming</a> is the phenomenon where a speaker tends to repeat certain words or language characteristics of the person they are replying to. It turns out that priming can often be observed in conversation. If A is talking to B, B will sometimes mirror A's language.
#
# #### <font color='blue'> Question 8a (code completion): Character priming matrix </font> <a class="anchor" id="8a"></a>
#
# In this analysis we will be looking at priming: i.e. when speaker B replies to speaker A, what is the probability that a word said by A will be repeated by B?
#
# That is, how many of the words in B's reply were also said by A (normalized by the number of words B said in total)?
# Specifically, consider the following example:
#
# ```
# Catelyn : Hi Ned, it is a really nice day today. Yes, it is.
# Ned : It is a really really nice day today. Yes.
# ```
#
# We should take the set of all words said by Catelyn: $W_c = \{$hi, ned, it, is, a, really, nice, day, today, yes$\}$, and the set of all words said by Ned: $W_n = \{$it, is, a, really, nice, day, today, yes$\}$, and perform the *priming computation*:
#
# $$\frac{\left|W_c \cap W_n\right|}{\left|W_n\right|}$$
#
# For a specific *ordered* pair of speakers A and B, we calculate the *arithmetic mean* of priming computations among all instances of B replying to A to get a single number between $0$ and $1$ as the answer to this question. That is, sum up the primed proportion for every B's reply to A and divide it by the number of times B replied to A.
#
# The next couple methods will walk you through necessary pre-computations to get this priming matrix.
# Do read through these functions carefully as you will be using their results.

# %%
def merge_deduped(transcripts):
    """Merges adjacent transcript lines by the same speaker."""
    result = []
    for t_id, tscript in transcripts:
        prev_speaker = tscript[0]['speaker']
        prev_line = tscript[0]['text']
        tscript_result = []
        for i in range(1, len(tscript)):
            curr_speaker = tscript[i]['speaker']
            curr_line = tscript[i]['text']
            if curr_speaker == prev_speaker:
                prev_line = prev_line + " " + curr_line
            else:
                tscript_result.append({'speaker': prev_speaker, 'text': prev_line})
                prev_speaker = curr_speaker
                prev_line = curr_line
            if i == len(tscript) - 1:
                tscript_result.append({'speaker': prev_speaker, 'text': prev_line})
        result.append((t_id, tscript_result))
    return result


merged_deduped_transcripts = merge_deduped(deduped_transcripts)


def prev_lines_and_replies(A, B, tscript):
    """
    Creates an array of all the transcript lines involving supposed correspondence between A (first 
    speaker) and B (second speaker), both previous message and current message.
    """
    # Prepare results for B responses to A, previous speak.
    result = []
    prev_speaker = None
    prev_line = None

    # Go through every line of the transcript.
    for line in tscript:
        curr_speaker = line['speaker']

        # If dialogue has happened.
        if ((curr_speaker == B and prev_speaker == A)):
            # Add the previous line and the current line.
            result.append([prev_line, line])

        # Update the speaker and line.
        prev_speaker = curr_speaker
        prev_line = line

    return result


def ordered_lines_for_pair(A, B):
    """Gathers all lines in all transcripts for an ORDERED pair of characters."""
    result = []

    for _, tscript in merged_deduped_transcripts:
        result = result + prev_lines_and_replies(A, B, tscript)
    return result


def ordered_pairs_all_lines():
    """Gathers all lines in all transcripts for all ORDERED pairs of good characters."""
    result = dict()

    # Setup pairings (tuples).
    for i in range(0, n_good_speakers):
        for j in range(0, n_good_speakers):
            if i != j:
                tup = (good_speakers[i], good_speakers[j])
                result[tup] = ordered_lines_for_pair(*tup)
    return result


# Groupings per pair.
ordered_pairs_lines = ordered_pairs_all_lines()

# %% [markdown]
# So, `ordered_pairs_lines` is a data structure containing all of the lines and replies between the pairs of speakers, organized in the following way:
#
# `dict → list → list → dict`
# ```json
# (A, B): [
#            [{speaker: A, text: ...}, {speaker: B, text: ...}],
#            [{speaker: A, text: ...}, {speaker: B, text: ...}],
#            ...
#         ]
# ```
#
# For example (not taken directly from the transcripts):
# ```json
# ('BRUCE', 'JONATHAN'): [
#                           [{'speaker': 'BRUCE', 'text': 'The guy is hitting on you, big-time.'},
#                            {'speaker': 'JONATHAN', 'text': 'And I am out of here early today.'}],
#                           [{'speaker': 'BRUCE', 'text': 'No, I am not making a scene.'},
#                            {'speaker': 'JONATHAN', 'text': 'What is that?'}],
#                        ]
# ```

# %% [markdown]
# In the cell below, fulfill the specification to return a priming matrix:
#
# Note: Ensure that only `good_types` are used. If you find that there are no good types in Speaker B's reply, skip that pair of lines (do not add anything to totals or proportions matrices) since there is no priming computation to be done.

# %%
def create_pair_priming_mat(input_tokenize_method, input_ordered_pair_lines, input_good_speakers,
                            input_n_speakers):
    """Create the priming matrix from pair-wise ordered transcript lines.
    
    Returns a np.ndarray of size (`input_n_speakers`, `input_n_speakers`) where entry (i, j) is the
    mean of priming computations (proportions where numerator is the number of good types in `j`'s 
    reply also said by `i` and denominator is number of good types in `j`'s reply) across all pairs
    of lines where `j` replied to `i`.
    
    Hint: Use numpy primitives to make this function optimal.
    Note: You should use `good_types_reverse_index` global variable. 
    
    Steps:
        1. Iterate through each tuple (for each pair i, j).
        2. Grab only good types.
        3. Do the necessary priming calculations.
    
    Parameters
    ----------
    input_tokenize_method : function
        A method that tokenizes the input text into tokens.
    input_ordered_pair_lines : dict
        A dictionary of all of the lines and replies between pairs of speakers, organized as a dict
        (keys: pairs of speakers) of list of dict lists (as values); see above for specifics.
    input_good_speakers : list
        A list of chosen "good" speakers.
    input_n_speakers : int
        The number of input speakers to be chosen in constructing the priming matrix.
    
    Returns
    -------
    np.ndarray
        The priming matrix of size (`input_n_speakers`, `input_n_speakers`), where entry (i, j) is
        the mean of priming computations across all pairs of lines where `j` replied to `i`.
    """

    # We are providing you the code structure below to help you get started in the right direction.
    # You may edit it, if you want.
    good_types_set = set(good_types_reverse_index.keys())

    # Resultant matricies.
    proportions = np.zeros((input_n_speakers, input_n_speakers))
    totals = np.zeros((input_n_speakers, input_n_speakers))

    # All the pairs.
    for pair in input_ordered_pair_lines.keys():
        A = pair[0]  # A, who is prompting B
        i = input_good_speakers.index(A)
        B = pair[1]  # B, who is responding to A
        j = input_good_speakers.index(B)
        # For tuple arrays for each pair.
        for arrs in input_ordered_pair_lines[pair]:
            # Grab sets of words.
            response = input_tokenize_method(arrs[1]['text'])
            B_sent = set(response)
            A_sent = set(input_tokenize_method(arrs[0]['text']))

            # TODO:
            # 1. Reduce `B_sent` to just good types.
            # 2. Up the total number of correspondences for each pair.
            # 3. Compute priming calculations and sum for each pair.

            # YOUR CODE GOES HERE

    totals[totals == 0] += 1
    answer = proportions / totals  # get arithmetic mean
    return answer

# %%
pair_priming_mat = create_pair_priming_mat(tokenize, ordered_pairs_lines, good_speakers,
                                           n_good_speakers)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `pair_priming_mat` returns the correct output."""
assert type(pair_priming_mat) == np.ndarray
assert pair_priming_mat.shape == (8, 8)
assert pair_priming_mat[0][0] == 0
assert pair_priming_mat[1][0] == 0
assert sum(pair_priming_mat[5]) > 0.7 and sum(pair_priming_mat[5]) < 0.8

# %%
plt.figure(figsize=(5, 5))
plt.imshow(pair_priming_mat, interpolation='none', cmap=plt.cm.Blues)
plt.colorbar()

plt.xticks(range(n_good_speakers), good_speakers, rotation=90)
plt.yticks(range(n_good_speakers), good_speakers)
plt.show()

# %% [markdown]
# Consider the three character pairs with the most priming, as well as the three with the least. **Note that priming is not symmetric.** For example, Kim might tend to mimic Kourtney more than Kourtney mimicing Kim.
#
# In the code we provided below we have ignored *ordered* pairs that have fewer than 100 words. Analyze the code and results provided:

# %%
mat_items = []
for i in range(n_good_speakers):
    for j in range(n_good_speakers):
        if i != j and reply_matrix[i, j] >= 100:
            mat_items.append((pair_priming_mat[i, j], (i, j)))
mat_items.sort()

print("Top three pairs:")
top_3_priming_pairs = []
for score, (i, j) in reversed(mat_items[-3:]):
    top_3_priming_pairs.append((i, j))
    print("- {} repeats {} (score: {:.4f})".format(good_speakers[j], good_speakers[i], score, 5))
print("\nBottom three pairs:")
for score, (i, j) in reversed(mat_items[:3]):
    print("- {} repeats {} (score: {:.4f})".format(good_speakers[j], good_speakers[i], score, 5))

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='green'> Question 8b (free response): Analyzing character priming findings </font> <a class="anchor" id="8b"></a>
#
# In the cell below, please use Markdown to describe anything that you notice about the heatmap generated from the priming matrix as well as the results above, in regards to the top/bottom three priming pairs. Were you expecting these results, or are were you surprised?

# %% [markdown]
# **Solution**: YOUR ANSWER GOES HERE

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 8c (code completion): Repeated words in replies </font> <a class="anchor" id="8c"></a>
#
# Next we are interested in the actual words that are being repeated in replies and how many times they are being repeated.
#
# In the following example:
# ```text
# Catelyn: Hi Ned, it is a really nice day today. Yes, it is.
# Ned    : It is a really really nice day today. Yes.
# ```
# We see that Ned repeats the words *it*, *is*, *a*, *nice*, *day*, *today*, and *yes* one time, and *really* two times.
#
# Note that in this analysis, we do not concern ourselves with how many times Catelyn repeats a word. That is, we disregard the fact that Catelyn has said the words *it* and *is* two times. We are only interested if Ned repeats words that Catelyn has said.
#
# For each of the three most-primed ordered pairs, what are the top 10 `good_types` being repeated? In the cell below, satisfy the specification to return the counts of repeated `good_types` per pair by returning a dictionary of word counts per ordered pair in the following format:
#
# ```json
# {(CHARACTER_NAME_A, CHARACTER_NAME_B):
#     {word_1: count_1, word_2: count_2, ...}
#  ...
# }
# ```

# %%
## Helper variables for the following cell.
ordered_pairs = list(ordered_pairs_lines.keys())
n_ordered_pairs = len(ordered_pairs)
ordered_pair_lookup = {}
for i in range(0, n_ordered_pairs):
    ordered_pair_lookup[ordered_pairs[i]] = i

# %%
def word_counts_per_ordered_pair(input_ordered_pairs, input_ordered_pairs_lines):
    """Retrieve word counts of primed words per ordered pair.
    
    Returns a dictionary that contains all the word counts of primed words (`good_types`) per 
    ordered pair in the following format:
    ```{
           (character_index_a, character_index_b): {word_1: count_1, word_2: count_2...},
           (character_index_a, character_index_c): {word_1: count_1, word_2: count_2...},
           ...
        ...
       }```.
    
    Hint: Make sure to use the `good_types_reverse_index` global variable.
    
    Note: The dictionary you are returning should contain all word counts of primed words 
    (`good_types`), not just the top ten, and for all pairs, not just the top three.
    
    Parameters
    ----------
    input_ordered_pairs : list
        A list of all ordered pairs of characters with correspondance in `input_ordered_pair_lines`.
    input_ordered_pair_lines : dict
        A dictionary of all of the lines and replies between pairs of speakers, organized as a dict
        (keys: pairs of speakers) of list of dict lists (as values); see above for specifics.
    
    Returns
    -------
    dict
        A dictionary that contains all the word counts of primed words (`good_types`) per ordered
        pair in the required format.
    """
    # YOUR CODE GOES HERE
    raise NotImplementedError()

# %%
priming_word_counts = word_counts_per_ordered_pair(ordered_pairs, ordered_pairs_lines)

# %%
# This is an autograder test. Here we can test the function you just wrote above.
"""Check that `priming_word_counts` returns the correct output."""
assert type(priming_word_counts) == dict
assert len(priming_word_counts[('BRUCE', 'JONATHAN')]) > 0
assert len(priming_word_counts[('KRIS', 'KOURTNEY')]) > 100
assert sum(priming_word_counts[('KIM', 'KRIS')].values()) > 1000

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='blue'> Question 8d (code completion): Character priming word analysis </font> <a class="anchor" id="8d"></a>
#
# To complete your analysis print the top ten words used by the top three priming pairs. The expected format is the following:
#
# ```json
# CHARACTER_NAME_A1 CHARACTER_NAME_A2
# WORD_1_COUNTS WORD_1
# ...
# WORD_10_COUNTS WORD_10
#
# CHARACTER_NAME_B1 CHARACTER_NAME_B2
# WORD_1_COUNTS WORD_1
# ...
# WORD_10_COUNTS WORD_10
#
# CHARACTER_NAME_C1 CHARACTER_NAME_C2
# WORD_1_COUNTS WORD_1
# ...
# WORD_10_COUNTS WORD_10
# ```
# where, (A1, A2), (B1, B2), and (C1, C2) represent the top three priming pairs. (You can use the global variable `top_3_priming_pairs`.)

# %%
# YOUR CODE GOES HERE
raise NotImplementedError()

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# #### <font color='green'> [optional] Question 8e (free response): Character priming and interaction strength </font> <a class="anchor" id="8e"></a>
#
# We have previously defined interaction strength and looked at the relationship between interaction strength and similarity. Here, we might also want to take a look at how interaction strength relates to the level of priming in each pair. That is, do pairs with stronger interaction strength tend to prime more? If you are curious, you can fill out this free response cell below and let us know.
#
# Note. While *no extra points* will be awarded for this task, it may help you with your extra-credit assignment.

# %%
# YOUR CODE GOES HERE

# %% [markdown]
# **Solution**: YOUR ANSWER GOES HERE

# %% [markdown]
# - - -
# <p style='text-align:right; font-size:11px'>[[contents](#contents)]</p>
#
# ### Can't get enough of language and information?  <a class="anchor" id="ec"></a>
#
# We have more! It is highly recommended that you check out **a2_extra_credit** for a chance to analyze [Game of Thrones](https://en.wikipedia.org/wiki/Game_of_Thrones) data and get some super-valuable extra-credit points.
#
# <p style="text-align:center">
#     <img src="https://imgs.xkcd.com/comics/sword_in_the_stone.png" alt="xkcd Sword in the Stone: That seems like an awful lot of hassle when all I wanted was a cool sword." width="800"/><br/>(source: <a href="https://xkcd.com/1521/">xkcd.com/1521</a>)
# </p>

# %% [markdown]
# - - -
# <p style="text-align:left;"> assignment-2 [PART 2] ends here <span style="float:right;font-size:11px;"> [[contents](#contents)] </span></p>
# - - -
